# %%
import csv
import pandas as pd

# %%
#set the mode to view the df
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
#read the raw spreadsheet
raw = pd.read_excel('/Users/songheekim/Google Drive/Primary/Projects/VerbVector/verblist_v2.5_wb.xlsx', index_col='Lemma')

# %%
raw.head()
# Out:
#        GrandIndex  Index  LogFreqHAL Concreteness  AgeofAcqsn Database  \
# Lemma
# work            1      1      13.020         3.48        5.86     CREA
# go              2      2      12.923         3.15        3.37     CREA
# run             3      3      12.316         4.31        4.47     CREA
# play            4      4      11.915         3.24        4.10     CREA
# live            5      5      11.763         3.57        6.10     CREA
#
#            Trans_Intrans      SynClass_Literature  SynFreq  \
# Lemma
# work                both               unergative      NaN
# go     intransitive only               unergative      NaN
# run                 both               unergative      NaN
# play                both               unergative      NaN
# live   intransitive only  unergative/unaccusative      NaN
#
#                 SynClassFinal Unnamed: 11  Typicality Note AspClass  \
# Lemma
# work               unergative       unerg         NaN  NaN   atelic
# go          unergative PP arg       unerg         NaN  NaN    telic
# run                unergative       unerg         NaN  NaN   atelic
# play   unergative, transitive       unerg         NaN  NaN   atelic
# live        unergative PP arg       unerg         NaN  NaN   atelic
#
#            SemanticType  \
# Lemma
# work             social
# go            ch of loc
# run          body movmt
# play             social
# live   long term status
#
#                                                                                    SemanticTypeLevin  \
# Lemma
# work                                                            verbs of creating and transformation
# go                                                               verbs of existence, verbs of motion
# run    verbs of creating and transformation, verbs of existence, verbs of existence, verbs of motion
# play                               verbs of creating and transformation, verbs of social interaction
# live                                             verbs of ingesting, lodge verbs, verbs of existence
#
#                      SemanticTypeNew  \
# Lemma
# work                           other
# go                    ch of location
# run         body movement or posture
# play   social or interpersonal event
# live              verbs of existence
#
#                                           SemanticType3  Percentage_dom_PoS  \
# Lemma
# work                                          26.5knead                0.57
# go                             47.7meander, 51.1advance                0.98
# run    26.3prepare, 47.5.1swarm, 47.7meander, 51.3.2run                0.89
# play                              26.7perform, 36.3meet                0.81
# live                      39.6gorge, 46lodge, 47.1exist                0.89
#
#        Length  Ortho_N  Phono_N   OLD   PLD  NPhon  NSyll  I_Mean_RT  \
# Lemma
# work        4        9       25  1.50  1.20      3      1    633.152
# go          2       17       48  1.35  1.00      2      1    597.688
# run         3       19       40  1.00  1.00      3      1    596.647
# play        4        6       15  1.45  1.10      3      1    537.909
# live        4       16       21  1.15  1.25      3      1    629.886
#
#        I_Mean_Accuracy  I_NMG_Mean_RT  I_NMG_Mean_Accuracy     N2_F     N3_F
# Lemma
# work              1.00        521.889                1.000  2421.10  1034.67
# go                0.97        524.071                1.000   974.49      NaN
# run               1.00        559.955                1.000   386.53   229.70
# play              1.00        566.077                0.963   781.22   329.47
# live              1.00        553.769                0.963  3645.64   606.44

# %%
# first attemp: make a crosstable from the raw
table_raw = pd.crosstab(raw.SynClassFinal, raw.AspClass, margins=True) #looks super messy due to messy labels

# %%
table_raw
# Out:
# AspClass                              a/telic  a/telic?  atelic  atelic?  \
# SynClassFinal
# transitive                                  3         0      28       10
# transitive (or covert obj)                  0         1       7        0
# unaccusative                                8        11      29        3
# unaccusative, transitive?                   0         0       1        0
# unaccusative, unergative                    0         0       1        0
# unaccusative,transitive                     0         0       1        0
# unaccusative?                               0         5      13        1
# unaccusative?                               0         0       0        0
# unaccusative? Unergative?                   0         0       0        0
# unaccusative? transitive?                   0         0       1        0
# unergative                                  0         0      42        3
# unergative PP arg                           0         0       2        0
# unergative PP arg, transitive               0         0       0        0
# unergative, transitive                      0         0       5        0
# unergative, transitive?                     0         0       2        0
# unergative, unaccusative                    0         0       2        0
# unergative, unaccusative, transitive        1         0       0        0
# unergative?                                 1         0      14        2
# unergative? unaccusative?                   0         0       0        0
# All                                        13        17     148       19
#
# AspClass                              atemporal?  punctual  punctual?  state  \
# SynClassFinal
# transitive                                    44         4          1     15
# transitive (or covert obj)                     0         1          0      0
# unaccusative                                   0         2          3      2
# unaccusative, transitive?                      0         0          0      0
# unaccusative, unergative                       0         0          0      0
# unaccusative,transitive                        0         0          0      0
# unaccusative?                                  0         0          0      1
# unaccusative?                                  0         0          0      0
# unaccusative? Unergative?                      0         0          0      0
# unaccusative? transitive?                      0         0          0      0
# unergative                                     0         4          4      0
# unergative PP arg                              0         0          0      0
# unergative PP arg, transitive                  0         0          0      0
# unergative, transitive                         0         0          0      0
# unergative, transitive?                        0         1          0      0
# unergative, unaccusative                       0         0          0      0
# unergative, unaccusative, transitive           0         0          0      0
# unergative?                                    0         2          0      0
# unergative? unaccusative?                      0         1          0      0
# All                                           44        15          8     18
#
# AspClass                              state?  telic  telic?  All
# SynClassFinal
# transitive                                 2     37      24  168
# transitive (or covert obj)                 0      2       0   11
# unaccusative                               1     46      19  124
# unaccusative, transitive?                  0      2       0    3
# unaccusative, unergative                   0      0       0    1
# unaccusative,transitive                    0      0       0    1
# unaccusative?                              1     12       7   40
# unaccusative?                              0      1       0    1
# unaccusative? Unergative?                  0      1       0    1
# unaccusative? transitive?                  0      3       2    6
# unergative                                 0      0       1   54
# unergative PP arg                          0      1       0    3
# unergative PP arg, transitive              0      1       0    1
# unergative, transitive                     0      0       0    5
# unergative, transitive?                    0      0       0    3
# unergative, unaccusative                   0      0       0    2
# unergative, unaccusative, transitive       0      0       0    1
# unergative?                                0      0       0   19
# unergative? unaccusative?                  0      0       0    1
# All                                        4    106      53  445

# %%
len(raw) #445 verbs in total
# Out:
# 445

# %%
##### run if need to calculate the number of unique Semantic Types #############
SemType = list(set(raw['SemanticTypeNew'].to_list()))
SemType = [i for i in SemType if (str(i) != 'nan')] #drop the nan value if exist

SemType_set = [] 
for i in SemType:
    if not i.startswith('verbs of appear'):
        split = i.split(',')
        for sp in split:
            #print (sp.strip("?").strip())
            SemType_set.append(sp.strip("?").strip())

        
SemType_set = list(set(SemType_set)) #the set of unique Semantic Types

# %%
SemType_set.sort()
SemType_set
# Out:
# ['aspectual verbs',
#  'body movement or posture',
#  'body process',
#  'ch of appearance',
#  'ch of cohesiveness',
#  'ch of location',
#  'ch of quantity',
#  'ch of state',
#  'cognitive event',
#  'communication',
#  'emotion',
#  'obj-directed motion or obj transfer',
#  'oral sound production',
#  'other',
#  'perception',
#  'social or interpersonal event',
#  'verbs of creation',
#  'verbs of emission',
#  'verbs of existence',
#  'verbs of motion']

# %%
len(SemType_set)
# Out:
# 20

# %%
##############second attempt: LETS CLEAN UP THE RAW #################

### first, lets define functions which will create new, tidy labels based on messy labels

def synclass_tidy(row):
    if row['SynClassFinal'].startswith('unerg'):
        return 'unergative'
    elif row['SynClassFinal'].startswith('unacc'):
        return 'unaccusative'
    elif row['SynClassFinal'].startswith('trans'):
        return 'transitive'
    else:
        return 'somethingwrong'

def aspclass_tidy(row):
    if row['AspClass'].startswith(('atelic', 'a/telic')):
        return 'atelic'
    elif row['AspClass'].startswith(('telic', 'punctual')):
        return 'telic'
    elif row['AspClass'].startswith('stat'):
        return 'state'
    elif row['AspClass'].startswith('atemp'):
        return 'atemp'   
    else:
        return 'somethingwrong'

# %%
#### just for test (ignore)
# raw.apply (lambda row: aspclass_tidy(row), axis=1)
# raw.agg((lambda row:synclass_tidy(row), lambda row:aspclass_tidy(row)), axis=1)

# %%
## function to rearrange the column positions 
def rearrange_col(dataframe, col_to_move, reference_col, right=True):
    col_list = dataframe.columns.values.tolist()
    col_list2 = [x for x in col_list if x != col_to_move]
    reference_idx = col_list2.index(reference_col)
    if right==True:
        col_list3 = []
        for y in col_list2:
            col_list3.append(y)
            if y == reference_col:
                col_list3.append(col_to_move)
        return dataframe[col_list3]
    else:
        col_list3 = []
        for y in col_list2:
            col_list3.append(y)
            if y == reference_col:
                col_list3.insert(-2, col_to_move)
        return  dataframe[col_list3]

# %%
### Add new labels as new columns & rearrange column position 
raw['SynClassTidy'] = raw.apply(lambda row: synclass_tidy(row), axis=1)
raw['AspClassTidy'] = raw.apply(lambda row: aspclass_tidy(row), axis=1)
raw2 = rearrange_col(raw, 'SynClassTidy', 'SynClassFinal')
raw3 = rearrange_col(raw2, 'AspClassTidy', 'AspClass') ### raw3 is the clean dataframe

# %%
## assign the updated raw to tidy_raw
tidy_raw = raw3

# %%
raw.head()

# %%
tidy_raw.head()

# %%
#somethingwrong = tidy_raw[tidy_raw['AspClassTidy']=='somethingwrong']

# %%
### now make a crosstable from the updated dataframe
table_tidy = pd.crosstab(tidy_raw.SynClassTidy, tidy_raw.AspClassTidy, margins=True)
table_tidy = table_tidy.loc[:, ['atemp', 'state', 'atelic', 'telic', 'All']]
table_tidy = table_tidy.loc[['unergative', 'unaccusative', 'transitive', 'All'], :]

# %%
table_tidy

# %%
###### Along with table_tidy, we'll make another table, "table_verbs", which shows individual verbs in it 
table_verbs = table_tidy.copy().loc[['unergative', 'unaccusative', 'transitive'], ['atemp', 'state', 'atelic', 'telic']] 
asp = table_verbs.columns.values.tolist()
syn = table_verbs.index.values.tolist()


for a in asp:
    for s in syn: 
        table_verbs[a] = table_verbs[a].astype('object')
        table_verbs.at[s,a] = tidy_raw.loc[(tidy_raw.SynClassTidy==s) & (tidy_raw.AspClassTidy==a)].index.tolist()

# for a in asp:
#     for s in syn: 
#         #table_verbs.loc[a,s] = tidy_raw.loc[(tidy_raw.SynClassTidy==s) & (tidy_raw.AspClassTidy==a)].index.tolist()
#         verbs=tidy_raw.loc[(tidy_raw.SynClassTidy==s) & (tidy_raw.AspClassTidy==a)].index.tolist()
#         table_verbs.loc[a,s] = verbs
#         verbs=[]

# %%
table_verbs

# %%
##attempt1: didn't work
# table_tidy_verbs = pd.crosstab(tidy_raw.SynClassTidy, tidy_raw.AspClassTidy, values=tidy_raw.index.values, aggfunc=ascii)
# table_tidy_verba

# %%
##########just testing ###############
# unerg_df = raw.loc[raw['SynClassFinal'].str.startswith('unergat')]
# unacc_df = raw.loc[raw['SynClassFinal'].str.startswith('unaccus')]
# trans_df = raw.loc[raw['SynClassFinal'].str.startswith('trans')]
# atelic_df = raw.loc[raw['AspClass'].str.startswith(('atelic', 'a/telic'))]
# telic_df = raw.loc[raw['AspClass'].str.startswith(('telic', 'punctual'))]
# state_df = raw.loc[raw['AspClass'].str.startswith('state')]
# atemp_df = raw.loc[raw['AspClass'].str.startswith('atemporal')]
#len(atelic_df) + len(telic_df) + len(state_df) + len(atemporal_df)
# unerg = unerg_df.index.to_list()
# unacc = unacc_df.index.to_list()
# trans = trans_df.index.to_list()
# atelic = atelic_df.index.to_list()
# telic = telic_df.index.to_list()
# state = state_df.index.to_list()
# atemp = atemp_df.index.to_list()
