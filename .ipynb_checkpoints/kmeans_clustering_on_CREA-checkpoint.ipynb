# %%
import csv, sys
import pandas as pd
import numpy as np
import random as rd
import matplotlib.pyplot as plt

# %%
raw = pd.read_csv('/Users/songkim/Google Drive/Primary/Projects/VerbVector/CREA_vrating_context_wb.csv', index_col=0)

# %%
raw.head()
# Out:
#       Lemma Database  AspClass SynClass   No        Word  WC   ID KRNS   N  \
# 0  approach     CREA  activity    trans  181  approached   2   19    Y  27
# 1    arrest     CREA   achieve    trans  182    arrested   2  201    Y  30
# 2       eat     CREA  activity    trans  183         ate   2  245    Y  29
# 3     block     CREA      else    trans  184     blocked   2  187    Y  27
# 4       buy     CREA   achieve    trans  185      bought   2   23    Y  29
#
#    ...  Dom_PoS_SUBTLEX  All_PoS_SUBTLEX  Percentage_dom_PoS  \
# 0  ...             Noun        Noun.Verb                0.63
# 1  ...             Noun   Noun.Verb.Name                0.56
# 2  ...             Verb        Verb.Noun                1.00
# 3  ...             Noun   Noun.Verb.Name                0.80
# 4  ...             Verb        Verb.Noun                0.99
#
#                                          Context 1  \
# 0  The yellow dog approached the friendly teacher.
# 1       The soldier arrested the injured activist.
# 2       The old farmer ate at the expensive hotel.
# 3              The bicycle blocked the green door.
# 4                 The doctor bought the used boat.
#
#                                   Context 2  \
# 0  The priest approached the lonely family.
# 1  The policeman arrested the angry driver.
# 2                      The dog ate the egg.
# 3                The cloud blocked the sun.
# 4     The banker bought the expensive boat.
#
#                                  Context 3  \
# 0          The mob approached the embassy.
# 1                                      NaN
# 2     The commander ate chicken at dinner.
# 3                                      NaN
# 4  The diplomat bought the aggressive dog.
#
#                             Context 4  \
# 0       The car approached the river.
# 1                                 NaN
# 2  The tourist ate bread on vacation.
# 3                                 NaN
# 4     The parent bought the magazine.
#
#                                  Context 5  Context 6  Context 7
# 0                                      NaN        NaN        NaN
# 1                                      NaN        NaN        NaN
# 2  The reporter ate at the new restaurant.        NaN        NaN
# 3                                      NaN        NaN        NaN
# 4  The woman bought medicine at the store.        NaN        NaN
#
# [5 rows x 292 columns]

# %%
#raw_es = vector with only "Event/Social" features
raw_es = raw[['Lemma', 'AspClass', 'SynClass', 'TimeCREA', 'DurationCREA', 'Long', 'Short', 'Caused', 'Consequential', 'Social', 'Human', 'Communication', 'Self', 'Cognition']]

# %%
raw_es.head()
# Out:
#       Lemma  AspClass SynClass  TimeCREA  DurationCREA    Long   Short  \
# 0  approach  activity    trans    1.0741        1.6667  0.5185  2.9630
# 1    arrest   achieve    trans    0.6000        1.6333  1.0667  2.4333
# 2       eat  activity    trans    3.2759        2.5862  0.7241  2.7241
# 3     block      else    trans    0.5185        1.0741  1.6296  1.5556
# 4       buy   achieve    trans    1.8276        1.8276  0.8621  3.0000
#
#    Caused  Consequential  Social   Human  Communication    Self  Cognition
# 0  1.7037         3.2963  4.1481  3.8889         2.4815  2.9259     1.1111
# 1  3.6000         5.2667  5.5333  3.9333         2.2000  0.1000     1.6667
# 2  2.4483         2.4483  2.0000  2.7931         0.6552  5.1034     1.0345
# 3  3.4074         4.2593  1.8889  2.2593         0.7778  0.7407     1.2963
# 4  1.8276         2.8276  4.5517  4.4828         3.2759  4.1034     2.6552

# %%
#plt.scatter(rc_es["Consequential"], rc_es["SynClass"])
#plt.xlabel("ratings on 'Consequential'")
#plt.ylabel("SynClass")
#plt.show()

# %%
synclass = set(raw_es['SynClass'].to_list())
synclass
# Out:
# {'trans', 'unacc', 'unerg'}

# %%
#Let's test how event/social features cluster the datapoints into three clusters. 
K=3
Centroids = (raw_es.sample(n=K))

#for initial plotting
# plt.scatter(rc_es["Caused"], rc_es["SynClass"], c='black')
# plt.scatter(Centroids["Caused"], Centroids["SynClass"], c='red')
# plt.show()

# %%
features = raw_es.columns.to_list()[3:]
features
# Out:
# ['TimeCREA',
#  'DurationCREA',
#  'Long',
#  'Short',
#  'Caused',
#  'Consequential',
#  'Social',
#  'Human',
#  'Communication',
#  'Self',
#  'Cognition']

# %%
#enumerate(features)

# %%
for i, j in enumerate(features):
    print (i,j)
# Out:
# 0 TimeCREA
# 1 DurationCREA
# 2 Long
# 3 Short
# 4 Caused
# 5 Consequential
# 6 Social
# 7 Human
# 8 Communication
# 9 Self
# 10 Cognition

# %%
dic = {1:3, 2:4, 3:5}
len(dic.values())
#np.sqrt(sum(dic.values()))
# Out:
# 3

# %%
diff = 1
j=0


while(diff!=0):
    XD=raw_es
    i=1
    for index_c,row_c in Centroids.iterrows():
        ED=[]
        for index_r,row_r in XD.iterrows():
            d_dict = {}
            for a, b in enumerate(features):
                d_dict[a+1] = (row_c[b]-row_r[b])**2
            d=np.sqrt(sum(d_dict.values()))
            ED.append(d)
        raw_es[i]=ED
        i=i+1
        
        
    C=[]
    for index,row in raw_es.iterrows():
        min_dist=row[1]
        pos=1
        for i in range(K):
            if row[i+1] < min_dist:
                min_dist = row[i+1]
                pos=i+1
        C.append(pos)
    raw_es["Cluster"]=C
    Centroids_new = raw_es.groupby(["Cluster"]).mean()[features]
    

    if j == 0:
        diff=1
        j=j+1
    else:
        diff = 0
        for c, d in enumerate(features):
            diff += (Centroids_new[d] - Centroids[d]).sum()
        print(diff)
    Centroids = raw_es.groupby(["Cluster"]).mean()[features]
# Out:
# 1.4229763160051756
# /Users/songkim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /Users/songkim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0.93681861634742
# 0.6950307179487184
# 0.8005521410256423
# 1.0358899067599072
# 0.0

# %%
raw_es.drop([1, 2, 3], axis=1)
# Out:
#        Lemma  AspClass SynClass  TimeCREA  DurationCREA    Long   Short  \
# 0   approach  activity    trans    1.0741        1.6667  0.5185  2.9630
# 1     arrest   achieve    trans    0.6000        1.6333  1.0667  2.4333
# 2        eat  activity    trans    3.2759        2.5862  0.7241  2.7241
# 3      block      else    trans    0.5185        1.0741  1.6296  1.5556
# 4        buy   achieve    trans    1.8276        1.8276  0.8621  3.0000
# ..       ...       ...      ...       ...           ...     ...     ...
# 57      want     state    trans    0.6154        0.8846  1.5769  1.8462
# 58     watch  activity    trans    1.0690        1.5862  1.6207  2.0345
# 59        go   achieve    unerg    1.0000        1.1290  1.2581  1.8387
# 60      work  activity    unerg    4.5000        4.2857  2.6429  1.3571
# 61     write  activity    unerg    0.6207        1.2759  1.6897  1.8966
#
#     Caused  Consequential  Social   Human  Communication    Self  Cognition  \
# 0   1.7037         3.2963  4.1481  3.8889         2.4815  2.9259     1.1111
# 1   3.6000         5.2667  5.5333  3.9333         2.2000  0.1000     1.6667
# 2   2.4483         2.4483  2.0000  2.7931         0.6552  5.1034     1.0345
# 3   3.4074         4.2593  1.8889  2.2593         0.7778  0.7407     1.2963
# 4   1.8276         2.8276  4.5517  4.4828         3.2759  4.1034     2.6552
# ..     ...            ...     ...     ...            ...     ...        ...
# 57  1.9231         3.6154  2.3846  4.7692         2.1923  3.4615     4.4615
# 58  1.1724         1.9655  2.2069  2.7586         2.4483  3.5862     2.4483
# 59  1.5161         2.2903  1.7097  3.4194         0.7742  2.9677     0.8065
# 60  2.8929         4.3214  4.9286  4.8929         3.4286  5.1071     4.0714
# 61  2.2414         2.3103  2.2759  3.7241         5.7586  3.7241     4.8276
#
#     Cluster
# 0         2
# 1         1
# 2         3
# 3         1
# 4         2
# ..      ...
# 57        2
# 58        3
# 59        3
# 60        2
# 61        2
#
# [62 rows x 15 columns]

# %%
raw_es
# Out:
#        Lemma  AspClass SynClass  TimeCREA  DurationCREA    Long   Short  \
# 0   approach  activity    trans    1.0741        1.6667  0.5185  2.9630
# 1     arrest   achieve    trans    0.6000        1.6333  1.0667  2.4333
# 2        eat  activity    trans    3.2759        2.5862  0.7241  2.7241
# 3      block      else    trans    0.5185        1.0741  1.6296  1.5556
# 4        buy   achieve    trans    1.8276        1.8276  0.8621  3.0000
# ..       ...       ...      ...       ...           ...     ...     ...
# 57      want     state    trans    0.6154        0.8846  1.5769  1.8462
# 58     watch  activity    trans    1.0690        1.5862  1.6207  2.0345
# 59        go   achieve    unerg    1.0000        1.1290  1.2581  1.8387
# 60      work  activity    unerg    4.5000        4.2857  2.6429  1.3571
# 61     write  activity    unerg    0.6207        1.2759  1.6897  1.8966
#
#     Caused  Consequential  Social   Human  Communication    Self  Cognition  \
# 0   1.7037         3.2963  4.1481  3.8889         2.4815  2.9259     1.1111
# 1   3.6000         5.2667  5.5333  3.9333         2.2000  0.1000     1.6667
# 2   2.4483         2.4483  2.0000  2.7931         0.6552  5.1034     1.0345
# 3   3.4074         4.2593  1.8889  2.2593         0.7778  0.7407     1.2963
# 4   1.8276         2.8276  4.5517  4.4828         3.2759  4.1034     2.6552
# ..     ...            ...     ...     ...            ...     ...        ...
# 57  1.9231         3.6154  2.3846  4.7692         2.1923  3.4615     4.4615
# 58  1.1724         1.9655  2.2069  2.7586         2.4483  3.5862     2.4483
# 59  1.5161         2.2903  1.7097  3.4194         0.7742  2.9677     0.8065
# 60  2.8929         4.3214  4.9286  4.8929         3.4286  5.1071     4.0714
# 61  2.2414         2.3103  2.2759  3.7241         5.7586  3.7241     4.8276
#
#            1         2         3  Cluster
# 0   4.180230  2.979728  3.450860        2
# 1   4.126788  5.045434  6.390605        1
# 2   5.419397  5.518398  2.854566        3
# 3   1.423540  5.839898  3.998373        1
# 4   5.580585  1.717259  4.504806        2
# ..       ...       ...       ...      ...
# 57  4.651101  3.212753  4.628622        2
# 58  4.579891  3.386288  2.265519        3
# 59  3.729017  4.987439  1.573514        3
# 60  8.077945  4.955026  7.388720        2
# 61  6.809439  3.408152  6.270702        2
#
# [62 rows x 18 columns]

# %%
# color=['blue','green','cyan']
# for k in range(K):
#     data=raw_es[raw_es["Cluster"]==k+1]
#     plt.scatter(data["AspClass"],data["SynClass"],c=color[k])
# #plt.scatter(Centroids["AspClass"],Centroids["SynClass"],c='red')
# plt.xlabel('AspClass')
# plt.ylabel('SynClass')
# plt.show()

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
raw_es.sort_values(by= ['SynClass', 'Cluster']).drop([1,2,3], axis=1)
# Out:
#         Lemma  AspClass SynClass  TimeCREA  DurationCREA    Long   Short  \
# 1      arrest   achieve    trans    0.6000        1.6333  1.0667  2.4333
# 3       block      else    trans    0.5185        1.0741  1.6296  1.5556
# 5       break   achieve    trans    0.2593        1.1481  0.5185  3.0741
# 6       build   accompl    trans    1.4194        2.2581  2.7419  1.5161
# 10     damage   achieve    trans    0.2414        0.7931  1.1724  2.1034
# 12    destroy   achieve    trans    0.5200        1.1200  1.6000  1.9600
# 15       drop   achieve    trans    0.2333        2.4333  0.0667  4.1000
# 17       fear     state    trans    0.3929        0.7500  1.2857  2.0714
# 19        fix   achieve    trans    1.0000        1.3793  2.0000  2.0345
# 28       kick      else    trans    0.6071        2.0357  0.2857  3.2143
# 35       lose   achieve    trans    0.4231        0.3462  1.6923  1.6923
# 50      steal   achieve    trans    0.5172        0.7931  0.5517  2.7241
# 51    survive      else    trans    0.2917        1.0417  2.0833  1.5833
# 53       take   achieve    trans    0.9310        1.2759  0.9655  2.6552
# 0    approach  activity    trans    1.0741        1.6667  0.5185  2.9630
# 4         buy   achieve    trans    1.8276        1.8276  0.8621  3.0000
# 11    deliver   achieve    trans    2.5517        2.3793  1.7931  2.5172
# 14       draw  activity    trans    0.2903        1.4839  1.9355  2.2581
# 22       give   achieve    trans    1.3548        1.8710  0.9355  2.8065
# 25       help  activity    trans    0.5000        0.8846  1.4231  1.8077
# 27  interview  activity    trans    2.4516        3.4194  1.1935  3.1613
# 32       like     state    trans    0.4286        0.9286  1.7500  1.4286
# 33     listen  activity    trans    0.5862        0.8621  1.0690  1.6897
# 37       meet  activity    trans    1.4516        2.2903  0.4516  2.7742
# 40       plan  activity    trans    2.3462        2.3462  2.5769  1.8077
# 41       play  activity    trans    1.4643        2.1786  1.2857  2.0714
# 44       read  activity    trans    1.2857        1.5000  1.5714  1.8929
# 48      speak  activity    trans    0.5000        1.3333  1.4000  2.0667
# 54        use  activity    trans    1.3478        2.1304  1.5652  2.4348
# 55      visit  activity    trans    1.5185        2.6296  1.7407  2.5926
# 57       want     state    trans    0.6154        0.8846  1.5769  1.8462
# 2         eat  activity    trans    3.2759        2.5862  0.7241  2.7241
# 7       carry  activity    trans    0.6667        1.8667  1.1333  2.6333
# 9       cross      else    trans    1.4167        2.3333  1.2917  2.5833
# 13      drink  activity    trans    1.5484        2.9032  0.6129  3.6452
# 18       feed  activity    trans    3.7586        3.0000  0.8621  2.8966
# 21       find   achieve    trans    0.1481        1.0000  0.7407  2.3704
# 24       hold  activity    trans    0.3333        1.0370  0.7407  2.1481
# 31      leave   achieve    trans    1.6207        1.7931  1.0000  3.0690
# 39       open   achieve    trans    1.0000        2.4231  0.3846  3.8077
# 42        put   achieve    trans    0.6296        1.4815  0.2963  3.1481
# 45        see  activity    trans    0.3333        0.6250  0.5000  1.9167
# 52      throw   achieve    trans    1.0000        1.4643  0.3214  3.1071
# 58      watch  activity    trans    1.0690        1.5862  1.6207  2.0345
# 16        end   achieve    unacc    2.3478        2.5652  0.8696  2.4348
# 23       grow  activity    unacc    2.1600        3.0400  4.7200  1.1600
# 47      sleep  activity    unacc    4.2500        3.7143  2.0357  1.9643
# 8   celebrate  activity    unerg    1.9000        2.3667  1.3333  2.2000
# 38  negotiate  activity    unerg    1.2500        1.6563  2.3125  2.0000
# 46      shout  activity    unerg    0.2000        1.2333  0.4333  2.1333
# 60       work  activity    unerg    4.5000        4.2857  2.6429  1.3571
# 61      write  activity    unerg    0.6207        1.2759  1.6897  1.8966
# 20        fly  activity    unerg    1.3929        2.7143  1.7857  1.6429
# 26       hike  activity    unerg    1.4667        2.5333  1.5667  1.8000
# 29       land   achieve    unerg    1.2692        2.5385  0.5385  3.0769
# 30      laugh  activity    unerg    0.6000        2.0333  0.4667  2.9333
# 34       live  activity    unerg    1.6552        3.1724  4.5172  0.4828
# 36      march  activity    unerg    0.9630        2.5556  1.1852  2.0370
# 43        run  activity    unerg    1.1935        2.0000  1.1290  1.9677
# 49       stay  activity    unerg    1.4483        2.7241  2.2069  2.1034
# 56       walk  activity    unerg    1.5862        2.3103  1.4138  2.1379
# 59         go   achieve    unerg    1.0000        1.1290  1.2581  1.8387
#
#     Caused  Consequential  Social   Human  Communication    Self  Cognition  \
# 1   3.6000         5.2667  5.5333  3.9333         2.2000  0.1000     1.6667
# 3   3.4074         4.2593  1.8889  2.2593         0.7778  0.7407     1.2963
# 5   4.9630         5.2222  0.5926  1.8519         0.2963  1.0741     0.3704
# 6   3.7742         2.7742  2.8387  4.8710         0.7742  1.3226     2.9355
# 10  5.2759         4.8276  1.0000  1.7931         0.4138  0.5517     0.4483
# 12  5.4800         5.0800  1.3200  2.7600         0.5600  0.2800     0.5200
# 15  2.8333         4.0333  0.6667  1.0667         0.3000  1.5667     0.6333
# 17  3.6071         4.0000  2.6429  2.3571         1.8929  1.7143     3.8929
# 19  4.8276         3.4483  1.9310  3.9655         1.2414  2.8966     3.5172
# 28  3.1071         4.5357  2.3929  2.2857         0.5000  1.1429     0.9643
# 35  2.5385         4.1923  0.7692  1.8077         0.8846  1.3846     2.3846
# 50  2.8966         5.4828  2.7586  4.7586         0.7586  0.1724     2.3103
# 51  3.0417         3.9583  2.2500  4.0417         0.7917  1.6250     2.4167
# 53  2.8276         4.0345  3.4483  4.0345         1.2759  2.5517     2.3793
# 0   1.7037         3.2963  4.1481  3.8889         2.4815  2.9259     1.1111
# 4   1.8276         2.8276  4.5517  4.4828         3.2759  4.1034     2.6552
# 11  1.6552         2.7586  5.0345  3.8276         4.7931  1.9310     1.1724
# 14  3.2581         1.2581  1.5161  3.9355         2.9032  2.0968     4.0323
# 22  2.6774         2.8710  5.5806  4.1613         3.7097  3.7097     1.4516
# 25  4.1538         4.0000  5.2692  4.6923         3.2308  3.6154     3.0385
# 27  2.3226         3.8710  5.9032  4.8065         5.6774  1.6129     4.3226
# 32  1.8929         2.2500  2.2143  3.3214         2.0714  4.5000     4.1071
# 33  1.4828         2.3103  4.7931  3.1034         5.4828  4.6207     3.9655
# 37  1.8065         3.0968  5.8710  3.2903         4.7097  3.6129     2.3871
# 40  2.9615         4.4231  4.0769  5.6923         3.9231  3.1154     5.0769
# 41  1.4643         2.5000  4.8929  3.6071         2.3214  3.7500     2.4643
# 44  1.0357         1.4643  1.1071  3.2500         5.0000  4.7500     5.2500
# 48  2.4333         3.5667  5.5667  4.1000         6.0000  4.1667     3.6333
# 54  3.6522         3.7391  2.3478  4.3043         2.3913  4.5652     3.1739
# 55  1.7407         2.6667  5.1852  4.4444         3.4444  3.8148     1.5926
# 57  1.9231         3.6154  2.3846  4.7692         2.1923  3.4615     4.4615
# 2   2.4483         2.4483  2.0000  2.7931         0.6552  5.1034     1.0345
# 7   2.1333         2.5333  1.8667  3.5000         1.7000  3.9667     0.5667
# 9   1.3333         2.4583  1.5833  4.0000         1.3333  2.3333     1.1667
# 13  2.0645         2.2258  0.9677  1.6452         0.1613  4.9355     0.6774
# 18  3.2759         2.9655  2.4483  2.5517         0.2759  4.2069     1.0000
# 21  2.1111         3.2222  1.5926  2.8519         1.0000  2.7037     2.2222
# 24  0.7778         1.5185  2.2963  2.3333         0.7407  3.4815     0.3704
# 31  2.5517         2.5517  1.8966  2.9655         1.3793  2.6552     1.4138
# 39  2.8846         2.6538  1.0000  2.2308         0.7308  3.1154     0.4615
# 42  2.6667         2.0370  1.0370  3.0741         1.0370  3.4815     1.3704
# 45  0.5833         1.9167  1.6250  1.9583         2.4167  4.8333     2.9583
# 52  2.1786         3.1429  2.5357  2.8214         0.8214  2.1786     1.1429
# 58  1.1724         1.9655  2.2069  2.7586         2.4483  3.5862     2.4483
# 16  4.3043         3.1739  1.3043  2.0000         0.5652  1.3478     1.5652
# 23  3.5600         2.7600  0.4400  1.2800         0.2800  2.2400     0.8400
# 47  1.0000         1.6071  0.4286  1.8929         0.3929  5.0714     0.7857
# 8   1.6333         2.3333  4.8667  4.1000         2.9667  2.5333     1.9000
# 38  3.6563         4.5625  5.8438  5.1875         5.3750  1.5625     5.0625
# 46  2.1667         3.4667  4.4000  3.4333         4.8333  1.5000     1.7333
# 60  2.8929         4.3214  4.9286  4.8929         3.4286  5.1071     4.0714
# 61  2.2414         2.3103  2.2759  3.7241         5.7586  3.7241     4.8276
# 20  1.2500         2.4286  1.0357  1.7857         0.9643  1.1429     0.7857
# 26  0.4000         1.5000  2.2333  3.6333         0.4667  2.6000     1.3000
# 29  1.9231         2.5385  0.4615  1.2308         0.4615  1.0385     0.6154
# 30  1.6667         1.5333  3.8667  1.8667         2.6333  4.1333     2.0333
# 34  2.0690         2.7931  2.7586  3.8276         2.0345  5.3793     2.2759
# 36  1.0370         1.9630  3.6296  3.3704         1.1481  0.4815     1.0741
# 43  1.4194         2.1935  0.8387  2.9677         0.4194  2.9032     0.5806
# 49  0.9655         1.7931  1.4483  3.1724         0.8621  2.6207     0.8621
# 56  1.5862         2.2069  1.3793  3.2759         0.6897  4.4138     0.5172
# 59  1.5161         2.2903  1.7097  3.4194         0.7742  2.9677     0.8065
#
#     Cluster
# 1         1
# 3         1
# 5         1
# 6         1
# 10        1
# 12        1
# 15        1
# 17        1
# 19        1
# 28        1
# 35        1
# 50        1
# 51        1
# 53        1
# 0         2
# 4         2
# 11        2
# 14        2
# 22        2
# 25        2
# 27        2
# 32        2
# 33        2
# 37        2
# 40        2
# 41        2
# 44        2
# 48        2
# 54        2
# 55        2
# 57        2
# 2         3
# 7         3
# 9         3
# 13        3
# 18        3
# 21        3
# 24        3
# 31        3
# 39        3
# 42        3
# 45        3
# 52        3
# 58        3
# 16        1
# 23        3
# 47        3
# 8         2
# 38        2
# 46        2
# 60        2
# 61        2
# 20        3
# 26        3
# 29        3
# 30        3
# 34        3
# 36        3
# 43        3
# 49        3
# 56        3
# 59        3

# %%
#raw_es.groupby(['SynClass','Cluster']).size().transform(lambda x: x/sum(x)).unstack(fill_value=0).plot.bar()
fig = raw_es.groupby(['SynClass','Cluster']).size().transform(lambda x: x/sum(x)).unstack(fill_value=0).plot(kind='bar',  figsize=(8, 4), fontsize=15, position=0.9, rot=1).get_figure()
fig.savefig('/users/songkim/Google Drive/Primary/Projects/VerbVector/cluster_by_synclass.pdf')

# %%
fig2 = raw_es.groupby(['Cluster','SynClass']).size().transform(lambda x: x/sum(x)).unstack(fill_value=0).plot(kind='bar',  figsize=(8, 4), fontsize=15, rot=1).get_figure()
fig2.savefig('/users/songkim/Google Drive/Primary/Projects/VerbVector/synclass_by_cluster.pdf')

# %%
fig3 = raw_es.groupby(['AspClass','Cluster']).size().transform(lambda x: x/sum(x)).unstack(fill_value=0).plot(kind='bar',  figsize=(8, 4), fontsize=15, rot=0).get_figure()
fig3.savefig('/users/songkim/Google Drive/Primary/Projects/VerbVector/cluster_by_aspclass.pdf')

#raw_es.groupby(['AspClass','Cluster']).size().transform(lambda x: x/sum(x)).unstack(fill_value=0).plot.bar()

# %%
fig4 = raw_es.groupby(['Cluster','AspClass']).size().transform(lambda x: x/sum(x)).unstack(fill_value=0).plot(kind='bar',  figsize=(8, 4), fontsize=25, rot=1).get_figure()
fig4.savefig('/users/songkim/Google Drive/Primary/Projects/VerbVector/synclass_by_cluster.pdf')

# %%
color=['blue','green','cyan']
for k in range(K):
    data=raw_es[raw_es["Cluster"]==k+1]
    plt.scatter(data["Caused"],data["Consequential"],c=color[k])
#plt.scatter(Centroids["AspClass"],Centroids["SynClass"],c='red')
plt.xlabel('Caused')
plt.ylabel('Consequential')
#plt.show()
plt.savefig('/users/songkim/Google Drive/Primary/Projects/verbvector/caused_consequential_scatter.png', format='png')

# %%
color=['blue','green','cyan']
for k in range(K):
    data=raw_es[raw_es["Cluster"]==k+1]
    plt.scatter(data["AspClass"],data["SynClass"],c=color[k])
#plt.scatter(Centroids["AspClass"],Centroids["SynClass"],c='red')
plt.xlabel('Aspectual Class')
plt.ylabel('Syntactic Class')
plt.show()

# %%
groups = raw_es.groupby('Cluster')

# %%
raw_es['AspClass']
# Out:
# 0     activity
# 1      achieve
# 2     activity
# 3         else
# 4      achieve
# 5      achieve
# 6      accompl
# 7     activity
# 8     activity
# 9         else
# 10     achieve
# 11     achieve
# 12     achieve
# 13    activity
# 14    activity
# 15     achieve
# 16     achieve
# 17       state
# 18    activity
# 19     achieve
# 20    activity
# 21     achieve
# 22     achieve
# 23    activity
# 24    activity
# 25    activity
# 26    activity
# 27    activity
# 28        else
# 29     achieve
# 30    activity
# 31     achieve
# 32       state
# 33    activity
# 34    activity
# 35     achieve
# 36    activity
# 37    activity
# 38    activity
# 39     achieve
# 40    activity
# 41    activity
# 42     achieve
# 43    activity
# 44    activity
# 45    activity
# 46    activity
# 47    activity
# 48    activity
# 49    activity
# 50     achieve
# 51        else
# 52     achieve
# 53     achieve
# 54    activity
# 55    activity
# 56    activity
# 57       state
# 58    activity
# 59     achieve
# 60    activity
# 61    activity
# Name: AspClass, dtype: object

# %%
import seaborn as sns
sns.swarmplot("Cluster", 'AspClass', hue='Cluster', data=raw_es)

# %%
fig, ax = plt.subplots()
for name, group in groups:
    ax.scatter(group['AspClass'], group['SynClass'], marker='o', label=name)

# %%
plt.scatter(raw_es['AspClass'], raw_es["SynClass"])

# %%
raw_neat = raw_es.sort_values(by=['Cluster']).drop([1,2,3], axis=1)

# %%
raw_neat.to_csv('/Users/songkim/Google Drive/Primary/Projects/VerbVector/kmeans_result.csv')
