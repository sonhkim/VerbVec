# %%
import csv
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
def rearrange_col(dataframe, col_to_move, reference_col, right=True):
    col_list = dataframe.columns.values.tolist()
    col_list2 = [x for x in col_list if x != col_to_move]
    reference_idx = col_list2.index(reference_col)
    if right==True:
        col_list3 = []
        for y in col_list2:
            col_list3.append(y)
            if y == reference_col:
                col_list3.append(col_to_move)
        return dataframe[col_list3]
    else:
        col_list3 = []
        for y in col_list2:
            col_list3.append(y)
            if y == reference_col:
                col_list3.insert(-2, col_to_move)
        return  dataframe[col_list3]

# %%
def get_key(val): 
    for key, value in row.items():  ##replace the dict name as needed
         if val == value: 
             return key 
  
    return "not found"

# %%
raw = pd.read_excel('/Users/songheekim/Google Drive/Primary/Projects/VerbVector/verblist_v2.10_wb.xlsx')

# %%
raw = raw.set_index('Lemma')

# %%
#raw['GrandIndex'].tolist()

# %%
pd.to_numeric([raw["GrandIndex"], raw["unerg_pb"], raw["unacc_pb"], raw["tr_pb"], raw["totalN_pb"], raw["intr_g"], raw["tr_g"], raw["totalN_g"]], errors='ignore')
# Out:
# array([[1, 2, 3, ..., 443, 444, 445],
#        [0.78, 0.16, 0.18, ..., 0.5, nan, nan],
#        [0.044, 0.43, 0.34, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., 0.0, nan, nan],
#        [nan, nan, nan, ..., 0.36, nan, nan],
#        [nan, nan, nan, ..., 88.0, nan, nan]], dtype=object)

# %%
raw_dic = raw.to_dict(orient='index')

# %%
raw_dic

# %%
l = [15, 59, 1000, -1, 'ab']
l2 = [i for i in l if isinstance(i, int)]
print(l2)

# %%
### get the category from
for verb, row in raw_dic.items():
    #print(verb)
    l = [row['unerg_pb'], row['unacc_pb'], row['tr_pb']]
    #print (l)
    #l2 = [i for i in l if isinstance(i, float)]
    l3 = [number for number in l if pd.notna(number)]
    if len(l3) > 0: 
        mx = max(l3)
        pb_cat = get_key(mx)
        row['most_frequent_pb'] = pb_cat[0:-3]
#     l = []
#     unerg = raw[verb]['unerg_pb']
#     unacc = raw[verb]['unacc_pb']
#     tr = raw[verb]['tr_pb']
#     l.append([unerg, unacc, tr])
#     for x in l:
#         if x=='':
#             x=0
#     ordered_list = l.sort(reverse=True)
#     raw[verb]['mostfrequent'] = get_key(ordered_list[0])

# %%
raw_dic['work']
# Out:
# {'GrandIndex': 1,
#  'Index': 1,
#  'LogFreqHAL': 13.02,
#  'Concreteness': 3.48,
#  'AgeofAcqsn': 5.86,
#  'Database': 'CREA',
#  'Trans_Intrans': 'both',
#  'SynClass_Literature': 'unergative',
#  'SynFreq': nan,
#  'SynClassFinal': 'unergative',
#  'unerg_pb': 0.78,
#  'unacc_pb': 0.044,
#  'tr_pb': 0.16,
#  'totalN_pb': 431.0,
#  'intr_g': nan,
#  'tr_g': nan,
#  'totalN_g': nan,
#  'Note': nan,
#  'AspClass_SK': 'atelic',
#  'AspClass_JB': 'atelic',
#  'AspClass_Consensus': 'Process',
#  'SemanticType': 'social',
#  'SemanticTypeLevin': 'verbs of creating and transformation',
#  'SemanticTypeNew': 'other',
#  'SemanticType_JB': 'other - general process',
#  'SemanticType_JB_edit': 'other - general process',
#  'Typicality_JB': 5.0,
#  'SemanticType_LC': 'other',
#  'Typicality_LC': nan,
#  'AGREE(formula)': 'NO',
#  'AGREE': 'YES',
#  'CONSENSUS_SK': 'other',
#  'CONSENSUS_LC': 'other',
#  'Comment_LC': nan,
#  'CONSENSUS_JB': 'other',
#  'Fit_JB': nan,
#  'SemClass_Consensus': 'other',
#  'CONSENSUS_JB.1': 'other',
#  'SemanticType3': '26.5knead',
#  'Percentage_dom_PoS': 0.57,
#  'Length': 4,
#  'Ortho_N': 9,
#  'Phono_N': 25,
#  'OLD': 1.5,
#  'PLD': 1.2,
#  'NPhon': 3,
#  'NSyll': 1,
#  'I_Mean_RT': 633.152,
#  'I_Mean_Accuracy': 1.0,
#  'I_NMG_Mean_RT': 521.889,
#  'I_NMG_Mean_Accuracy': 1.0,
#  'N2_F': 2421.1,
#  'N3_F': 1034.67,
#  'most_frequent_pb': 'unerg'}

# %%
raw_upd = pd.DataFrame.from_dict(raw_dic, orient='index')

# %%
# raw_upd.head()

# %%
raw_upd = rearrange_col(raw_upd, 'most_frequent_pb', 'totalN_pb', right=True)

# %%
raw_upd

# %%
### get the category from g ratings
for verb, row in raw_dic.items():
    #print(verb)
    l = [row['intr_g'], row['tr_g']]
    #print (l)
    #l2 = [i for i in l if isinstance(i, float)]
    l2 = [number for number in l if pd.notna(number)]
    if len(l2) > 0: 
        mx = max(l2)
        g_cat = get_key(mx)
        row['most_frequent_g'] = g_cat[0:-2]

# %%
raw_upd = pd.DataFrame.from_dict(raw_dic, orient='index')
raw_upd = rearrange_col(raw_upd, 'most_frequent_g', 'totalN_g', right=True)

# %%
raw_upd
# Out:
#               GrandIndex  Index  LogFreqHAL Concreteness  AgeofAcqsn Database  \
# work                   1      1      13.020         3.48        5.86     CREA
# go                     2      2      12.923         3.15        3.37     CREA
# run                    3      3      12.316         4.31        4.47     CREA
# play                   4      4      11.915         3.24        4.10     CREA
# live                   5      5      11.763         3.57        6.10     CREA
# leave                  6      6      11.245         2.53        5.58     CREA
# speak                  7      7      10.891          3.7        3.56     CREA
# listen                 8      8      10.432         3.47        5.40     CREA
# walk                   9      9      10.407         4.07        3.45     CREA
# cross                 10     10      10.301         4.44        4.74     CREA
# fly                   11     11      10.289         4.64        3.05     CREA
# sleep                 12     12      10.151         4.44        2.79     CREA
# laugh                 13     13       9.507         4.21        3.79     CREA
# negotiate             14     14       8.350            2       10.85     CREA
# shout                 15     15       8.097         4.17        4.72     CREA
# act                   16     16      11.187         2.46        6.42  VerbNet
# jump                  17     17      10.198         4.52        2.84  VerbNet
# dance                 18     18      10.171         4.32        4.63  VerbNet
# lie                   19     19       9.995         3.11        3.75  VerbNet
# cry                   20     20       9.492            4        2.78  VerbNet
# sing                  21     21       9.298         4.34        3.47  VerbNet
# skate                 22     22       9.243         4.56        5.37  VerbNet
# dive                  23     23       9.009         4.03        7.21  VerbNet
# scream                24     24       8.914         4.32        4.20  VerbNet
# proceed               25     25       8.780         2.55        8.33  VerbNet
# hesitate              26     26       8.666         2.46        8.30  VerbNet
# behave                27     27       8.656         1.78        4.28  VerbNet
# swim                  28     28       8.540         4.43        4.17  VerbNet
# hop                   29     29       8.408          3.8        4.84  VerbNet
# sail                  30     30       8.175         4.59        6.47  VerbNet
# yell                  31     31       8.108         3.86        3.83  VerbNet
# howl                  32     32       8.079         3.83        5.55  VerbNet
# pee                   33     33       8.058         4.72        3.89  VerbNet
# crawl                 34     34       8.049         4.27        3.89  VerbNet
# breathe               35     35       8.045         4.07        4.11  VerbNet
# sneak                 36     36       7.878         2.82        5.83  VerbNet
# wander                37     37       7.832         2.28        6.89  VerbNet
# moan                  38     38       7.669         3.72        7.72  VerbNet
# nod                   39     39       7.665         4.62        5.62  VerbNet
# blink                 40     40       7.629         4.39        5.63  VerbNet
# gamble                41     41       7.585         3.17        9.05  VerbNet
# shuffle               42     42       7.580         3.83        8.95  VerbNet
# fret                  43     43       7.560         2.65       11.11  VerbNet
# endure                44     44       7.528            2       10.70  VerbNet
# whisper               45     45       7.473         4.34        4.26  VerbNet
# shrug                 46     46       7.449         4.21        7.94  VerbNet
# prosper               47     47       7.410         2.27       10.06  VerbNet
# prevail               48     48       7.365         1.43       10.33  VerbNet
# depart                49     49       7.308         2.86        9.89  VerbNet
# giggle                50     50       7.206         3.72        5.48  VerbNet
# yawn                  51     51       7.195         4.46        5.30  VerbNet
# vomit                 52     52       7.180         4.75        5.68  VerbNet
# puke                  53     53       7.152         4.59        6.94  VerbNet
# hiss                  54     54       7.034          3.6        6.33  VerbNet
# cringe                55     55       6.836         3.34        9.11  VerbNet
# inhale                56     56       6.753         3.84        7.26  VerbNet
# weep                  57     57       6.717         4.54        8.50  VerbNet
# meditate              58     58       6.687         3.25       11.44  VerbNet
# hustle                59     59       6.667         2.96        9.72  VerbNet
# stoop                 60     60       6.646         4.63        9.76  VerbNet
# kneel                 61     61       6.597         4.31        6.95  VerbNet
# strut                 62     62       6.594         3.97        9.00  VerbNet
# squirm                63     63       6.593         3.82        9.18  VerbNet
# shiver                64     64       6.544         3.88        7.50  VerbNet
# bathe                 65     65       6.507         4.19        5.00  VerbNet
# jog                   66     66       6.486         3.63        6.21  VerbNet
# retaliate             67     67       6.412         2.25       10.00  VerbNet
# squeal                68     68       6.378         3.42        7.00  VerbNet
# mumble                69     69       6.377         3.69        7.15  VerbNet
# dine                  70     70       6.346         3.37        8.95  VerbNet
# sneeze                71     71       6.292         4.03        4.17  VerbNet
# squeak                72     72       6.246         4.07        5.84  VerbNet
# burp                  73     73       6.144         4.34        4.67  VerbNet
# wail                  74     74       6.078         3.93        9.41  VerbNet
# urinate               75     75       6.073         4.46        7.63  VerbNet
# oink                  76     76       6.059         3.24        3.44  VerbNet
# flinch                77     77       5.875         3.59        7.89  VerbNet
# persevere             78     78       5.793         1.48       11.05  VerbNet
# stutter               79     79       5.700         3.97        8.78  VerbNet
# bellow                80     80       5.670         3.42       11.11  VerbNet
# snooze                81     81       5.666         3.31        6.84  VerbNet
# belch                 82     82       5.645         4.14        6.22  VerbNet
# doze                  83     83       5.624         3.46        8.00  VerbNet
# squint                84     84       5.565          4.3        8.05  VerbNet
# wriggle               85     85       5.525         3.63        6.47  VerbNet
# scoot                 86     86       5.425         2.89        6.00  VerbNet
# snore                 87     87       5.412         4.39        5.94  VerbNet
# tiptoe                88     88       5.407         3.89        5.65  VerbNet
# swerve                89     89       5.357            4        8.69  VerbNet
# open                  90      1      11.885         3.21        5.00     CREA
# stay                  91      2      10.800         2.15        4.22     CREA
# break                 92      3      10.774         3.71        5.30     CREA
# drop                  93      4      10.765         4.21        3.26     CREA
# grow                  94      5      10.119         3.03        4.79     CREA
# come                  95      6      12.355         2.72        3.32  VerbNet
# start                 96      7      12.058         2.71        4.37  VerbNet
# change                97      8      11.965         2.89        4.26  VerbNet
# stop                  98      9      11.478         3.68        2.89  VerbNet
# resume                99     10      11.295            4       13.47  VerbNet
# sell                 100     11      11.255         3.35        7.05  VerbNet
# die                  101     12      11.126         3.07        4.53  VerbNet
# happen               102     13      11.099         1.78        5.26  VerbNet
# begin                103     14      11.016         2.56        4.84  VerbNet
# stand                104     15      10.794         4.16        4.39  VerbNet
# exist                105     16      10.782         2.38        8.89  VerbNet
# appear               106     17      10.747         3.13        6.67  VerbNet
# fall                 107     18      10.738         4.04        4.71  VerbNet
# increase             108     19      10.684         2.61        7.42  VerbNet
# fit                  109     20      10.661          2.7        5.74  VerbNet
# remain               110     21      10.110         1.96        8.17  VerbNet
# spread               111     22      10.030         3.68        5.72  VerbNet
# improve              112     23      10.003         1.82        7.47  VerbNet
# roll                 113     24       9.986         4.16        4.47  VerbNet
# occur                114     25       9.972         1.84        9.74  VerbNet
# click                115     26       9.906         4.03        6.94  VerbNet
# fail                 116     27       9.835            3        6.00  VerbNet
# rise                 117     28       9.599         4.04        6.72  VerbNet
# expand               118     29       9.449         3.36        8.42  VerbNet
# burn                 119     30       9.433         4.11        4.72  VerbNet
# wake                 120     31       9.398         3.11        5.63  VerbNet
# vary                 121     32       9.392         1.93        8.94  VerbNet
# spin                 122     33       9.276          3.9        5.00  VerbNet
# slide                123     34       9.211         4.48        4.79  VerbNet
# smell                124     35       9.179          3.7        4.22  VerbNet
# arrive               125     36       9.164         3.22        6.26  VerbNet
# stretch              126     37       9.151         3.62        5.47  VerbNet
# snap                 127     38       9.032          4.1        6.05  VerbNet
# swing                128     39       8.951         4.54        4.16  VerbNet
# gather               129     40       8.889         2.75        6.50  VerbNet
# tear                 130     41       8.797         4.56        4.89  VerbNet
# decrease             131     42       8.770         2.68        8.56  VerbNet
# flip                 132     43       8.699         3.97        5.11  VerbNet
# disappear            133     44       8.660         2.86        5.37  VerbNet
# freeze               134     45       8.645         3.96        4.89  VerbNet
# float                135     46       8.631         4.07        5.39  VerbNet
# collapse             136     47       8.612         3.67        9.17  VerbNet
# shake                137     48       8.574         4.07        5.26  VerbNet
# arise                138     49       8.523         3.17        6.89  VerbNet
# fold                 139     50       8.498         4.13        4.95  VerbNet
# surrender            140     51       8.400         2.63        7.61  VerbNet
# heal                 141     52       8.371         3.03        7.47  VerbNet
# dim                  142     53       8.364         3.31        7.06  VerbNet
# bounce               143     54       8.350         3.86        6.17  VerbNet
# cease                144     55       8.267         2.39        9.26  VerbNet
# boil                 145     56       8.252          4.2        6.60  VerbNet
# integrate            146     57       8.243         2.08       11.47  VerbNet
# bloom                147     58       8.236            4        6.84  VerbNet
# fade                 148     59       8.162         2.48        6.95  VerbNet
# multiply             149     60       8.151         2.79        7.95  VerbNet
# crumble              150     61       8.106         4.04        6.68  VerbNet
# shine                151     62       8.073         3.85        5.79  VerbNet
# explode              152     63       7.994          4.1        7.00  VerbNet
# choke                153     64       7.993         3.97        6.11  VerbNet
# peel                 154     65       7.942         4.61        6.05  VerbNet
# melt                 155     66       7.931         3.96        5.47  VerbNet
# expire               156     67       7.873         2.73        7.68  VerbNet
# smash                157     68       7.853         3.79        4.65  VerbNet
# assemble             158     69       7.839         3.67        8.72  VerbNet
# strengthen           159     70       7.839          2.5        9.70  VerbNet
# ooze                 160     71       7.805            4        7.45  VerbNet
# shatter              161     72       7.776         3.96        9.33  VerbNet
# rot                  162     73       7.774         3.96        7.57  VerbNet
# accelerate           163     74       7.770         3.48       10.74  VerbNet
# unite                164     75       7.745         2.58        7.89  VerbNet
# retire               165     76       7.744         3.11       10.50  VerbNet
# emerge               166     77       7.707         2.27        9.76  VerbNet
# tilt                 167     78       7.667         4.04        8.83  VerbNet
# dissolve             168     79       7.499         3.15        9.20  VerbNet
# shudder              169     81       7.479         3.41       10.16  VerbNet
# spoil                170     80       7.479         2.82        6.30  VerbNet
# lighten              171     82       7.475         2.93        7.95  VerbNet
# disintegrate         172     83       7.439         2.68       11.42  VerbNet
# tighten              173     84       7.407         3.33        6.95  VerbNet
# persist              174     85       7.361         2.59        9.50  VerbNet
# stink                175     86       7.341         3.72        4.30  VerbNet
# sway                 176     87       7.291          3.6        9.58  VerbNet
# glide                177     88       7.264         3.93        7.72  VerbNet
# drown                178     89       7.255         3.93        7.00  VerbNet
# thrive               179     90       7.251         2.21        9.35  VerbNet
# vanish               180     91       7.241         2.77        8.58  VerbNet
# accumulate           181     92       7.238            3       12.30  VerbNet
# squirt               182     93       7.223         3.93        6.53  VerbNet
# loosen               183     94       7.192         3.24        7.22  VerbNet
# diminish             184     95       7.166          2.5       10.95  VerbNet
# curl                 185     96       7.120         4.38        6.39  VerbNet
# rattle               186     97       7.118         4.07        4.50  VerbNet
# weaken               187     98       7.114         2.37        7.95  VerbNet
# straighten           188     99       7.047         3.72        7.63  VerbNet
# stumble              189    100       7.033         3.75        7.94  VerbNet
# ascend               190    101       7.028         2.66       10.67  VerbNet
# perish               191    102       7.028         3.22       10.95  VerbNet
# simmer               192    103       7.022         3.88        9.65  VerbNet
# lessen               193    104       7.016         2.23        8.88  VerbNet
# revive               194    105       7.015         3.13       10.47  VerbNet
# shorten              195    106       7.010         3.11        7.33  VerbNet
# chime                196    107       6.982          4.4        7.83  VerbNet
# abound               197    108       6.971         2.27       11.65  VerbNet
# wiggle               198    109       6.932         3.93        3.95  VerbNet
# wilt                 199    110       6.930          2.9        7.76  VerbNet
# flourish             200    111       6.829          2.1       10.94  VerbNet
# awaken               201    112       6.828         3.45        7.17  VerbNet
# evaporate            202    113       6.779         3.29       10.05  VerbNet
# sag                  203    114       6.767         3.27        6.95  VerbNet
# soar                 204    115       6.762         3.67        9.58  VerbNet
# broaden              205    116       6.729          2.3        9.56  VerbNet
# dribble              206    117       6.683         3.83        6.50  VerbNet
# circulate            207    118       6.676         2.88        9.79  VerbNet
# soften               208    119       6.673         2.57        7.37  VerbNet
# enlarge              209    120       6.661         3.17        8.26  VerbNet
# thump                210    121       6.652         3.77        7.63  VerbNet
# diffuse              211    122       6.599         2.46       11.17  VerbNet
# consolidate          212    123       6.578         2.72       12.56  VerbNet
# harden               213    124       6.526         3.36        8.72  VerbNet
# flatten              214    125       6.483         3.86        7.05  VerbNet
# inflate              215    126       6.412         3.34        8.37  VerbNet
# linger               216    128       6.368         2.41       10.56  VerbNet
# unfold               217    127       6.368         3.55        8.00  VerbNet
# undress              218    129       6.363         3.97        5.28  VerbNet
# converge             219    130       6.356         2.65       12.00  VerbNet
# deteriorate          220    131       6.333            3       11.78  VerbNet
# thaw                 221    132       6.319          3.8        8.11  VerbNet
# wobble               222    133       6.314          3.6        6.56  VerbNet
# disperse             223    134       6.306         2.85       12.11  VerbNet
# tremble              224    135       6.299         3.61        8.89  VerbNet
# vibrate              225    136       6.297            4       10.16  VerbNet
# sharpen              226    137       6.260         3.72        5.61  VerbNet
# twinkle              227    138       6.227         3.21        4.48  VerbNet
# plop                 228    139       6.205         3.48        7.15  VerbNet
# fasten               229    140       6.196         4.14        7.26  VerbNet
# wither               230    141       6.111         2.71        9.33  VerbNet
# gush                 231    142       6.094         3.38       10.00  VerbNet
# intensify            232    143       6.091         2.25       13.00  VerbNet
# sprout               233    144       6.009         4.64        9.11  VerbNet
# worsen               234    145       5.991          1.7        8.33  VerbNet
# erupt                235    146       5.979          3.7        8.26  VerbNet
# ensue                236    147       5.953         2.36       12.11  VerbNet
# erode                237    148       5.908         3.24       10.60  VerbNet
# lengthen             238    149       5.894         3.47        7.84  VerbNet
# stiffen              239    150       5.861         3.82       10.32  VerbNet
# wag                  240    151       5.858         3.88        4.53  VerbNet
# subside              241    152       5.855         2.26       10.44  VerbNet
# dampen               242    153       5.841         3.25       10.21  VerbNet
# flutter              243    154       5.811          3.4        8.35  VerbNet
# defrost              244    155       5.737          3.9        7.80  VerbNet
# throb                245    156       5.733         2.96       10.05  VerbNet
# plummet              246    157       5.720         3.12       12.79  VerbNet
# fizzle               247    158       5.704         3.89        8.56  VerbNet
# wince                248    159       5.690         4.15        8.89  VerbNet
# dangle               249    160       5.624         3.36        6.89  VerbNet
# condense             250    161       5.624         3.26       11.30  VerbNet
# darken               251    162       5.598          3.3        6.85  VerbNet
# thicken              252    163       5.561         3.52        8.62  VerbNet
# decompose            253    165       5.557            3       10.48  VerbNet
# deepen               254    164       5.557          3.2        9.21  VerbNet
# jiggle               255    166       5.509         3.52        7.48  VerbNet
# tarnish              256    167       5.497         3.29       11.39  VerbNet
# vaporize             257    168       5.460         3.22       10.75  VerbNet
# suffocate            258    169       5.455         3.74       10.37  VerbNet
# recur                259    170       5.447          2.5       11.17  VerbNet
# solidify             260    171       5.371         3.16       11.26  VerbNet
# seep                 261    172       5.333         3.08       10.06  VerbNet
# submerge             262    173       5.298         3.39        8.68  VerbNet
# waver                263    174       5.283         2.56       11.26  VerbNet
# slouch               264    175       5.273         3.56        9.11  VerbNet
# germinate            265    176       5.204         2.85       12.80  VerbNet
# writhe               266    177       5.170         2.77       11.00  VerbNet
# use                  267      1      13.426         2.78        4.50     CREA
# see                  268      2      13.272         3.21        3.06     CREA
# want                 269      3      13.138         1.93        4.16     CREA
# find                 270      4      12.845         2.63        5.78     CREA
# help                 271      5      12.723         2.56        3.65     CREA
# take                 272      6      12.709         3.06        4.37     CREA
# read                 273      7      12.576         3.56        4.11     CREA
# give                 274      8      12.350         2.83        4.28     CREA
# put                  275      9      12.320          2.5        3.72     CREA
# write                276     10      11.795         4.22        4.89     CREA
# buy                  277     11      11.778         3.35        5.56     CREA
# hold                 278     12      11.171         3.68        4.67     CREA
# watch                279     13      10.950         4.61        4.33     CREA
# meet                 280     14      10.783            3        4.74     CREA
# build                281     15      10.773         3.71        4.45     CREA
# visit                282     16      10.689         3.92        5.79     CREA
# lose                 283     17      10.554         2.25        5.78     CREA
# carry                284     18      10.509         4.04        5.16     CREA
# fix                  285     19      10.491         2.93        5.00     CREA
# eat                  286     20      10.479         4.44        2.78     CREA
# throw                287     21      10.250         4.04        4.14     CREA
# draw                 288     22      10.188         3.97        4.11     CREA
# feed                 289     23       9.908         4.17        4.17     CREA
# kick                 290     24       9.897         4.33        4.06     CREA
# destroy              291     25       9.766         3.08        6.70     CREA
# survive              292     26       9.511         2.55        7.11     CREA
# steal                293     27       9.330         3.84        6.17     CREA
# deliver              294     28       9.197         3.12        6.63     CREA
# celebrate            295     29       8.063          2.9        6.21     CREA
# mean                 296     30      11.930          2.5        4.00  VerbNet
# include              297     31      11.881         2.48        6.47  VerbNet
# cost                 298     32      11.508          2.5        5.67  VerbNet
# thank                299     33      11.469            3        3.79  VerbNet
# allow                300     34      11.251         2.41        5.32  VerbNet
# release              301     35      11.247         3.24        8.53  VerbNet
# hit                  302     36      11.069         4.11        4.75  VerbNet
# expect               303     37      11.007         1.89        8.70  VerbNet
# welcome              304     38      10.916         2.07        4.06  VerbNet
# suggest              305     39      10.834          1.8        8.67  VerbNet
# mention              306     40      10.819         2.69        8.06  VerbNet
# install              307     41      10.813         3.19       10.14  VerbNet
# doubt                308     42      10.792         1.79        8.79  VerbNet
# require              309     43      10.757         2.07        8.67  VerbNet
# enjoy                310     44      10.752         2.29        5.75  VerbNet
# handle               311     45      10.747         4.57        6.30  VerbNet
# avoid                312     46      10.722         2.41        8.50  VerbNet
# pick                 313     47      10.721         3.82        5.26  VerbNet
# hate                 314     48      10.695         1.97        5.53  VerbNet
# prefer               315     49      10.682         1.62        6.95  VerbNet
# assume               316     50      10.666         1.75        8.21  VerbNet
# recall               317     51      10.562         2.14       11.45  VerbNet
# recommend            318     52      10.533         1.74        9.11  VerbNet
# insert               319     53      10.470         2.57        8.20  VerbNet
# realize              320     54      10.458         2.03        8.23  VerbNet
# imagine              321     55      10.446         1.53        6.06  VerbNet
# suppose              322     56      10.408         1.37        8.21  VerbNet
# discuss              323     57      10.316         3.17        7.89  VerbNet
# protect              324     58      10.287         2.86        6.79  VerbNet
# ignore               325     59      10.232         2.22        6.74  VerbNet
# maintain             326     60      10.216         2.32        9.94  VerbNet
# contain              327     61      10.156         2.74        7.88  VerbNet
# determine            328     62      10.150         2.13        8.89  VerbNet
# express              329     63      10.139         2.21        8.80  VerbNet
# obtain               330     64      10.130            3        9.32  VerbNet
# raise                331     65      10.120          3.8        6.72  VerbNet
# describe             332     66      10.042         2.18        7.67  VerbNet
# represent            333     67       9.979         2.12       10.33  VerbNet
# recognize            334     68       9.953         2.07        8.89  VerbNet
# solve                335     69       9.904          2.1        6.58  VerbNet
# excuse               336     70       9.868         2.29        6.33  VerbNet
# delete               337     71       9.843         3.48        7.78  VerbNet
# affect               338     72       9.836         1.93        9.60  VerbNet
# ensure               339     73       9.782         1.68       11.11  VerbNet
# guarantee            340     74       9.736         1.96       11.05  VerbNet
# compile              341     75       9.733         2.64       10.79  VerbNet
# generate             342     76       9.722         2.23       10.78  VerbNet
# encourage            343     77       9.692         2.61        8.50  VerbNet
# specify              344     78       9.690          2.3        9.21  VerbNet
# identify             345     79       9.676         2.64        8.00  VerbNet
# achieve              346     80       9.651         2.29        8.53  VerbNet
# implement            347     81       9.645         2.33       12.11  VerbNet
# secure               348     82       9.561         2.69        8.42  VerbNet
# establish            349     83       9.509            2       10.63  VerbNet
# deny                 350     84       9.479          2.2        7.80  VerbNet
# launch               351     85       9.474          3.7        7.92  VerbNet
# chuck                352     86       9.437         3.82        6.72  VerbNet
# earn                 353     87       9.392         2.39        7.57  VerbNet
# eliminate            354     88       9.382         2.77       10.21  VerbNet
# hire                 355     89       9.378         3.11        9.00  VerbNet
# rescue               356     90       9.335         3.17        7.17  VerbNet
# discover             357     91       9.315         2.37        7.61  VerbNet
# console              358     92       9.294         3.86       10.68  VerbNet
# restore              359     93       9.275         2.79       10.78  VerbNet
# confirm              360     94       9.271         2.15        9.33  VerbNet
# spare                361     95       9.269         3.48        8.35  VerbNet
# justify              362     96       9.253         1.45       10.40  VerbNet
# modify               363     97       9.248         2.55        9.39  VerbNet
# explore              364     98       9.244          2.9        7.06  VerbNet
# grab                 365     99       9.233         3.52        5.37  VerbNet
# capture              366    100       9.220         3.21        6.39  VerbNet
# announce             367    101       9.212         3.31        9.48  VerbNet
# involve              368    102       9.212         2.43        9.71  VerbNet
# resolve              369    103       9.149         1.96       11.00  VerbNet
# extend               370    104       9.146         2.93        9.89  VerbNet
# verify               371    105       9.146          2.1       10.28  VerbNet
# execute              372    106       9.131         2.76       10.22  VerbNet
# detect               373    107       9.121         2.19        9.53  VerbNet
# imply                374    108       9.102         1.86       10.78  VerbNet
# examine              375    109       9.036         2.86        8.85  VerbNet
# extract              376    110       9.013         3.56       11.05  VerbNet
# accomplish           377    111       8.961         2.33        7.84  VerbNet
# construct            378    112       8.956          2.6        8.72  VerbNet
# reveal               379    113       8.952         2.79        9.47  VerbNet
# restrict             380    114       8.945         2.21        9.47  VerbNet
# disable              381    115       8.939         3.42        9.05  VerbNet
# reject               382    116       8.919          2.4        9.53  VerbNet
# evaluate             383    117       8.889         1.85        9.11  VerbNet
# ruin                 384    118       8.879         2.59        7.16  VerbNet
# insult               385    119       8.868         2.79        8.63  VerbNet
# possess              386    120       8.841          2.6       11.95  VerbNet
# bang                 387    121       8.823         3.77        5.74  VerbNet
# acknowledge          388    122       8.822         2.03        9.11  VerbNet
# assure               389    123       8.813         2.43       12.06  VerbNet
# enhance              390    124       8.809         2.21        9.95  VerbNet
# acquire              391    125       8.784         2.93        9.94  VerbNet
# invite               392    126       8.772            3        6.79  VerbNet
# seal                 393    127       8.767         4.63        5.42  VerbNet
# preserve             394    128       8.749         2.57        9.63  VerbNet
# calm                 395    129       8.748         2.83        6.26  VerbNet
# cite                 396    130       8.724         3.07       13.29  VerbNet
# predict              397    131       8.708            2        8.00  VerbNet
# observe              398    132       8.704         2.63        9.53  VerbNet
# praise               399    133       8.697         2.61        7.95  VerbNet
# wrap                 400    134       8.695         4.11        7.00  VerbNet
# adopt                401    135       8.649         2.36        7.83  VerbNet
# enforce              402    136       8.604          2.4        9.11  VerbNet
# dislike              403    137       8.577          1.7        5.42  VerbNet
# constitute           404    138       8.543         2.13       12.70  VerbNet
# summon               405    139       8.528         2.79       11.33  VerbNet
# exceed               406    140       8.524         1.76        9.95  VerbNet
# regret               407    141       8.515          1.8        9.61  VerbNet
# owe                  408    142       8.473         2.07        8.61  VerbNet
# abandon              409    143       8.232         2.54        8.32  VerbNet
# assert               410    144       8.184         2.03       10.83  VerbNet
# employ               411    145       8.184         2.41       11.41  VerbNet
# activate             412    146       8.157         2.97       11.11  VerbNet
# erase                413    147       8.138         3.79        5.68  VerbNet
# perceive             414    148       8.128         1.72       10.42  VerbNet
# admire               415    149       8.058         2.04        7.42  VerbNet
# isolate              416    150       8.053         2.67       10.60  VerbNet
# sustain              417    152       8.042         2.17       10.39  VerbNet
# initiate             418    151       8.042         2.71       10.17  VerbNet
# forbid               419    153       7.925         1.96        8.47  VerbNet
# discourage           420    154       7.923          1.9        9.32  VerbNet
# suppress             421    155       7.888         2.22       12.94  VerbNet
# harass               422    156       7.882         2.67       10.84  VerbNet
# envy                 423    157       7.846         1.69        8.37  VerbNet
# classify             424    158       7.438         2.41        9.65  VerbNet
# omit                 425    159       7.396         2.14       10.90  VerbNet
# restrain             426    160       6.773         2.76        9.06  VerbNet
# congratulate         427    161       6.741         3.04        9.57  VerbNet
# underline            428    162       6.720         3.95        6.67  VerbNet
# ascertain            429    163       6.709         2.11       12.68  VerbNet
# amaze                430    164       6.688            2        7.50  VerbNet
# excite               431    165       6.669         1.97        6.61  VerbNet
# evade                432    166       6.666         2.67       11.11  VerbNet
# loathe               433    167       6.663         2.04       11.12  VerbNet
# relish               434    168       6.645          3.3        7.83  VerbNet
# enrich               435    169       6.619            2       10.89  VerbNet
# eradicate            436    170       6.612            3       14.75  VerbNet
# embarrass            437    171       6.604         2.14        6.11  VerbNet
# pare                 438    172       6.592            #       11.33  VerbNet
# forfeit              439    173       6.590         2.63       10.40  VerbNet
# frighten             440    174       6.576         3.07        8.83  VerbNet
# crave                441    175       6.542         2.52        9.17  VerbNet
# overwhelm            442    176       6.513         1.42        9.21  VerbNet
# amuse                443    177       6.468         2.57        9.00  VerbNet
# irritate             444    178       6.465         2.43        9.47  VerbNet
# purify               445    179       6.395         2.35       11.00  VerbNet
#
#                   Trans_Intrans      SynClass_Literature  SynFreq  \
# work                       both               unergative      NaN
# go            intransitive only               unergative      NaN
# run                        both               unergative      NaN
# play                       both               unergative      NaN
# live          intransitive only  unergative/unaccusative      NaN
# leave                      both                      NaN      NaN
# speak                      both               unergative      NaN
# listen        intransitive only                      NaN      NaN
# walk                       both               unergative      NaN
# cross                      both                      NaN      NaN
# fly                        both                      NaN      NaN
# sleep                      both               unergative      NaN
# laugh                      both                      NaN      NaN
# negotiate                  both                      NaN      NaN
# shout                      both               unergative      NaN
# act                        both                      NaN      NaN
# jump                       both               unergative      NaN
# dance                      both               unergative      NaN
# lie           intransitive only               unergative      NaN
# cry                        both               unergative      NaN
# sing                       both                      NaN      NaN
# skate         intransitive only               unergative      NaN
# dive          intransitive only                      NaN      NaN
# scream                     both                      NaN      NaN
# proceed       intransitive only                      NaN      NaN
# hesitate      intransitive only                      NaN      NaN
# behave                     both                      NaN      NaN
# swim                       both               unergative      NaN
# hop                        both                      NaN      NaN
# sail                       both                      NaN      NaN
# yell                       both                      NaN      NaN
# howl                       both                      NaN      NaN
# pee           intransitive only                      NaN      NaN
# crawl         intransitive only               unergative      NaN
# breathe                    both               unergative      NaN
# sneak                      both                      NaN      NaN
# wander                     both                      NaN      NaN
# moan                       both                      NaN      NaN
# nod                        both                      NaN      NaN
# blink                      both                      NaN      NaN
# gamble        intransitive only                      NaN      NaN
# shuffle                    both                      NaN      NaN
# fret                       both                      NaN      NaN
# endure                     both                      NaN      NaN
# whisper                    both                      NaN      NaN
# shrug                      both                      NaN      NaN
# prosper                    both                      NaN      NaN
# prevail       intransitive only                      NaN      NaN
# depart        intransitive only             unaccusative      NaN
# giggle                     both                      NaN      NaN
# yawn          intransitive only                      NaN      NaN
# vomit                      both               unergative      NaN
# puke                       both                      NaN      NaN
# hiss                       both                      NaN      NaN
# cringe        intransitive only                      NaN      NaN
# inhale                     both                      NaN      NaN
# weep                       both               unergative      NaN
# meditate                   both               unergative      NaN
# hustle        intransitive only                      NaN      NaN
# stoop                      both                      NaN      NaN
# kneel         intransitive only               unergative      NaN
# strut         intransitive only                      NaN      NaN
# squirm        intransitive only                      NaN      NaN
# shiver                     both                      NaN      NaN
# bathe                      both                      NaN      NaN
# jog                        both               unergative      NaN
# retaliate     intransitive only                      NaN      NaN
# squeal        intransitive only                      NaN      NaN
# mumble                     both               unergative      NaN
# dine                       both                      NaN      NaN
# sneeze        intransitive only               unergative      NaN
# squeak        intransitive only                      NaN      NaN
# burp                       both               unergative      NaN
# wail                       both                      NaN      NaN
# urinate       intransitive only               unergative      NaN
# oink          intransitive only               unergative      NaN
# flinch        intransitive only                      NaN      NaN
# persevere     intransitive only                      NaN      NaN
# stutter       intransitive only                      NaN      NaN
# bellow                     both               unergative      NaN
# snooze        intransitive only               unergative      NaN
# belch                      both               unergative      NaN
# doze          intransitive only                      NaN      NaN
# squint        intransitive only                      NaN      NaN
# wriggle                    both                      NaN      NaN
# scoot         intransitive only                      NaN      NaN
# snore         intransitive only                      NaN      NaN
# tiptoe        intransitive only                      NaN      NaN
# swerve                     both                      NaN      NaN
# open                       both             unaccusative      NaN
# stay                       both             unaccusative      NaN
# break                      both             unaccusative      NaN
# drop                       both             unaccusative      NaN
# grow                       both             unaccusative      NaN
# come          intransitive only             unaccusative      NaN
# start                      both             unaccusative      NaN
# change                     both                      NaN      NaN
# stop                       both             unaccusative      NaN
# resume                     both                      NaN      NaN
# sell                       both                      NaN      NaN
# die                        both             unaccusative      NaN
# happen        intransitive only             unaccusative      NaN
# begin                      both             unaccusative      NaN
# stand                      both                      NaN      NaN
# exist         intransitive only             unaccusative      NaN
# appear        intransitive only             unaccusative      NaN
# fall          intransitive only             unaccusative      NaN
# increase                   both             unaccusative      NaN
# fit                        both                      NaN      NaN
# remain        intransitive only             unaccusative      NaN
# spread                     both                      NaN      NaN
# improve                    both                      NaN      NaN
# roll                       both             unaccusative      NaN
# occur         intransitive only             unaccusative      NaN
# click                      both                      NaN      NaN
# fail                       both             unaccusative      NaN
# rise          intransitive only             unaccusative      NaN
# expand                     both                      NaN      NaN
# burn                       both             unaccusative      NaN
# wake                       both                      NaN      NaN
# vary                       both                      NaN      NaN
# spin                       both                      NaN      NaN
# slide                      both             unaccusative      NaN
# smell                      both             unaccusative      NaN
# arrive        intransitive only             unaccusative      NaN
# stretch                    both                      NaN      NaN
# snap                       both             unaccusative      NaN
# swing                      both                      NaN      NaN
# gather                     both                      NaN      NaN
# tear                       both                      NaN      NaN
# decrease                   both             unaccusative      NaN
# flip                       both                      NaN      NaN
# disappear     intransitive only             unaccusative      NaN
# freeze                     both             unaccusative      NaN
# float                      both             unaccusative      NaN
# collapse                   both             unaccusative      NaN
# shake                      both             unaccusative      NaN
# arise         intransitive only             unaccusative      NaN
# fold                       both                      NaN      NaN
# surrender                  both             unaccusative      NaN
# heal                       both                      NaN      NaN
# dim                        both             unaccusative      NaN
# bounce                     both                      NaN      NaN
# cease                      both             unaccusative      NaN
# boil                       both             unaccusative      NaN
# integrate                  both                      NaN      NaN
# bloom         intransitive only             unaccusative      NaN
# fade                       both                      NaN      NaN
# multiply                   both                      NaN      NaN
# crumble                    both             unaccusative      NaN
# shine         intransitive only             unaccusative      NaN
# explode                    both             unaccusative      NaN
# choke                      both             unaccusative      NaN
# peel                       both                      NaN      NaN
# melt                       both             unaccusative      NaN
# expire        intransitive only             unaccusative      NaN
# smash                      both                      NaN      NaN
# assemble                   both                      NaN      NaN
# strengthen                 both                      NaN      NaN
# ooze            transitive only             unaccusative      NaN
# shatter                    both             unaccusative      NaN
# rot                        both             unaccusative      NaN
# accelerate                 both                      NaN      NaN
# unite                      both                      NaN      NaN
# retire                     both                      NaN      NaN
# emerge        intransitive only             unaccusative      NaN
# tilt                       both                      NaN      NaN
# dissolve                   both             unaccusative      NaN
# shudder       intransitive only                      NaN      NaN
# spoil                      both                      NaN      NaN
# lighten                    both                      NaN      NaN
# ...
# expire                      0.926    692.02   111.59
# smash                       1.000    730.45   216.04
# assemble                    1.000    530.54   222.24
# strengthen                  1.000    146.50    35.07
# ooze                        1.000     53.15     2.44
# shatter                     1.000   1393.11   203.69
# rot                         1.000   3173.44     8.21
# accelerate                  0.964    227.94    79.11
# unite                       0.963   1192.62   470.29
# retire                      1.000   1402.38   132.86
# emerge                      1.000    318.67   111.12
# tilt                        1.000   1856.79    53.19
# dissolve                    1.000    387.94    91.90
# shudder                     0.963    895.82    29.45
# spoil                       1.000    505.87    72.03
# lighten                     0.962    777.31    99.03
# disintegrate                0.962     63.77    27.36
# tighten                     1.000    736.19    95.75
# persist                     1.000   1100.31   235.92
# stink                       1.000   2557.42   656.42
# sway                        1.000    667.37   358.98
# glide                       1.000    297.84    59.10
# drown                       1.000   1019.51   306.69
# thrive                      0.964    833.41   129.47
# vanish                      1.000    530.52    88.72
# accumulate                  1.000    145.33    65.58
# squirt                      1.000    208.59    36.16
# loosen                      1.000   1023.26   218.49
# diminish                    0.962    450.34    85.47
# curl                        1.000    416.39    20.70
# rattle                      1.000   2168.04   881.18
# weaken                      1.000   1174.71   101.94
# straighten                  1.000    162.26    23.73
# stumble                     1.000    521.39   122.31
# ascend                      1.000    831.22   125.75
# perish                      1.000    989.69   238.40
# simmer                      0.963   1896.65   207.96
# lessen                      1.000    874.61   136.91
# revive                      1.000    890.89    75.72
# shorten                     1.000    953.37   156.38
# chime                       1.000   2067.43   255.72
# abound                      1.000   1261.35   390.96
# wiggle                      0.964   1186.26    64.09
# wilt                        0.962   4512.55  1110.97
# flourish                    1.000    400.96    74.72
# awaken                      1.000    721.80    68.77
# evaporate                   1.000    291.61   103.12
# sag                         1.000    764.72     1.84
# soar                        1.000   1598.69    24.15
# broaden                     0.962    890.33   101.48
# dribble                     1.000    594.23    89.77
# circulate                   0.963    214.35    74.28
# soften                      1.000   1134.48    70.99
# enlarge                     1.000    368.08     6.48
# thump                       0.964   2720.53    33.49
# diffuse                     1.000    641.02   240.58
# consolidate                 1.000    271.44   118.08
# harden                      1.000   1108.14   285.09
# flatten                     1.000    902.01    98.14
# inflate                     1.000    370.52    72.39
# linger                      0.962   2258.83   328.13
# unfold                      1.000    600.42    10.83
# undress                     1.000    481.08   177.63
# converge                    1.000    600.69   161.19
# deteriorate                 0.917    278.46    99.10
# thaw                        0.964  14195.10  6557.35
# wobble                      0.964   1005.64    90.53
# disperse                    0.958    548.00   136.42
# tremble                     1.000    552.45    87.98
# vibrate                     0.963    353.64    97.07
# sharpen                     0.964    731.39    77.76
# twinkle                     1.000    298.68    17.11
# plop                        0.963    355.13    17.88
# fasten                      0.962   1505.21   300.83
# wither                      1.000   2718.91  1075.75
# gush                        1.000   1050.76    66.78
# intensify                   1.000    586.85   217.56
# sprout                      0.964    487.80    66.51
# worsen                      0.920    932.69   112.62
# erupt                       1.000    184.41     1.19
# ensue                       0.962    162.91    31.02
# erode                       1.000    595.85     2.14
# lengthen                    0.964    425.43    67.38
# stiffen                     0.964    505.25    21.85
# wag                         0.963   6327.30     1.19
# subside                     1.000    599.23   187.87
# dampen                      1.000    693.44    82.96
# flutter                     1.000   1161.16   173.91
# defrost                     1.000    546.07    39.65
# throb                       1.000   2885.01   261.97
# plummet                     1.000    219.10    20.48
# fizzle                      0.963    941.63     8.46
# wince                       0.962   1121.44   406.69
# dangle                      1.000   1356.54   165.33
# condense                    0.926    881.83   300.83
# darken                      1.000   1160.75   213.30
# thicken                     1.000    760.23   134.83
# decompose                   0.929    315.14    47.25
# deepen                      1.000    797.18    82.68
# jiggle                      1.000   1032.24    64.68
# tarnish                     1.000    981.15   274.55
# vaporize                    1.000    372.84    65.27
# suffocate                   0.929    319.38    74.61
# recur                       0.828    152.35    16.48
# solidify                    1.000    411.50    86.14
# seep                        1.000   2475.71   609.50
# submerge                    1.000    353.62    20.22
# waver                       1.000   2835.71   471.10
# slouch                      1.000    987.01    60.34
# germinate                   0.963    413.82    98.79
# writhe                      0.792    422.60    39.95
# use                         1.000    467.49   467.49
# see                         1.000   1426.78  1061.35
# want                        1.000   2200.56   607.27
# find                        1.000   2150.47   997.75
# help                        1.000   1899.11   536.54
# take                        1.000   2289.78  1257.97
# read                        1.000   2082.90   841.58
# give                        1.000   2764.27   724.53
# put                         0.889   4662.86   659.12
# write                       1.000   1286.52   437.95
# buy                         0.964   2793.96   121.13
# hold                        1.000   1335.93   642.55
# watch                       1.000   1819.15   403.74
# meet                        1.000   2255.69   261.20
# build                       1.000   2555.75   321.38
# visit                       1.000    338.50   104.87
# lose                        0.880   1884.49   318.43
# carry                       1.000   1114.60   260.18
# fix                         1.000    173.75    18.92
# eat                         1.000    396.25   139.21
# throw                       1.000   2961.94   280.03
# draw                        1.000    199.34    71.78
# feed                        0.963   2797.05   614.98
# kick                        1.000   1043.44   102.27
# destroy                     1.000    742.18   190.65
# survive                     1.000    689.35   154.29
# steal                       1.000   1783.16   125.23
# deliver                     0.963   1259.73   227.30
# celebrate                   1.000    323.61   116.51
# mean                        1.000   2272.21   387.98
# include                     1.000    347.25    73.49
# cost                        0.962   3260.82   895.33
# thank                       1.000   3472.52   100.11
# allow                       0.964    386.97   139.77
# release                     1.000   1031.44    89.32
# hit                         1.000   4577.52    91.26
# expect                      1.000    503.36   260.03
# welcome                     1.000    354.05    68.06
# suggest                     1.000    704.91   181.74
# mention                     1.000   1322.37   394.35
# install                     1.000    642.27   144.66
# doubt                       1.000   2321.10   154.44
# require                     1.000    652.69    89.44
# enjoy                       1.000    164.74    66.16
# handle                      1.000   1557.33   158.10
# avoid                       1.000    137.31    77.74
# pick                        1.000    910.14   124.19
# hate                        1.000   2603.28   320.31
# prefer                      1.000   1705.11    85.76
# assume                      1.000    414.36    91.96
# recall                      1.000    964.77   169.06
# recommend                   1.000    586.83   134.60
# insert                      1.000    756.19   113.10
# realize                     1.000   1251.19   299.06
# imagine                     0.926   1807.76   200.55
# suppose                     1.000    790.30   298.25
# discuss                     1.000    620.86   108.48
# protect                     1.000   1298.90   400.16
# ignore                      1.000    846.86   276.48
# maintain                    1.000    390.16   120.42
# contain                     0.963   1218.12   555.33
# determine                   1.000    960.69   133.91
# express                     0.964    620.67   247.23
# obtain                      1.000    322.47    95.14
# raise                       1.000   1427.37   102.70
# describe                    0.960    446.60    65.49
# represent                   1.000    851.40   282.78
# recognize                   0.966    490.22   105.19
# solve                       1.000    532.18    53.17
# excuse                      1.000    426.08    82.86
# delete                      1.000    510.80     9.18
# affect                      1.000    545.30   274.60
# ensure                      0.926   1021.13   214.90
# guarantee                   1.000    440.78    89.54
# compile                     1.000    934.75   201.56
# generate                    1.000    531.64   160.66
# encourage                   1.000    324.57    90.89
# specify                     1.000    327.02   197.14
# identify                    0.926    514.88   102.98
# achieve                     1.000    419.07   156.11
# implement                   0.960    736.97   382.04
# secure                      1.000   1339.17   322.90
# establish                   1.000    216.07    66.56
# deny                        1.000   1247.58    26.44
# launch                      1.000    579.20    81.18
# chuck                       0.958    619.94    29.29
# earn                        1.000   1231.22    65.23
# eliminate                   1.000    323.05    97.00
# hire                        1.000   3032.60   117.47
# rescue                      1.000    697.11    84.64
# discover                    1.000    753.21   204.82
# console                     0.926    847.23   176.19
# restore                     1.000   1175.32   249.62
# confirm                     1.000    679.59   178.54
# spare                       1.000   2173.22   211.66
# justify                     1.000    810.92   108.80
# modify                      1.000    495.05    86.07
# explore                     1.000    601.62    98.98
# grab                        1.000    225.87    41.02
# capture                     1.000    664.74   309.06
# announce                    0.963    444.70   166.69
# involve                     1.000    297.95    48.59
# resolve                     1.000    680.53    77.58
# extend                      1.000    854.51   174.55
# verify                      1.000    511.44    85.54
# execute                     0.889    328.77    10.32
# detect                      1.000    753.33   165.61
# imply                       1.000    343.70    47.53
# examine                     1.000   1952.78   246.12
# extract                     1.000    445.97    75.15
# accomplish                  1.000    175.17    51.83
# construct                   0.962    536.28   178.88
# reveal                      1.000    989.38    84.79
# restrict                    0.962    883.30   152.87
# disable                     1.000    474.58   149.86
# reject                      1.000    772.97   173.32
# evaluate                    1.000    315.75    78.65
# ruin                        1.000    347.54    12.76
# insult                      1.000    642.95   171.37
# possess                     0.815    701.97   162.34
# bang                        1.000   2049.35   158.99
# acknowledge                 1.000     34.37    13.25
# assure                      1.000    831.61   249.27
# enhance                     1.000    492.22   160.73
# acquire                     0.964    314.37    66.64
# invite                      1.000    583.67    31.59
# seal                        0.960   1936.01   330.33
# preserve                    0.964    747.09   184.74
# calm                        1.000   1336.51   171.58
# cite                        1.000   2835.09   152.66
# predict                     1.000    905.64   126.27
# observe                     1.000    463.09    54.42
# praise                      0.929    633.65    55.15
# wrap                        1.000    141.83    22.16
# adopt                       1.000    170.98    21.83
# enforce                     1.000    344.25    30.09
# dislike                     0.963    634.71    76.58
# constitute                  1.000    538.05   203.61
# summon                      1.000    745.40   170.85
# exceed                      1.000   2162.22   155.74
# regret                      1.000    998.69   122.78
# owe                         0.963    479.78    12.61
# abandon                     1.000    440.72    24.14
# assert                      0.966    577.60    78.46
# employ                      1.000    122.10    28.18
# activate                    1.000    447.43   144.13
# erase                       1.000   1633.40    73.57
# perceive                    0.960    255.09    81.85
# admire                      1.000    701.68    70.72
# isolate                     1.000    266.51    68.83
# sustain                     1.000    948.35   355.21
# initiate                    0.963    550.71    87.08
# forbid                      0.929    513.21   156.23
# discourage                  1.000    237.19   115.74
# suppress                    0.962    634.38   266.63
# harass                      1.000    725.95    65.25
# envy                        1.000     43.91    20.17
# classify                    1.000    244.33    37.35
# omit                        0.960    126.36     3.45
# restrain                    1.000    765.53   169.00
# congratulate                1.000    181.32    88.30
# underline                   1.000    808.25    89.34
# ascertain                   0.926    381.99    82.64
# amaze                       1.000    273.55     6.07
# excite                      1.000    380.27    53.54
# evade                       1.000    392.03    76.11
# loathe                      0.929    496.18    17.94
# relish                      1.000    894.63   118.66
# enrich                      1.000    841.68    37.38
# eradicate                   1.000    323.75   107.98
# embarrass                   1.000    169.98    10.22
# pare                        0.852   3844.90   434.21
# forfeit                     0.964    463.99   111.67
# frighten                    1.000    601.73   132.89
# crave                       1.000    824.27   169.95
# overwhelm                   1.000    186.61    51.76
# amuse                       0.960   1358.49   253.93
# irritate                    0.821    416.17   112.23
# purify                      1.000    721.22   144.67

# %%
verb_w_2syncat = raw_upd[raw_upd['most_frequent_pb'].notnull() & raw_upd['most_frequent_g'].notnull()]

# %%
verb_w_1syncat = raw_upd[raw_upd['most_frequent_pb'].notnull() | raw_upd['most_frequent_g'].notnull()]

# %%
verb_wo_syncat = raw_upd[raw_upd['most_frequent_pb'].isnull() & raw_upd['most_frequent_g'].isnull()]

# %%
verb_w_2syncat.shape #number of verbs that appear both in PB and G
# Out:
# (86, 55)

# %%
verb_wo_syncat.shape #number of verbs that do not appear in either
# Out:
# (55, 55)

# %%
verb_w_1syncat.shape #number of verbs that appear in PB or G
# Out:
# (390, 55)

# %%
verb_w_1syncat.shape[0] + verb_w_2syncat.shape[0] + verb_wo_syncat.shape[0]
# Out:
# 531

# %%
raw_upd.shape
# Out:
# (445, 55)
