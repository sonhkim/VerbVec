# %%
import csv
import pandas as pd
from scipy import stats

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
def rearrange_col(dataframe, col_to_move, reference_col, right=True):
    col_list = dataframe.columns.values.tolist()
    col_list2 = [x for x in col_list if x != col_to_move]
    reference_idx = col_list2.index(reference_col)
    if right==True:
        col_list3 = []
        for y in col_list2:
            col_list3.append(y)
            if y == reference_col:
                col_list3.append(col_to_move)
        return dataframe[col_list3]
    else:
        col_list3 = []
        for y in col_list2:
            col_list3.append(y)
            if y == reference_col:
                col_list3.insert(-2, col_to_move)
        return  dataframe[col_list3]

# %%
def get_key(dic, val): 
    for key, value in dic.items(): 
         if val == value: 
             return key 
  
    return "not found"

# %%
raw = pd.read_excel('/Users/songheekim/Google Drive/Primary/Projects/VerbVector/verblist_v2.11_wb.xlsx')

# %%
raw = raw.set_index('Lemma')

# %%
#raw['GrandIndex'].tolist()

# %%
pd.to_numeric([raw["GrandIndex"], raw["unerg_pb"], raw["unacc_pb"], raw["tr_pb"], raw["totalN_pb"], raw["intr_g"], raw["tr_g"], raw["totalN_g"]], errors='ignore')

# %%
raw_dic = raw.to_dict(orient='index')

# %%
# l = [15, 59, 1000, -1, 'ab']
# l2 = [i for i in l if isinstance(i, int)]
# print(l2)

# %%
raw_dic['work']

# %%
### get the category from
for verb, row in raw_dic.items():
    #print(verb)
    row['most_frequent_pb'] = ''
    row['most_frequent_g'] = ''
    
    keys_to_extract1 = ["unerg_pb", "unacc_pb", "tr_pb"]
    sub_dic1 = {key: row[key] for key in keys_to_extract1 if pd.notna(row[key])}
    #tup1 = list(sub_dic1.items())
    #print (tup1)
    if len(sub_dic1) > 0: 
        max1 = max(sub_dic1.values())
        pb_cat = get_key(sub_dic1, max1)
        row['most_frequent_pb'] = pb_cat[0:-3]
    
    keys_to_extract2 = ["intr_g", "tr_g"]
    sub_dic2 = {key: row[key] for key in keys_to_extract2 if pd.notna(row[key])}
    if len(sub_dic2) > 0: 
        max2 = max(sub_dic2.values())
        g_cat = get_key(sub_dic2, max2)
        row['most_frequent_g'] = g_cat[0:-2]
    
    #print (l)
    #l2 = [i for i in l if isinstance(i, float)]
#     l2 = [number for number in l if pd.notna(number)]
#     if len(l2) > 0: 
#         mx = max(l2)
#         pb_cat = get_key(mx)
#         row['most_frequent_pb'] = pb_cat[0:-3]
#     m = [row['intr_g'], row['tr_g']]
#     m2 = [number for number in m if pd.notna(number)]
#     if len(m2) > 0: 
#         mxx = max(m2)
#         g_cat = get_key(mxx)
#         row['most_frequent_g'] = g_cat[0:-2]

# %%
### fill in "SynClassFinal" based on most_frequent_pb, most_frequent_g
for verb, row in raw_dic.items():
    #print (verb)
    l1 = [row['most_frequent_pb'], row['most_frequent_g']]
    l2 = [i for i in l1 if len(i)>0]
    #print (len(l2), l2)
    if len(l2)==0:
        row['SynClassCorpus']='none'
    elif len(l2)==1:
        row['SynClassCorpus']=l2[0]
    elif len(l2)==2:
        if l2[0]==l2[1]:
            row['SynClassCorpus']=l2[0]
        else:
            if l2[0]=='tr' or l2[1]=='tr':
                row['SynClassCorpus']='conflict'
            else:
                row['SynClassCorpus']=l2[0]
                
                
    else:
        print (verb, " needs check")
#     print (row['SynClassCorpus'])
#     print ('============')

# %%
raw_upd = pd.DataFrame.from_dict(raw_dic, orient='index')

# %%
# raw_upd.head()

# %%
#raw_upd

# %%
raw_upd = rearrange_col(raw_upd, 'most_frequent_g', 'totalN_g', right=True)
raw_upd = rearrange_col(raw_upd, 'most_frequent_pb', 'totalN_pb', right=True)

# %%
raw_upd2 = raw_upd.sort_values(by=['SynClassCorpus', 'GrandIndex'])

# %%
raw_upd2

# %%
raw_upd2.to_excel('/Users/songheekim/Google Drive/Primary/Projects/VerbVector/verblist_v2.12.xlsx')

# %%
unerg = raw_upd2.loc[raw_upd2['SynClassCorpus']=='unerg']
unacc = raw_upd2.loc[raw_upd2['SynClassCorpus']=='unacc']
trans = raw_upd2.loc[raw_upd2['SynClassCorpus']=='tr']
conflict = raw_upd2.loc[raw_upd2['SynClassCorpus']=='conflict']
nodata = raw_upd2.loc[raw_upd2['SynClassCorpus']=='none']

# %%
raw_upd2.head()

# %%
###########PART 2###############

# %%
raw2 = pd.read_excel('/Users/songheekim/Google Drive/Primary/Projects/VerbVector/verblist_v2.12_wb.xlsx')

# %%
###google syntactic N-gram
ngram_raw = pd.read_csv('/Users/songheekim/Documents/verb_transitivity/verb_transitivity.tsv', delimiter='\t', index_col='verb')

# %%
ngram_raw.head()
# Out:
#                 intrans     trans  xtrans  ditrans      total  \
# verb
# expect         744348.0  197175.0    67.0    463.0   942053.0
# expected      2342329.0   66846.0    23.0    764.0  2409962.0
# expecting      158713.0   84397.0    27.0    575.0   243712.0
# expectorate      2075.0     273.0     0.0      0.0     2348.0
# expectorated     4035.0     115.0     0.0      0.0     4150.0
#
#               percent_intrans  percent_trans  percent_ditrans
# verb
# expect               0.790134       0.209304         0.000491
# expected             0.971936       0.027737         0.000317
# expecting            0.651232       0.346298         0.002359
# expectorate          0.883731       0.116269         0.000000
# expectorated         0.972289       0.027711         0.000000

# %%
ngram_raw.iloc[:,0]

# %%
ngram_raw.shape

# %%
ngram_trimmed = ngram_raw[~ngram_raw.index.duplicated(keep='first')]

# %%
ngram_trimmed.shape

# %%
#ngram_trimmed.loc['expect']

# %%
# keylist = ngram_raw.index.tolist()
# [(i, keylist.count(i)) for i in keylist if keylist.count(i)!=1]

# %%
ngram_dict = ngram_trimmed.to_dict(orient='index')

# %%
ngram_dict
# Out:
# {'expect': {'intrans': 744348.0,
#   'trans': 197175.0,
#   'xtrans': 67.0,
#   'ditrans': 463.0,
#   'total': 942053.0,
#   'percent_intrans': 0.7901338884330287,
#   'percent_trans': 0.2093035105243548,
#   'percent_ditrans': 0.0004914797787385635},
#  'expected': {'intrans': 2342329.0,
#   'trans': 66846.0,
#   'xtrans': 23.0,
#   'ditrans': 764.0,
#   'total': 2409962.0,
#   'percent_intrans': 0.9719360720210526,
#   'percent_trans': 0.027737366813252656,
#   'percent_ditrans': 0.000317017446748123},
#  'expecting': {'intrans': 158713.0,
#   'trans': 84397.0,
#   'xtrans': 27.0,
#   'ditrans': 575.0,
#   'total': 243712.0,
#   'percent_intrans': 0.6512317817752101,
#   'percent_trans': 0.3462980895483193,
#   'percent_ditrans': 0.002359342174369748},
#  'expectorate': {'intrans': 2075.0,
#   'trans': 273.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2348.0,
#   'percent_intrans': 0.8837308347529813,
#   'percent_trans': 0.11626916524701872,
#   'percent_ditrans': 0.0},
#  'expectorated': {'intrans': 4035.0,
#   'trans': 115.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 4150.0,
#   'percent_intrans': 0.972289156626506,
#   'percent_trans': 0.02771084337349397,
#   'percent_ditrans': 0.0},
#  'expects': {'intrans': 62918.0,
#   'trans': 9567.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 72485.0,
#   'percent_intrans': 0.86801407187694,
#   'percent_trans': 0.13198592812305995,
#   'percent_ditrans': 0.0},
#  'expedient': {'intrans': 3327.0,
#   'trans': 10.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3337.0,
#   'percent_intrans': 0.9970032963739888,
#   'percent_trans': 0.002996703626011388,
#   'percent_ditrans': 0.0},
#  'expedite': {'intrans': 2724.0,
#   'trans': 17700.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 20424.0,
#   'percent_intrans': 0.13337250293772032,
#   'percent_trans': 0.8666274970622797,
#   'percent_ditrans': 0.0},
#  'expedited': {'intrans': 3797.0,
#   'trans': 204.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 4001.0,
#   'percent_intrans': 0.9490127468132968,
#   'percent_trans': 0.050987253186703316,
#   'percent_ditrans': 0.0},
#  'expediting': {'intrans': 2515.0,
#   'trans': 4634.0,
#   'xtrans': 0.0,
#   'ditrans': 11.0,
#   'total': 7160.0,
#   'percent_intrans': 0.3512569832402235,
#   'percent_trans': 0.6472067039106145,
#   'percent_ditrans': 0.0015363128491620109},
#  'expel': {'intrans': 11064.0,
#   'trans': 60975.0,
#   'xtrans': 0.0,
#   'ditrans': 164.0,
#   'total': 72203.0,
#   'percent_intrans': 0.1532346301400219,
#   'percent_trans': 0.8444939960943451,
#   'percent_ditrans': 0.0022713737656330072},
#  'expelled': {'intrans': 97042.0,
#   'trans': 16219.0,
#   'xtrans': 0.0,
#   'ditrans': 184.0,
#   'total': 113445.0,
#   'percent_intrans': 0.8554101106262947,
#   'percent_trans': 0.14296795804134166,
#   'percent_ditrans': 0.0016219313323637006},
#  'expelling': {'intrans': 5587.0,
#   'trans': 21191.0,
#   'xtrans': 0.0,
#   'ditrans': 25.0,
#   'total': 26803.0,
#   'percent_intrans': 0.208446815654964,
#   'percent_trans': 0.7906204529343729,
#   'percent_ditrans': 0.0009327314106629855},
#  'expels': {'intrans': 592.0,
#   'trans': 2762.0,
#   'xtrans': 0.0,
#   'ditrans': 11.0,
#   'total': 3365.0,
#   'percent_intrans': 0.1759286775631501,
#   'percent_trans': 0.8208023774145616,
#   'percent_ditrans': 0.003268945022288261},
#  'expend': {'intrans': 8444.0,
#   'trans': 15345.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 23789.0,
#   'percent_intrans': 0.35495397032241793,
#   'percent_trans': 0.6450460296775821,
#   'percent_ditrans': 0.0},
#  'expended': {'intrans': 122169.0,
#   'trans': 6008.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 128177.0,
#   'percent_intrans': 0.9531273161331596,
#   'percent_trans': 0.04687268386684038,
#   'percent_ditrans': 0.0},
#  'expending': {'intrans': 2467.0,
#   'trans': 8609.0,
#   'xtrans': 0.0,
#   'ditrans': 12.0,
#   'total': 11088.0,
#   'percent_intrans': 0.22249278499278502,
#   'percent_trans': 0.7764249639249641,
#   'percent_ditrans': 0.0010822510822510825},
#  'expends': {'intrans': 1290.0,
#   'trans': 1265.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2555.0,
#   'percent_intrans': 0.5048923679060665,
#   'percent_trans': 0.4951076320939334,
#   'percent_ditrans': 0.0},
#  'experience': {'intrans': 110070.0,
#   'trans': 93266.0,
#   'xtrans': 29.0,
#   'ditrans': 123.0,
#   'total': 203488.0,
#   'percent_intrans': 0.5409164176757352,
#   'percent_trans': 0.4583366095298002,
#   'percent_ditrans': 0.0006044582481522253},
#  'experienced': {'intrans': 515257.0,
#   'trans': 64770.0,
#   'xtrans': 15.0,
#   'ditrans': 149.0,
#   'total': 580191.0,
#   'percent_intrans': 0.888081683445624,
#   'percent_trans': 0.11163565101837154,
#   'percent_ditrans': 0.0002568119808821578},
#  'experiences': {'intrans': 20738.0,
#   'trans': 8763.0,
#   'xtrans': 46.0,
#   'ditrans': 0.0,
#   'total': 29547.0,
#   'percent_intrans': 0.701864825532203,
#   'percent_trans': 0.2965783328256676,
#   'percent_ditrans': 0.0},
#  'experiencing': {'intrans': 34823.0,
#   'trans': 59272.0,
#   'xtrans': 0.0,
#   'ditrans': 74.0,
#   'total': 94169.0,
#   'percent_intrans': 0.36979260690885535,
#   'percent_trans': 0.6294215718548567,
#   'percent_ditrans': 0.0007858212362879504},
#  'experiment': {'intrans': 8780.0,
#   'trans': 1311.0,
#   'xtrans': 12.0,
#   'ditrans': 21.0,
#   'total': 10124.0,
#   'percent_intrans': 0.8672461477676807,
#   'percent_trans': 0.12949427103911498,
#   'percent_ditrans': 0.0020742789411299888},
#  'experimental': {'intrans': 1879.0,
#   'trans': 229.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2108.0,
#   'percent_intrans': 0.8913662239089184,
#   'percent_trans': 0.1086337760910816,
#   'percent_ditrans': 0.0},
#  'experimented': {'intrans': 12646.0,
#   'trans': 170.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 12816.0,
#   'percent_intrans': 0.9867353308364544,
#   'percent_trans': 0.01326466916354557,
#   'percent_ditrans': 0.0},
#  'experimenting': {'intrans': 36937.0,
#   'trans': 1142.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 38079.0,
#   'percent_intrans': 0.9700097166417184,
#   'percent_trans': 0.02999028335828147,
#   'percent_ditrans': 0.0},
#  'expiate': {'intrans': 3631.0,
#   'trans': 12265.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 15896.0,
#   'percent_intrans': 0.22842224458983396,
#   'percent_trans': 0.7715777554101659,
#   'percent_ditrans': 0.0},
#  'expiated': {'intrans': 4788.0,
#   'trans': 1674.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 6462.0,
#   'percent_intrans': 0.7409470752089137,
#   'percent_trans': 0.2590529247910863,
#   'percent_ditrans': 0.0},
#  'expiating': {'intrans': 966.0,
#   'trans': 2075.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3041.0,
#   'percent_intrans': 0.3176586649128576,
#   'percent_trans': 0.6823413350871423,
#   'percent_ditrans': 0.0},
#  'expire': {'intrans': 49211.0,
#   'trans': 1300.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 50511.0,
#   'percent_intrans': 0.9742630318148522,
#   'percent_trans': 0.025736968185147792,
#   'percent_ditrans': 0.0},
#  'expired': {'intrans': 164353.0,
#   'trans': 1240.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 165593.0,
#   'percent_intrans': 0.9925117607628342,
#   'percent_trans': 0.0074882392371658215,
#   'percent_ditrans': 0.0},
#  'expires': {'intrans': 17182.0,
#   'trans': 1579.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 18761.0,
#   'percent_intrans': 0.9158360428548584,
#   'percent_trans': 0.08416395714514152,
#   'percent_ditrans': 0.0},
#  'expiring': {'intrans': 65884.0,
#   'trans': 3076.0,
#   'xtrans': 0.0,
#   'ditrans': 15.0,
#   'total': 68975.0,
#   'percent_intrans': 0.9551866618339978,
#   'percent_trans': 0.04459586806814063,
#   'percent_ditrans': 0.00021747009786154405},
#  'explain': {'intrans': 630884.0,
#   'trans': 808209.0,
#   'xtrans': 0.0,
#   'ditrans': 481.0,
#   'total': 1439574.0,
#   'percent_intrans': 0.4382435359349363,
#   'percent_trans': 0.5614223374414931,
#   'percent_ditrans': 0.00033412662357058413},
#  'explained': {'intrans': 713241.0,
#   'trans': 58050.0,
#   'xtrans': 0.0,
#   'ditrans': 64.0,
#   'total': 771355.0,
#   'percent_intrans': 0.9246598518192012,
#   'percent_trans': 0.0752571773048726,
#   'percent_ditrans': 8.297087592613001e-05},
#  'explaining': {'intrans': 130678.0,
#   'trans': 235421.0,
#   'xtrans': 0.0,
#   'ditrans': 75.0,
#   'total': 366174.0,
#   'percent_intrans': 0.35687405441129083,
#   'percent_trans': 0.6429211249296782,
#   'percent_ditrans': 0.00020482065903095248},
#  'explains': {'intrans': 39130.0,
#   'trans': 49671.0,
#   'xtrans': 0.0,
#   'ditrans': 28.0,
#   'total': 88829.0,
#   'percent_intrans': 0.4405092931362505,
#   'percent_trans': 0.5591754944894123,
#   'percent_ditrans': 0.00031521237433720966},
#  'explicate': {'intrans': 1572.0,
#   'trans': 1441.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3013.0,
#   'percent_intrans': 0.5217391304347826,
#   'percent_trans': 0.4782608695652174,
#   'percent_ditrans': 0.0},
#  'explicated': {'intrans': 2152.0,
#   'trans': 11.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2163.0,
#   'percent_intrans': 0.994914470642626,
#   'percent_trans': 0.005085529357374018,
#   'percent_ditrans': 0.0},
#  'explicit': {'intrans': 3289.0,
#   'trans': 19.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3308.0,
#   'percent_intrans': 0.9942563482466747,
#   'percent_trans': 0.005743651753325272,
#   'percent_ditrans': 0.0},
#  'explode': {'intrans': 30884.0,
#   'trans': 5377.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 36261.0,
#   'percent_intrans': 0.8517139626596067,
#   'percent_trans': 0.14828603734039325,
#   'percent_ditrans': 0.0},
#  'exploded': {'intrans': 57866.0,
#   'trans': 2180.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 60046.0,
#   'percent_intrans': 0.9636945008826566,
#   'percent_trans': 0.03630549911734337,
#   'percent_ditrans': 0.0},
#  'explodes': {'intrans': 4324.0,
#   'trans': 500.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 4824.0,
#   'percent_intrans': 0.896351575456053,
#   'percent_trans': 0.10364842454394692,
#   'percent_ditrans': 0.0},
#  'exploding': {'intrans': 33692.0,
#   'trans': 5209.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 38901.0,
#   'percent_intrans': 0.8660959872496851,
#   'percent_trans': 0.1339040127503149,
#   'percent_ditrans': 0.0},
#  'exploit': {'intrans': 63398.0,
#   'trans': 61222.0,
#   'xtrans': 40.0,
#   'ditrans': 14.0,
#   'total': 124674.0,
#   'percent_intrans': 0.5085101945874841,
#   'percent_trans': 0.4910566758105138,
#   'percent_ditrans': 0.0001122928597783018},
#  'exploited': {'intrans': 41996.0,
#   'trans': 2205.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 44201.0,
#   'percent_intrans': 0.9501142508088052,
#   'percent_trans': 0.04988574919119477,
#   'percent_ditrans': 0.0},
#  'exploiting': {'intrans': 17481.0,
#   'trans': 26147.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 43628.0,
#   'percent_intrans': 0.40068304758412027,
#   'percent_trans': 0.5993169524158797,
#   'percent_ditrans': 0.0},
#  'exploits': {'intrans': 2410.0,
#   'trans': 1171.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3581.0,
#   'percent_intrans': 0.6729963697291259,
#   'percent_trans': 0.32700363027087404,
#   'percent_ditrans': 0.0},
#  'explore': {'intrans': 65756.0,
#   'trans': 161593.0,
#   'xtrans': 0.0,
#   'ditrans': 105.0,
#   'total': 227454.0,
#   'percent_intrans': 0.28909581717622024,
#   'percent_trans': 0.7104425510213054,
#   'percent_ditrans': 0.00046163180247434647},
#  'explored': {'intrans': 79230.0,
#   'trans': 14576.0,
#   'xtrans': 0.0,
#   'ditrans': 38.0,
#   'total': 93844.0,
#   'percent_intrans': 0.8442734751289374,
#   'percent_trans': 0.1553215975448617,
#   'percent_ditrans': 0.0004049273262009292},
#  'explores': {'intrans': 1633.0,
#   'trans': 2751.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 4384.0,
#   'percent_intrans': 0.3724908759124088,
#   'percent_trans': 0.6275091240875912,
#   'percent_ditrans': 0.0},
#  'exploring': {'intrans': 85021.0,
#   'trans': 83941.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 168962.0,
#   'percent_intrans': 0.5031959848960121,
#   'percent_trans': 0.4968040151039879,
#   'percent_ditrans': 0.0},
#  'expofed': {'intrans': 4021.0,
#   'trans': 48.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 4069.0,
#   'percent_intrans': 0.988203489800934,
#   'percent_trans': 0.011796510199066109,
#   'percent_ditrans': 0.0},
#  'export': {'intrans': 11634.0,
#   'trans': 21205.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 32839.0,
#   'percent_intrans': 0.3542738816650933,
#   'percent_trans': 0.6457261183349067,
#   'percent_ditrans': 0.0},
#  'exported': {'intrans': 125368.0,
#   'trans': 2867.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 128235.0,
#   'percent_intrans': 0.9776426092720396,
#   'percent_trans': 0.022357390727960384,
#   'percent_ditrans': 0.0},
#  'exporting': {'intrans': 53998.0,
#   'trans': 12455.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 66453.0,
#   'percent_intrans': 0.8125743006335304,
#   'percent_trans': 0.18742569936646952,
#   'percent_ditrans': 0.0},
#  'exports': {'intrans': 3382.0,
#   'trans': 2982.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 6364.0,
#   'percent_intrans': 0.5314267756128221,
#   'percent_trans': 0.4685732243871778,
#   'percent_ditrans': 0.0},
#  'expose': {'intrans': 29732.0,
#   'trans': 115592.0,
#   'xtrans': 0.0,
#   'ditrans': 214.0,
#   'total': 145538.0,
#   'percent_intrans': 0.20429028844700356,
#   'percent_trans': 0.7942393051986423,
#   'percent_ditrans': 0.0014704063543541893},
#  'exposed': {'intrans': 826395.0,
#   'trans': 30744.0,
#   'xtrans': 0.0,
#   'ditrans': 80.0,
#   'total': 857219.0,
#   'percent_intrans': 0.9640418609480192,
#   'percent_trans': 0.0358648140090222,
#   'percent_ditrans': 9.332504295868384e-05},
#  'exposes': {'intrans': 4129.0,
#   'trans': 9240.0,
#   'xtrans': 0.0,
#   'ditrans': 50.0,
#   'total': 13419.0,
#   'percent_intrans': 0.3076980400924063,
#   'percent_trans': 0.6885758998435054,
#   'percent_ditrans': 0.0037260600640882328},
#  'exposing': {'intrans': 15013.0,
#   'trans': 93067.0,
#   'xtrans': 0.0,
#   'ditrans': 138.0,
#   'total': 108218.0,
#   'percent_intrans': 0.13872923173594046,
#   'percent_trans': 0.859995564508677,
#   'percent_ditrans': 0.0012752037553826535},
#  'expostulate': {'intrans': 8887.0,
#   'trans': 114.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 9001.0,
#   'percent_intrans': 0.9873347405843796,
#   'percent_trans': 0.012665259415620486,
#   'percent_ditrans': 0.0},
#  'expostulated': {'intrans': 4878.0,
#   'trans': 88.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 4966.0,
#   'percent_intrans': 0.982279500604108,
#   'percent_trans': 0.017720499395892066,
#   'percent_ditrans': 0.0},
#  'expostulating': {'intrans': 3482.0,
#   'trans': 17.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3499.0,
#   'percent_intrans': 0.9951414689911404,
#   'percent_trans': 0.004858531008859674,
#   'percent_ditrans': 0.0},
#  'expound': {'intrans': 12609.0,
#   'trans': 19315.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 31924.0,
#   'percent_intrans': 0.3949693020924696,
#   'percent_trans': 0.6050306979075304,
#   'percent_ditrans': 0.0},
#  'expounded': {'intrans': 24140.0,
#   'trans': 4088.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 28228.0,
#   'percent_intrans': 0.8551792546407821,
#   'percent_trans': 0.1448207453592178,
#   'percent_ditrans': 0.0},
#  'expounding': {'intrans': 6404.0,
#   'trans': 14895.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 21299.0,
#   'percent_intrans': 0.3006713930231466,
#   'percent_trans': 0.6993286069768534,
#   'percent_ditrans': 0.0},
#  'expounds': {'intrans': 1431.0,
#   'trans': 1436.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2867.0,
#   'percent_intrans': 0.4991280083711197,
#   'percent_trans': 0.5008719916288804,
#   'percent_ditrans': 0.0},
#  'exprefs': {'intrans': 1907.0,
#   'trans': 1946.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3853.0,
#   'percent_intrans': 0.4949390085647548,
#   'percent_trans': 0.5050609914352453,
#   'percent_ditrans': 0.0},
#  'express': {'intrans': 190256.0,
#   'trans': 742320.0,
#   'xtrans': 0.0,
#   'ditrans': 525.0,
#   'total': 933101.0,
#   'percent_intrans': 0.20389646994269645,
#   'percent_trans': 0.7955408900001179,
#   'percent_ditrans': 0.0005626400571856636},
#  'expressed': {'intrans': 1066357.0,
#   'trans': 272807.0,
#   'xtrans': 14.0,
#   'ditrans': 260.0,
#   'total': 1339438.0,
#   'percent_intrans': 0.7961227022079409,
#   'percent_trans': 0.20367273438561545,
#   'percent_ditrans': 0.0001941112615888156},
#  'expresses': {'intrans': 30826.0,
#   'trans': 94735.0,
#   'xtrans': 60.0,
#   'ditrans': 130.0,
#   'total': 125751.0,
#   'percent_intrans': 0.2451352275528624,
#   'percent_trans': 0.7533538500687867,
#   'percent_ditrans': 0.0010337889957137518},
#  'expressing': {'intrans': 58344.0,
#   'trans': 408834.0,
#   'xtrans': 0.0,
#   'ditrans': 75.0,
#   'total': 467253.0,
#   'percent_intrans': 0.12486597196807725,
#   'percent_trans': 0.8749735154188416,
#   'percent_ditrans': 0.0001605126130811359},
#  'expropriated': {'intrans': 6423.0,
#   'trans': 82.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 6505.0,
#   'percent_intrans': 0.9873943120676404,
#   'percent_trans': 0.012605687932359723,
#   'percent_ditrans': 0.0},
#  'expunge': {'intrans': 2569.0,
#   'trans': 2676.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 5245.0,
#   'percent_intrans': 0.4897998093422307,
#   'percent_trans': 0.5102001906577693,
#   'percent_ditrans': 0.0},
#  'expunged': {'intrans': 7282.0,
#   'trans': 380.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 7662.0,
#   'percent_intrans': 0.9504045941007571,
#   'percent_trans': 0.049595405899243016,
#   'percent_ditrans': 0.0},
#  'expunging': {'intrans': 3227.0,
#   'trans': 1238.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 4465.0,
#   'percent_intrans': 0.7227323628219485,
#   'percent_trans': 0.27726763717805153,
#   'percent_ditrans': 0.0},
#  'expurgated': {'intrans': 2157.0,
#   'trans': 0.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2157.0,
#   'percent_intrans': 1.0,
#   'percent_trans': 0.0,
#   'percent_ditrans': 0.0},
#  'extend': {'intrans': 155586.0,
#   'trans': 189152.0,
#   'xtrans': 0.0,
#   'ditrans': 280.0,
#   'total': 345018.0,
#   'percent_intrans': 0.4509503851972941,
#   'percent_trans': 0.5482380629416437,
#   'percent_ditrans': 0.0008115518610623214},
#  'extended': {'intrans': 416718.0,
#   'trans': 52914.0,
#   'xtrans': 18.0,
#   'ditrans': 183.0,
#   'total': 469833.0,
#   'percent_intrans': 0.8869491925854506,
#   'percent_trans': 0.11262299583043335,
#   'percent_ditrans': 0.00038950009897133664},
#  'extending': {'intrans': 395495.0,
#   'trans': 190100.0,
#   'xtrans': 0.0,
#   'ditrans': 152.0,
#   'total': 585747.0,
#   'percent_intrans': 0.6751976535944699,
#   'percent_trans': 0.32454284870430405,
#   'percent_ditrans': 0.0002594977012259559},
#  'extends': {'intrans': 117624.0,
#   'trans': 23873.0,
#   'xtrans': 0.0,
#   'ditrans': 13.0,
#   'total': 141510.0,
#   'percent_intrans': 0.8312062751748993,
#   'percent_trans': 0.16870185852589922,
#   'percent_ditrans': 9.186629920146988e-05},
#  'extenuate': {'intrans': 3996.0,
#   'trans': 5863.0,
#   'xtrans': 0.0,
#   'ditrans': 54.0,
#   'total': 9913.0,
#   'percent_intrans': 0.40310703117118935,
#   'percent_trans': 0.5914455765156865,
#   'percent_ditrans': 0.005447392313124182},
#  'extenuated': {'intrans': 1894.0,
#   'trans': 346.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2240.0,
#   'percent_intrans': 0.8455357142857143,
#   'percent_trans': 0.15446428571428572,
#   'percent_ditrans': 0.0},
#  'extenuating': {'intrans': 8466.0,
#   'trans': 2195.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 10661.0,
#   'percent_intrans': 0.7941093706031329,
#   'percent_trans': 0.2058906293968671,
#   'percent_ditrans': 0.0},
#  'exterior': {'intrans': 1878.0,
#   'trans': 1126.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3004.0,
#   'percent_intrans': 0.6251664447403462,
#   'percent_trans': 0.3748335552596538,
#   'percent_ditrans': 0.0},
#  'exterminate': {'intrans': 6041.0,
#   'trans': 25243.0,
#   'xtrans': 0.0,
#   'ditrans': 31.0,
#   'total': 31315.0,
#   'percent_intrans': 0.19291074564905,
#   'percent_trans': 0.8060993134280696,
#   'percent_ditrans': 0.0009899409228804087},
#  'exterminated': {'intrans': 18648.0,
#   'trans': 2488.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 21136.0,
#   'percent_intrans': 0.8822861468584405,
#   'percent_trans': 0.11771385314155942,
#   'percent_ditrans': 0.0},
#  'exterminating': {'intrans': 12455.0,
#   'trans': 9097.0,
#   'xtrans': 0.0,
#   'ditrans': 34.0,
#   'total': 21586.0,
#   'percent_intrans': 0.5769943481886408,
#   'percent_trans': 0.4214305568423978,
#   'percent_ditrans': 0.0015750949689613636},
#  'externalizing': {'intrans': 1672.0,
#   'trans': 407.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2079.0,
#   'percent_intrans': 0.8042328042328042,
#   'percent_trans': 0.19576719576719576,
#   'percent_ditrans': 0.0},
#  'extinct': {'intrans': 4252.0,
#   'trans': 401.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 4653.0,
#   'percent_intrans': 0.913819041478616,
#   'percent_trans': 0.08618095852138405,
#   'percent_ditrans': 0.0},
#  'extinguish': {'intrans': 12935.0,
#   'trans': 51538.0,
#   'xtrans': 0.0,
#   'ditrans': 23.0,
#   'total': 64496.0,
#   'percent_intrans': 0.20055507318283305,
#   'percent_trans': 0.799088315554453,
#   'percent_ditrans': 0.00035661126271396674},
#  'extinguished': {'intrans': 102598.0,
#   'trans': 13017.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 115615.0,
#   'percent_intrans': 0.8874108030964839,
#   'percent_trans': 0.11258919690351596,
#   'percent_ditrans': 0.0},
#  'extinguishes': {'intrans': 806.0,
#   'trans': 3786.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 4592.0,
#   'percent_intrans': 0.1755226480836237,
#   'percent_trans': 0.8244773519163763,
#   'percent_ditrans': 0.0},
#  'extinguishing': {'intrans': 9627.0,
#   'trans': 21846.0,
#   'xtrans': 0.0,
#   'ditrans': 10.0,
#   'total': 31483.0,
#   'percent_intrans': 0.30578407394466856,
#   'percent_trans': 0.6938982943175682,
#   'percent_ditrans': 0.0003176317377632373},
#  'extirpate': {'intrans': 4640.0,
#   'trans': 17875.0,
#   'xtrans': 0.0,
#   'ditrans': 15.0,
#   'total': 22530.0,
#   'percent_intrans': 0.20594762538837105,
#   'percent_trans': 0.7933865956502442,
#   'percent_ditrans': 0.0006657789613848202},
#  'extirpated': {'intrans': 10409.0,
#   'trans': 1299.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 11708.0,
#   'percent_intrans': 0.8890502220703792,
#   'percent_trans': 0.11094977792962077,
#   'percent_ditrans': 0.0},
#  'extirpating': {'intrans': 1580.0,
#   'trans': 6134.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 7714.0,
#   'percent_intrans': 0.2048224008296604,
#   'percent_trans': 0.7951775991703396,
#   'percent_ditrans': 0.0},
#  'extol': {'intrans': 3901.0,
#   'trans': 8415.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 12316.0,
#   'percent_intrans': 0.31674244884702824,
#   'percent_trans': 0.6832575511529717,
#   'percent_ditrans': 0.0},
#  'extolled': {'intrans': 10754.0,
#   'trans': 4097.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 14851.0,
#   'percent_intrans': 0.7241263214598344,
#   'percent_trans': 0.27587367854016565,
#   'percent_ditrans': 0.0},
#  'extolling': {'intrans': 1573.0,
#   'trans': 9730.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 11303.0,
#   'percent_intrans': 0.13916659293992745,
#   'percent_trans': 0.8608334070600725,
#   'percent_ditrans': 0.0},
#  'extort': {'intrans': 5823.0,
#   'trans': 21434.0,
#   'xtrans': 0.0,
#   'ditrans': 33.0,
#   'total': 27290.0,
#   'percent_intrans': 0.2133748625870282,
#   'percent_trans': 0.7854159032612679,
#   'percent_ditrans': 0.0012092341517039211},
#  'extorted': {'intrans': 21000.0,
#   'trans': 4897.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 25897.0,
#   'percent_intrans': 0.8109047380005406,
#   'percent_trans': 0.1890952619994594,
#   'percent_ditrans': 0.0},
#  'extorting': {'intrans': 2880.0,
#   'trans': 7533.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 10413.0,
#   'percent_intrans': 0.27657735522904064,
#   'percent_trans': 0.7234226447709594,
#   'percent_ditrans': 0.0},
#  'extra': {'intrans': 4605.0,
#   'trans': 726.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 5331.0,
#   'percent_intrans': 0.8638154192459201,
#   'percent_trans': 0.1361845807540799,
#   'percent_ditrans': 0.0},
#  'extract': {'intrans': 314102.0,
#   'trans': 96441.0,
#   'xtrans': 89.0,
#   'ditrans': 51.0,
#   'total': 410683.0,
#   'percent_intrans': 0.7648283469245135,
#   'percent_trans': 0.2348307575429224,
#   'percent_ditrans': 0.00012418337257690237},
#  'extracted': {'intrans': 140492.0,
#   'trans': 7140.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 147632.0,
#   'percent_intrans': 0.9516365015714752,
#   'percent_trans': 0.04836349842852498,
#   'percent_ditrans': 0.0},
#  'extracting': {'intrans': 22450.0,
#   'trans': 40219.0,
#   'xtrans': 0.0,
#   'ditrans': 14.0,
#   'total': 62683.0,
#   'percent_intrans': 0.3581513328972768,
#   'percent_trans': 0.6416253210599365,
#   'percent_ditrans': 0.00022334604278672045},
#  'extracts': {'intrans': 2456.0,
#   'trans': 1894.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 4350.0,
#   'percent_intrans': 0.5645977011494253,
#   'percent_trans': 0.4354022988505747,
#   'percent_ditrans': 0.0},
#  'extrapolated': {'intrans': 2224.0,
#   'trans': 0.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2224.0,
#   'percent_intrans': 1.0,
#   'percent_trans': 0.0,
#   'percent_ditrans': 0.0},
#  'extrapolating': {'intrans': 1402.0,
#   'trans': 1285.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2687.0,
#   'percent_intrans': 0.5217714923706737,
#   'percent_trans': 0.4782285076293264,
#   'percent_ditrans': 0.0},
#  'extravagance': {'intrans': 3632.0,
#   'trans': 57.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3689.0,
#   'percent_intrans': 0.9845486581729466,
#   'percent_trans': 0.015451341827053404,
#   'percent_ditrans': 0.0},
#  'extremes': {'intrans': 1875.0,
#   'trans': 307.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2182.0,
#   'percent_intrans': 0.8593033913840513,
#   'percent_trans': 0.14069660861594868,
#   'percent_ditrans': 0.0},
#  'extremities': {'intrans': 2373.0,
#   'trans': 154.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2527.0,
#   'percent_intrans': 0.9390581717451524,
#   'percent_trans': 0.06094182825484765,
#   'percent_ditrans': 0.0},
#  'extricate': {'intrans': 1295.0,
#   'trans': 37983.0,
#   'xtrans': 36.0,
#   'ditrans': 11.0,
#   'total': 39325.0,
#   'percent_intrans': 0.032930705657978385,
#   'percent_trans': 0.965874125874126,
#   'percent_ditrans': 0.00027972027972027967},
#  'extricated': {'intrans': 4907.0,
#   'trans': 3398.0,
#   'xtrans': 0.0,
#   'ditrans': 48.0,
#   'total': 8353.0,
#   'percent_intrans': 0.5874536094816234,
#   'percent_trans': 0.4067999521130133,
#   'percent_ditrans': 0.005746438405363342},
#  'extricating': {'intrans': 356.0,
#   'trans': 10404.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 10760.0,
#   'percent_intrans': 0.033085501858736065,
#   'percent_trans': 0.9669144981412641,
#   'percent_ditrans': 0.0},
#  'extruded': {'intrans': 6574.0,
#   'trans': 51.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 6625.0,
#   'percent_intrans': 0.9923018867924528,
#   'percent_trans': 0.00769811320754717,
#   'percent_ditrans': 0.0},
#  'extruding': {'intrans': 2580.0,
#   'trans': 178.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2758.0,
#   'percent_intrans': 0.9354604786076868,
#   'percent_trans': 0.06453952139231328,
#   'percent_ditrans': 0.0},
#  'exude': {'intrans': 2249.0,
#   'trans': 1075.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3324.0,
#   'percent_intrans': 0.6765944645006017,
#   'percent_trans': 0.3234055354993983,
#   'percent_ditrans': 0.0},
#  'exuded': {'intrans': 2863.0,
#   'trans': 238.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3101.0,
#   'percent_intrans': 0.9232505643340858,
#   'percent_trans': 0.07674943566591423,
#   'percent_ditrans': 0.0},
#  'exudes': {'intrans': 4703.0,
#   'trans': 680.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 5383.0,
#   'percent_intrans': 0.8736763886308749,
#   'percent_trans': 0.126323611369125,
#   'percent_ditrans': 0.0},
#  'exuding': {'intrans': 3463.0,
#   'trans': 1253.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 4716.0,
#   'percent_intrans': 0.7343087362171332,
#   'percent_trans': 0.26569126378286684,
#   'percent_ditrans': 0.0},
#  'exult': {'intrans': 10614.0,
#   'trans': 186.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 10800.0,
#   'percent_intrans': 0.9827777777777778,
#   'percent_trans': 0.017222222222222222,
#   'percent_ditrans': 0.0},
#  'exulted': {'intrans': 5606.0,
#   'trans': 31.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 5637.0,
#   'percent_intrans': 0.9945006208976406,
#   'percent_trans': 0.005499379102359411,
#   'percent_ditrans': 0.0},
#  'exulting': {'intrans': 34052.0,
#   'trans': 2066.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 36118.0,
#   'percent_intrans': 0.9427986045738966,
#   'percent_trans': 0.05720139542610333,
#   'percent_ditrans': 0.0},
#  'exults': {'intrans': 2205.0,
#   'trans': 10.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2215.0,
#   'percent_intrans': 0.9954853273137696,
#   'percent_trans': 0.004514672686230248,
#   'percent_ditrans': 0.0},
#  'eye': {'intrans': 2448.0,
#   'trans': 0.0,
#   'xtrans': 0.0,
#   'ditrans': 18.0,
#   'total': 2466.0,
#   'percent_intrans': 0.9927007299270072,
#   'percent_trans': 0.0,
#   'percent_ditrans': 0.007299270072992701},
#  'eyed': {'intrans': 4491.0,
#   'trans': 6283.0,
#   'xtrans': 0.0,
#   'ditrans': 22.0,
#   'total': 10796.0,
#   'percent_intrans': 0.4159874027417562,
#   'percent_trans': 0.5819748054835124,
#   'percent_ditrans': 0.002037791774731382},
#  'eyeing': {'intrans': 459.0,
#   'trans': 9639.0,
#   'xtrans': 0.0,
#   'ditrans': 59.0,
#   'total': 10157.0,
#   'percent_intrans': 0.04519050900856552,
#   'percent_trans': 0.949000689179876,
#   'percent_ditrans': 0.005808801811558531},
#  'eying': {'intrans': 189.0,
#   'trans': 2099.0,
#   'xtrans': 0.0,
#   'ditrans': 32.0,
#   'total': 2320.0,
#   'percent_intrans': 0.0814655172413793,
#   'percent_trans': 0.9047413793103448,
#   'percent_ditrans': 0.013793103448275862},
#  'fa': {'intrans': 2413.0,
#   'trans': 99.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2512.0,
#   'percent_intrans': 0.9605891719745224,
#   'percent_trans': 0.039410828025477705,
#   'percent_ditrans': 0.0},
#  'fabricate': {'intrans': 3905.0,
#   'trans': 3663.0,
#   'xtrans': 0.0,
#   'ditrans': 19.0,
#   'total': 7587.0,
#   'percent_intrans': 0.5146961908527745,
#   'percent_trans': 0.4827995255041518,
#   'percent_ditrans': 0.0025042836430736785},
#  'fabricated': {'intrans': 25463.0,
#   'trans': 790.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 26253.0,
#   'percent_intrans': 0.9699082009675084,
#   'percent_trans': 0.030091799032491526,
#   'percent_ditrans': 0.0},
#  'fabricating': {'intrans': 6428.0,
#   'trans': 4430.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 10858.0,
#   'percent_intrans': 0.5920058942715049,
#   'percent_trans': 0.4079941057284951,
#   'percent_ditrans': 0.0},
#  'face': {'intrans': 424466.0,
#   'trans': 383983.0,
#   'xtrans': 0.0,
#   'ditrans': 201.0,
#   'total': 808650.0,
#   'percent_intrans': 0.5249069436715513,
#   'percent_trans': 0.4748444939096024,
#   'percent_ditrans': 0.0002485624188462252},
#  'faced': {'intrans': 208141.0,
#   'trans': 56472.0,
#   'xtrans': 13.0,
#   'ditrans': 30.0,
#   'total': 264656.0,
#   'percent_intrans': 0.7864586482074845,
#   'percent_trans': 0.21337887673054834,
#   'percent_ditrans': 0.00011335469439574392},
#  'faces': {'intrans': 28638.0,
#   'trans': 18109.0,
#   'xtrans': 11.0,
#   'ditrans': 31.0,
#   'total': 46789.0,
#   'percent_intrans': 0.6120669388104042,
#   'percent_trans': 0.3870354143067815,
#   'percent_ditrans': 0.0006625488896962961},
#  'faceted': {'intrans': 3136.0,
#   'trans': 0.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3136.0,
#   'percent_intrans': 1.0,
#   'percent_trans': 0.0,
#   'percent_ditrans': 0.0},
#  'facilitate': {'intrans': 24064.0,
#   'trans': 275180.0,
#   'xtrans': 0.0,
#   'ditrans': 34.0,
#   'total': 299278.0,
#   'percent_intrans': 0.08040684580891345,
#   'percent_trans': 0.9194795474441824,
#   'percent_ditrans': 0.00011360674690421617},
#  'facilitated': {'intrans': 15131.0,
#   'trans': 7262.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 22393.0,
#   'percent_intrans': 0.6757022283749387,
#   'percent_trans': 0.3242977716250614,
#   'percent_ditrans': 0.0},
#  'facilitates': {'intrans': 2496.0,
#   'trans': 17232.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 19728.0,
#   'percent_intrans': 0.12652068126520682,
#   'percent_trans': 0.8734793187347932,
#   'percent_ditrans': 0.0},
#  'facilitating': {'intrans': 12666.0,
#   'trans': 61171.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 73837.0,
#   'percent_intrans': 0.17154001381421238,
#   'percent_trans': 0.8284599861857876,
#   'percent_ditrans': 0.0},
#  'facing': {'intrans': 169086.0,
#   'trans': 459582.0,
#   'xtrans': 27.0,
#   'ditrans': 180.0,
#   'total': 628875.0,
#   'percent_intrans': 0.2688706022659511,
#   'percent_trans': 0.7308002385211687,
#   'percent_ditrans': 0.00028622540250447233},
#  'faction': {'intrans': 2470.0,
#   'trans': 280.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2750.0,
#   'percent_intrans': 0.8981818181818182,
#   'percent_trans': 0.10181818181818182,
#   'percent_ditrans': 0.0},
#  'factor': {'intrans': 719.0,
#   'trans': 2279.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2998.0,
#   'percent_intrans': 0.2398265510340227,
#   'percent_trans': 0.7601734489659773,
#   'percent_ditrans': 0.0},
#  'faculties': {'intrans': 2440.0,
#   'trans': 375.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2815.0,
#   'percent_intrans': 0.866785079928952,
#   'percent_trans': 0.13321492007104796,
#   'percent_ditrans': 0.0},
#  'fade': {'intrans': 77191.0,
#   'trans': 1072.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 78263.0,
#   'percent_intrans': 0.9863025950960224,
#   'percent_trans': 0.013697404903977613,
#   'percent_ditrans': 0.0},
#  'faded': {'intrans': 208314.0,
#   'trans': 3818.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 212132.0,
#   'percent_intrans': 0.9820017724812852,
#   'percent_trans': 0.017998227518714764,
#   'percent_ditrans': 0.0},
#  'fades': {'intrans': 17820.0,
#   'trans': 655.0,
#   'xtrans': 11.0,
#   'ditrans': 0.0,
#   'total': 18486.0,
#   'percent_intrans': 0.9639727361246349,
#   'percent_trans': 0.035432218976522774,
#   'percent_ditrans': 0.0},
#  'fadeth': {'intrans': 3711.0,
#   'trans': 153.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3864.0,
#   'percent_intrans': 0.9604037267080744,
#   'percent_trans': 0.03959627329192546,
#   'percent_ditrans': 0.0},
#  'fading': {'intrans': 44041.0,
#   'trans': 2056.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 46097.0,
#   'percent_intrans': 0.9553983990281364,
#   'percent_trans': 0.04460160097186368,
#   'percent_ditrans': 0.0},
#  'fagged': {'intrans': 4061.0,
#   'trans': 51.0,
#   'xtrans': 0.0,
#   'ditrans': 18.0,
#   'total': 4130.0,
#   'percent_intrans': 0.9832929782082324,
#   'percent_trans': 0.012348668280871672,
#   'percent_ditrans': 0.004358353510895884},
#  'fahrenheit': {'intrans': 3772.0,
#   'trans': 226.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3998.0,
#   'percent_intrans': 0.9434717358679341,
#   'percent_trans': 0.056528264132066026,
#   'percent_ditrans': 0.0},
#  'faid': {'intrans': 47411.0,
#   'trans': 5356.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 52767.0,
#   'percent_intrans': 0.8984971667898497,
#   'percent_trans': 0.10150283321015027,
#   'percent_ditrans': 0.0},
#  'fail': {'intrans': 313412.0,
#   'trans': 13826.0,
#   'xtrans': 0.0,
#   'ditrans': 36.0,
#   'total': 327274.0,
#   'percent_intrans': 0.9576440536064582,
#   'percent_trans': 0.042245946821317916,
#   'percent_ditrans': 0.00010999957222388579},
#  'returns': {'intrans': 37159.0,
#   'trans': 12782.0,
#   'xtrans': 0.0,
#   'ditrans': 238.0,
#   'total': 50179.0,
#   'percent_intrans': 0.7405289065146775,
#   'percent_trans': 0.25472807349688115,
#   'percent_ditrans': 0.004743019988441379},
#  'reunite': {'intrans': 3592.0,
#   'trans': 4320.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 7912.0,
#   'percent_intrans': 0.4539939332659252,
#   'percent_trans': 0.5460060667340748,
#   'percent_ditrans': 0.0},
#  'reunited': {'intrans': 13219.0,
#   'trans': 715.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 13934.0,
#   'percent_intrans': 0.9486866657097748,
#   'percent_trans': 0.05131333429022535,
#   'percent_ditrans': 0.0},
#  'reuniting': {'intrans': 1625.0,
#   'trans': 1545.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3170.0,
#   'percent_intrans': 0.5126182965299685,
#   'percent_trans': 0.4873817034700316,
#   'percent_ditrans': 0.0},
#  'reused': {'intrans': 5645.0,
#   'trans': 136.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 5781.0,
#   'percent_intrans': 0.9764746583636048,
#   'percent_trans': 0.023525341636395088,
#   'percent_ditrans': 0.0},
#  'rev.': {'intrans': 14900.0,
#   'trans': 51.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 14951.0,
#   'percent_intrans': 0.9965888569326466,
#   'percent_trans': 0.003411143067353355,
#   'percent_ditrans': 0.0},
#  'revamped': {'intrans': 3158.0,
#   'trans': 32.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3190.0,
#   'percent_intrans': 0.9899686520376176,
#   'percent_trans': 0.010031347962382446,
#   'percent_ditrans': 0.0},
#  'reveal': {'intrans': 63484.0,
#   'trans': 154886.0,
#   'xtrans': 12.0,
#   'ditrans': 116.0,
#   'total': 218498.0,
#   'percent_intrans': 0.2905472818973172,
#   'percent_trans': 0.7088669003835275,
#   'percent_ditrans': 0.0005308973079845125},
#  'revealed': {'intrans': 332124.0,
#   'trans': 44943.0,
#   'xtrans': 33.0,
#   'ditrans': 38.0,
#   'total': 377138.0,
#   'percent_intrans': 0.8806431597982701,
#   'percent_trans': 0.11916858020141168,
#   'percent_ditrans': 0.0001007588734097333},
#  'revealing': {'intrans': 73517.0,
#   'trans': 81975.0,
#   'xtrans': 0.0,
#   'ditrans': 47.0,
#   'total': 155539.0,
#   'percent_intrans': 0.4726595901992426,
#   'percent_trans': 0.5270382347835592,
#   'percent_ditrans': 0.00030217501719825894},
#  'reveals': {'intrans': 27023.0,
#   'trans': 36253.0,
#   'xtrans': 0.0,
#   'ditrans': 11.0,
#   'total': 63287.0,
#   'percent_intrans': 0.4269913252326702,
#   'percent_trans': 0.5728348634000664,
#   'percent_ditrans': 0.00017381136726341904},
#  'revel': {'intrans': 9036.0,
#   'trans': 323.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 9359.0,
#   'percent_intrans': 0.9654877657869432,
#   'percent_trans': 0.03451223421305695,
#   'percent_ditrans': 0.0},
#  'revelled': {'intrans': 4362.0,
#   'trans': 84.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 4446.0,
#   'percent_intrans': 0.98110661268556,
#   'percent_trans': 0.018893387314439947,
#   'percent_ditrans': 0.0},
#  'revelling': {'intrans': 5844.0,
#   'trans': 69.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 5913.0,
#   'percent_intrans': 0.9883307965499746,
#   'percent_trans': 0.011669203450025369,
#   'percent_ditrans': 0.0},
#  'revenge': {'intrans': 9677.0,
#   'trans': 38098.0,
#   'xtrans': 0.0,
#   'ditrans': 44.0,
#   'total': 47819.0,
#   'percent_intrans': 0.2023672598757816,
#   'percent_trans': 0.7967126037767415,
#   'percent_ditrans': 0.0009201363474769444},
#  'revenged': {'intrans': 17220.0,
#   'trans': 3332.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 20552.0,
#   'percent_intrans': 0.8378746594005451,
#   'percent_trans': 0.16212534059945505,
#   'percent_ditrans': 0.0},
#  'revenging': {'intrans': 2147.0,
#   'trans': 7163.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 9310.0,
#   'percent_intrans': 0.2306122448979592,
#   'percent_trans': 0.7693877551020408,
#   'percent_ditrans': 0.0},
#  'reverberated': {'intrans': 3549.0,
#   'trans': 98.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3647.0,
#   'percent_intrans': 0.9731285988483686,
#   'percent_trans': 0.02687140115163148,
#   'percent_ditrans': 0.0},
#  'reverberating': {'intrans': 7422.0,
#   'trans': 707.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 8129.0,
#   'percent_intrans': 0.9130274326485422,
#   'percent_trans': 0.08697256735145774,
#   'percent_ditrans': 0.0},
#  'revere': {'intrans': 12819.0,
#   'trans': 8775.0,
#   'xtrans': 10.0,
#   'ditrans': 0.0,
#   'total': 21604.0,
#   'percent_intrans': 0.5933623403073505,
#   'percent_trans': 0.4061747824476949,
#   'percent_ditrans': 0.0},
#  'revered': {'intrans': 39817.0,
#   'trans': 4495.0,
#   'xtrans': 0.0,
#   'ditrans': 11.0,
#   'total': 44323.0,
#   'percent_intrans': 0.8983372064165331,
#   'percent_trans': 0.10141461543668072,
#   'percent_ditrans': 0.00024817814678609304},
#  'reverence': {'intrans': 8894.0,
#   'trans': 14926.0,
#   'xtrans': 0.0,
#   'ditrans': 125.0,
#   'total': 23945.0,
#   'percent_intrans': 0.37143453748172894,
#   'percent_trans': 0.6233451660054291,
#   'percent_ditrans': 0.00522029651284193},
#  'reverenced': {'intrans': 13302.0,
#   'trans': 2856.0,
#   'xtrans': 0.0,
#   'ditrans': 211.0,
#   'total': 16369.0,
#   'percent_intrans': 0.8126336367523979,
#   'percent_trans': 0.1744761439306005,
#   'percent_ditrans': 0.01289021931700165},
#  'reverencing': {'intrans': 668.0,
#   'trans': 1708.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2376.0,
#   'percent_intrans': 0.28114478114478114,
#   'percent_trans': 0.7188552188552189,
#   'percent_ditrans': 0.0},
#  'reveres': {'intrans': 1328.0,
#   'trans': 785.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2113.0,
#   'percent_intrans': 0.6284902981542829,
#   'percent_trans': 0.37150970184571697,
#   'percent_ditrans': 0.0},
#  'reverse': {'intrans': 28420.0,
#   'trans': 71806.0,
#   'xtrans': 0.0,
#   'ditrans': 21.0,
#   'total': 100247.0,
#   'percent_intrans': 0.28349975560365903,
#   'percent_trans': 0.7162907618183088,
#   'percent_ditrans': 0.0002094825780322603},
#  'reversed': {'intrans': 175972.0,
#   'trans': 7863.0,
#   'xtrans': 0.0,
#   'ditrans': 21.0,
#   'total': 183856.0,
#   'percent_intrans': 0.9571186145679228,
#   'percent_trans': 0.042767165607867016,
#   'percent_ditrans': 0.00011421982421025152},
#  'reverses': {'intrans': 2831.0,
#   'trans': 3462.0,
#   'xtrans': 11.0,
#   'ditrans': 0.0,
#   'total': 6304.0,
#   'percent_intrans': 0.4490799492385787,
#   'percent_trans': 0.5491751269035533,
#   'percent_ditrans': 0.0},
#  'reversing': {'intrans': 31363.0,
#   'trans': 54778.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 86141.0,
#   'percent_intrans': 0.3640891097154665,
#   'percent_trans': 0.6359108902845335,
#   'percent_ditrans': 0.0},
#  'revert': {'intrans': 24961.0,
#   'trans': 162.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 25123.0,
#   'percent_intrans': 0.9935517255104884,
#   'percent_trans': 0.0064482744895116035,
#   'percent_ditrans': 0.0},
#  'reverted': {'intrans': 9120.0,
#   'trans': 159.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 9279.0,
#   'percent_intrans': 0.9828645328160364,
#   'percent_trans': 0.01713546718396379,
#   'percent_ditrans': 0.0},
#  'reverting': {'intrans': 9587.0,
#   'trans': 121.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 9708.0,
#   'percent_intrans': 0.9875360527400082,
#   'percent_trans': 0.012463947259991759,
#   'percent_ditrans': 0.0},
#  'review': {'intrans': 45457.0,
#   'trans': 105118.0,
#   'xtrans': 0.0,
#   'ditrans': 88.0,
#   'total': 150663.0,
#   'percent_intrans': 0.301713094787705,
#   'percent_trans': 0.6977028202013765,
#   'percent_ditrans': 0.0005840850109184073},
#  'reviewed': {'intrans': 100236.0,
#   'trans': 8575.0,
#   'xtrans': 0.0,
#   'ditrans': 38.0,
#   'total': 108849.0,
#   'percent_intrans': 0.9208720337348071,
#   'percent_trans': 0.07877885878602467,
#   'percent_ditrans': 0.00034910747916838924},
#  'reviewing': {'intrans': 44156.0,
#   'trans': 79347.0,
#   'xtrans': 0.0,
#   'ditrans': 76.0,
#   'total': 123579.0,
#   'percent_intrans': 0.3573098989310481,
#   'percent_trans': 0.6420751098487607,
#   'percent_ditrans': 0.0006149912201911328},
#  'reviews': {'intrans': 5380.0,
#   'trans': 3644.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 9024.0,
#   'percent_intrans': 0.5961879432624113,
#   'percent_trans': 0.40381205673758863,
#   'percent_ditrans': 0.0},
#  'revile': {'intrans': 3625.0,
#   'trans': 7076.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 10701.0,
#   'percent_intrans': 0.3387533875338753,
#   'percent_trans': 0.6612466124661247,
#   'percent_ditrans': 0.0},
#  'reviled': {'intrans': 14767.0,
#   'trans': 3666.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 18433.0,
#   'percent_intrans': 0.8011175608962188,
#   'percent_trans': 0.19888243910378128,
#   'percent_ditrans': 0.0},
#  'reviling': {'intrans': 5749.0,
#   'trans': 3741.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 9490.0,
#   'percent_intrans': 0.605795574288725,
#   'percent_trans': 0.39420442571127506,
#   'percent_ditrans': 0.0},
#  'revise': {'intrans': 17554.0,
#   'trans': 43788.0,
#   'xtrans': 0.0,
#   'ditrans': 32.0,
#   'total': 61374.0,
#   'percent_intrans': 0.2860168801120996,
#   'percent_trans': 0.713461726463975,
#   'percent_ditrans': 0.0005213934239254407},
#  'revised': {'intrans': 665082.0,
#   'trans': 9597.0,
#   'xtrans': 0.0,
#   'ditrans': 44.0,
#   'total': 674723.0,
#   'percent_intrans': 0.9857111733259426,
#   'percent_trans': 0.01422361472782164,
#   'percent_ditrans': 6.521194623571451e-05},
#  'revising': {'intrans': 18920.0,
#   'trans': 29676.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 48596.0,
#   'percent_intrans': 0.38933245534611904,
#   'percent_trans': 0.610667544653881,
#   'percent_ditrans': 0.0},
#  'revisit': {'intrans': 1976.0,
#   'trans': 16074.0,
#   'xtrans': 0.0,
#   'ditrans': 33.0,
#   'total': 18083.0,
#   'percent_intrans': 0.10927390366642704,
#   'percent_trans': 0.8889011779018968,
#   'percent_ditrans': 0.0018249184316761601},
#  'revisited': {'intrans': 3930.0,
#   'trans': 1840.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 5770.0,
#   'percent_intrans': 0.6811091854419411,
#   'percent_trans': 0.3188908145580589,
#   'percent_ditrans': 0.0},
#  'revisiting': {'intrans': 1242.0,
#   'trans': 6004.0,
#   'xtrans': 0.0,
#   'ditrans': 36.0,
#   'total': 7282.0,
#   'percent_intrans': 0.17055753913759955,
#   'percent_trans': 0.8244987640758034,
#   'percent_ditrans': 0.004943696786597089},
#  'revitalize': {'intrans': 1086.0,
#   'trans': 1697.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2783.0,
#   'percent_intrans': 0.39022637441609775,
#   'percent_trans': 0.6097736255839022,
#   'percent_ditrans': 0.0},
#  'revitalized': {'intrans': 6151.0,
#   'trans': 55.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 6206.0,
#   'percent_intrans': 0.9911376087657106,
#   'percent_trans': 0.008862391234289398,
#   'percent_ditrans': 0.0},
#  'revitalizing': {'intrans': 1786.0,
#   'trans': 928.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2714.0,
#   'percent_intrans': 0.658069270449521,
#   'percent_trans': 0.341930729550479,
#   'percent_ditrans': 0.0},
#  'revive': {'intrans': 43131.0,
#   'trans': 99248.0,
#   'xtrans': 0.0,
#   'ditrans': 104.0,
#   'total': 142483.0,
#   'percent_intrans': 0.30270979695823363,
#   'percent_trans': 0.6965602914031851,
#   'percent_ditrans': 0.000729911638581445},
#  'revived': {'intrans': 128247.0,
#   'trans': 16152.0,
#   'xtrans': 0.0,
#   'ditrans': 94.0,
#   'total': 144493.0,
#   'percent_intrans': 0.8875654876014755,
#   'percent_trans': 0.11178396185282333,
#   'percent_ditrans': 0.0006505505457011758},
#  'revives': {'intrans': 4077.0,
#   'trans': 2775.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 6852.0,
#   'percent_intrans': 0.5950087565674256,
#   'percent_trans': 0.4049912434325744,
#   'percent_ditrans': 0.0},
#  'revivified': {'intrans': 2118.0,
#   'trans': 84.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2202.0,
#   'percent_intrans': 0.9618528610354224,
#   'percent_trans': 0.038147138964577665,
#   'percent_ditrans': 0.0},
#  'reviving': {'intrans': 40612.0,
#   'trans': 30427.0,
#   'xtrans': 17.0,
#   'ditrans': 0.0,
#   'total': 71056.0,
#   'percent_intrans': 0.5715492006304886,
#   'percent_trans': 0.4282115514523756,
#   'percent_ditrans': 0.0},
#  'revoke': {'intrans': 11839.0,
#   'trans': 17546.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 29385.0,
#   'percent_intrans': 0.4028926322953888,
#   'percent_trans': 0.5971073677046111,
#   'percent_ditrans': 0.0},
#  'revoked': {'intrans': 25365.0,
#   'trans': 2539.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 27904.0,
#   'percent_intrans': 0.9090094610091743,
#   'percent_trans': 0.09099053899082568,
#   'percent_ditrans': 0.0},
#  'revoking': {'intrans': 3384.0,
#   'trans': 6251.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 9635.0,
#   'percent_intrans': 0.35121951219512193,
#   'percent_trans': 0.6487804878048781,
#   'percent_ditrans': 0.0},
#  'revolted': {'intrans': 60017.0,
#   'trans': 1315.0,
#   'xtrans': 0.0,
#   'ditrans': 19.0,
#   'total': 61351.0,
#   'percent_intrans': 0.9782562631415952,
#   'percent_trans': 0.02143404345487441,
#   'percent_ditrans': 0.00030969340353050485},
#  'revolting': {'intrans': 6954.0,
#   'trans': 591.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 7545.0,
#   'percent_intrans': 0.9216699801192842,
#   'percent_trans': 0.07833001988071571,
#   'percent_ditrans': 0.0},
#  'revolts': {'intrans': 1946.0,
#   'trans': 686.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2632.0,
#   'percent_intrans': 0.7393617021276596,
#   'percent_trans': 0.26063829787234044,
#   'percent_ditrans': 0.0},
#  'revolutionize': {'intrans': 1144.0,
#   'trans': 7793.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 8937.0,
#   'percent_intrans': 0.12800716123978964,
#   'percent_trans': 0.8719928387602104,
#   'percent_ditrans': 0.0},
#  'revolutionized': {'intrans': 4112.0,
#   'trans': 2813.0,
#   'xtrans': 0.0,
# ...
#   'trans': 3613.0,
#   'xtrans': 0.0,
#   'ditrans': 33.0,
#   'total': 22953.0,
#   'percent_intrans': 0.8411536618306975,
#   'percent_trans': 0.1574086176098985,
#   'percent_ditrans': 0.0014377205594039994},
#  'vacate': {'intrans': 4348.0,
#   'trans': 9221.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 13569.0,
#   'percent_intrans': 0.3204362885990125,
#   'percent_trans': 0.6795637114009876,
#   'percent_ditrans': 0.0},
#  'vacated': {'intrans': 29402.0,
#   'trans': 1284.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 30686.0,
#   'percent_intrans': 0.9581568141823632,
#   'percent_trans': 0.04184318581763671,
#   'percent_ditrans': 0.0},
#  'vacating': {'intrans': 2503.0,
#   'trans': 2937.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 5440.0,
#   'percent_intrans': 0.460110294117647,
#   'percent_trans': 0.539889705882353,
#   'percent_ditrans': 0.0},
#  'vacationing': {'intrans': 2379.0,
#   'trans': 10.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2389.0,
#   'percent_intrans': 0.9958141481791544,
#   'percent_trans': 0.0041858518208455426,
#   'percent_ditrans': 0.0},
#  'vaccinate': {'intrans': 968.0,
#   'trans': 1076.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2044.0,
#   'percent_intrans': 0.4735812133072407,
#   'percent_trans': 0.5264187866927593,
#   'percent_ditrans': 0.0},
#  'vaccinated': {'intrans': 15347.0,
#   'trans': 143.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 15490.0,
#   'percent_intrans': 0.9907682375726276,
#   'percent_trans': 0.009231762427372498,
#   'percent_ditrans': 0.0},
#  'vaccinating': {'intrans': 1694.0,
#   'trans': 512.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2206.0,
#   'percent_intrans': 0.7679057116953762,
#   'percent_trans': 0.2320942883046237,
#   'percent_ditrans': 0.0},
#  'vacillating': {'intrans': 8835.0,
#   'trans': 371.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 9206.0,
#   'percent_intrans': 0.9597001955246578,
#   'percent_trans': 0.04029980447534217,
#   'percent_ditrans': 0.0},
#  'vacuolated': {'intrans': 5981.0,
#   'trans': 0.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 5981.0,
#   'percent_intrans': 1.0,
#   'percent_trans': 0.0,
#   'percent_ditrans': 0.0},
#  'vacuum': {'intrans': 1439.0,
#   'trans': 747.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2186.0,
#   'percent_intrans': 0.6582799634034767,
#   'percent_trans': 0.3417200365965233,
#   'percent_ditrans': 0.0},
#  'vain': {'intrans': 2396.0,
#   'trans': 788.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3184.0,
#   'percent_intrans': 0.7525125628140703,
#   'percent_trans': 0.24748743718592964,
#   'percent_ditrans': 0.0},
#  'validate': {'intrans': 4635.0,
#   'trans': 7584.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 12219.0,
#   'percent_intrans': 0.3793272771912595,
#   'percent_trans': 0.6206727228087405,
#   'percent_ditrans': 0.0},
#  'validated': {'intrans': 15518.0,
#   'trans': 52.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 15570.0,
#   'percent_intrans': 0.996660244059088,
#   'percent_trans': 0.0033397559409120104,
#   'percent_ditrans': 0.0},
#  'validating': {'intrans': 6389.0,
#   'trans': 2964.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 9353.0,
#   'percent_intrans': 0.6830963327274672,
#   'percent_trans': 0.3169036672725329,
#   'percent_ditrans': 0.0},
#  'valleys': {'intrans': 3192.0,
#   'trans': 347.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3539.0,
#   'percent_intrans': 0.9019497033060186,
#   'percent_trans': 0.09805029669398137,
#   'percent_ditrans': 0.0},
#  'value': {'intrans': 31325.0,
#   'trans': 50942.0,
#   'xtrans': 0.0,
#   'ditrans': 446.0,
#   'total': 82713.0,
#   'percent_intrans': 0.3787191856177384,
#   'percent_trans': 0.6158886752989252,
#   'percent_ditrans': 0.005392139083336356},
#  'valued': {'intrans': 354322.0,
#   'trans': 18154.0,
#   'xtrans': 17.0,
#   'ditrans': 107.0,
#   'total': 372600.0,
#   'percent_intrans': 0.9509447128287708,
#   'percent_trans': 0.048722490606548575,
#   'percent_ditrans': 0.0002871712292002147},
#  'values': {'intrans': 9457.0,
#   'trans': 7547.0,
#   'xtrans': 21.0,
#   'ditrans': 0.0,
#   'total': 17025.0,
#   'percent_intrans': 0.5554772393538914,
#   'percent_trans': 0.4432892804698972,
#   'percent_ditrans': 0.0},
#  'valuing': {'intrans': 9310.0,
#   'trans': 8921.0,
#   'xtrans': 0.0,
#   'ditrans': 39.0,
#   'total': 18270.0,
#   'percent_intrans': 0.5095785440613027,
#   'percent_trans': 0.4882868089764642,
#   'percent_ditrans': 0.002134646962233169},
#  'vanish': {'intrans': 62003.0,
#   'trans': 791.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 62794.0,
#   'percent_intrans': 0.9874032550880656,
#   'percent_trans': 0.012596744911934259,
#   'percent_ditrans': 0.0},
#  'vanished': {'intrans': 184043.0,
#   'trans': 1457.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 185500.0,
#   'percent_intrans': 0.9921455525606468,
#   'percent_trans': 0.0078544474393531,
#   'percent_ditrans': 0.0},
#  'vanishes': {'intrans': 23156.0,
#   'trans': 466.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 23622.0,
#   'percent_intrans': 0.9802726272119212,
#   'percent_trans': 0.019727372788078908,
#   'percent_ditrans': 0.0},
#  'vanishing': {'intrans': 84000.0,
#   'trans': 3832.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 87832.0,
#   'percent_intrans': 0.9563712542125876,
#   'percent_trans': 0.04362874578741233,
#   'percent_ditrans': 0.0},
#  'vanquish': {'intrans': 4980.0,
#   'trans': 6506.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 11486.0,
#   'percent_intrans': 0.43357130419641293,
#   'percent_trans': 0.566428695803587,
#   'percent_ditrans': 0.0},
#  'vanquished': {'intrans': 100288.0,
#   'trans': 9931.0,
#   'xtrans': 76.0,
#   'ditrans': 0.0,
#   'total': 110295.0,
#   'percent_intrans': 0.9092705925019268,
#   'percent_trans': 0.09004034634389592,
#   'percent_ditrans': 0.0},
#  'vanquishing': {'intrans': 1026.0,
#   'trans': 2847.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3873.0,
#   'percent_intrans': 0.26491092176607284,
#   'percent_trans': 0.7350890782339272,
#   'percent_ditrans': 0.0},
#  'vapor': {'intrans': 2456.0,
#   'trans': 422.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2878.0,
#   'percent_intrans': 0.8533703961084086,
#   'percent_trans': 0.14662960389159138,
#   'percent_ditrans': 0.0},
#  'vaporize': {'intrans': 1674.0,
#   'trans': 1684.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3358.0,
#   'percent_intrans': 0.498511018463371,
#   'percent_trans': 0.5014889815366289,
#   'percent_ditrans': 0.0},
#  'vaporized': {'intrans': 8804.0,
#   'trans': 11.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 8815.0,
#   'percent_intrans': 0.9987521270561542,
#   'percent_trans': 0.0012478729438457176,
#   'percent_ditrans': 0.0},
#  'vaporizing': {'intrans': 3115.0,
#   'trans': 664.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3779.0,
#   'percent_intrans': 0.8242921407779836,
#   'percent_trans': 0.1757078592220164,
#   'percent_ditrans': 0.0},
#  'vapour': {'intrans': 2006.0,
#   'trans': 187.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2193.0,
#   'percent_intrans': 0.9147286821705426,
#   'percent_trans': 0.08527131782945736,
#   'percent_ditrans': 0.0},
#  'variation': {'intrans': 6819.0,
#   'trans': 41.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 6860.0,
#   'percent_intrans': 0.9940233236151604,
#   'percent_trans': 0.00597667638483965,
#   'percent_ditrans': 0.0},
#  'varied': {'intrans': 271084.0,
#   'trans': 5098.0,
#   'xtrans': 0.0,
#   'ditrans': 12.0,
#   'total': 276194.0,
#   'percent_intrans': 0.9814985119155376,
#   'percent_trans': 0.0184580403629333,
#   'percent_ditrans': 4.3447721529070147e-05},
#  'variegated': {'intrans': 15740.0,
#   'trans': 78.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 15818.0,
#   'percent_intrans': 0.9950689088380328,
#   'percent_trans': 0.004931091161967379,
#   'percent_ditrans': 0.0},
#  'varies': {'intrans': 99201.0,
#   'trans': 6119.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 105320.0,
#   'percent_intrans': 0.9419008735282948,
#   'percent_trans': 0.05809912647170527,
#   'percent_ditrans': 0.0},
#  'varnished': {'intrans': 19704.0,
#   'trans': 381.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 20085.0,
#   'percent_intrans': 0.9810306198655712,
#   'percent_trans': 0.01896938013442868,
#   'percent_ditrans': 0.0},
#  'varnishing': {'intrans': 5634.0,
#   'trans': 812.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 6446.0,
#   'percent_intrans': 0.8740304064536146,
#   'percent_trans': 0.12596959354638534,
#   'percent_ditrans': 0.0},
#  'vary': {'intrans': 182776.0,
#   'trans': 49735.0,
#   'xtrans': 0.0,
#   'ditrans': 56.0,
#   'total': 232567.0,
#   'percent_intrans': 0.7859068569487503,
#   'percent_trans': 0.2138523522253802,
#   'percent_ditrans': 0.0002407908258695344},
#  'varying': {'intrans': 1182251.0,
#   'trans': 126957.0,
#   'xtrans': 0.0,
#   'ditrans': 253.0,
#   'total': 1309461.0,
#   'percent_intrans': 0.9028531586660464,
#   'percent_trans': 0.0969536320669344,
#   'percent_ditrans': 0.00019320926701902542},
#  'vascular': {'intrans': 1600.0,
#   'trans': 5565.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 7165.0,
#   'percent_intrans': 0.22330774598743894,
#   'percent_trans': 0.7766922540125608,
#   'percent_ditrans': 0.0},
#  'vascularized': {'intrans': 7241.0,
#   'trans': 27.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 7268.0,
#   'percent_intrans': 0.9962850853054486,
#   'percent_trans': 0.0037149146945514586,
#   'percent_ditrans': 0.0},
#  'vaulted': {'intrans': 10611.0,
#   'trans': 640.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 11251.0,
#   'percent_intrans': 0.943116167451782,
#   'percent_trans': 0.05688383254821794,
#   'percent_ditrans': 0.0},
#  'vaulting': {'intrans': 14444.0,
#   'trans': 1092.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 15536.0,
#   'percent_intrans': 0.9297116374871268,
#   'percent_trans': 0.07028836251287332,
#   'percent_ditrans': 0.0},
#  'vaunt': {'intrans': 955.0,
#   'trans': 1345.0,
#   'xtrans': 0.0,
#   'ditrans': 57.0,
#   'total': 2357.0,
#   'percent_intrans': 0.4051760712770471,
#   'percent_trans': 0.5706406448875689,
#   'percent_ditrans': 0.024183283835383963},
#  'vaunted': {'intrans': 7032.0,
#   'trans': 688.0,
#   'xtrans': 0.0,
#   'ditrans': 36.0,
#   'total': 7756.0,
#   'percent_intrans': 0.9066529138731304,
#   'percent_trans': 0.0887055183084064,
#   'percent_ditrans': 0.0046415678184631255},
#  'vaunting': {'intrans': 6598.0,
#   'trans': 845.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 7443.0,
#   'percent_intrans': 0.8864705092032783,
#   'percent_trans': 0.11352949079672175,
#   'percent_ditrans': 0.0},
#  've': {'intrans': 6216.0,
#   'trans': 1544.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 7760.0,
#   'percent_intrans': 0.8010309278350516,
#   'percent_trans': 0.19896907216494844,
#   'percent_ditrans': 0.0},
#  'ved': {'intrans': 2293.0,
#   'trans': 39.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2332.0,
#   'percent_intrans': 0.9832761578044596,
#   'percent_trans': 0.01672384219554031,
#   'percent_ditrans': 0.0},
#  'veer': {'intrans': 2167.0,
#   'trans': 255.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2422.0,
#   'percent_intrans': 0.8947151114781172,
#   'percent_trans': 0.10528488852188274,
#   'percent_ditrans': 0.0},
#  'veered': {'intrans': 2736.0,
#   'trans': 292.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3028.0,
#   'percent_intrans': 0.903566710700132,
#   'percent_trans': 0.0964332892998679,
#   'percent_ditrans': 0.0},
#  'veering': {'intrans': 3513.0,
#   'trans': 146.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3659.0,
#   'percent_intrans': 0.9600983875375786,
#   'percent_trans': 0.039901612462421424,
#   'percent_ditrans': 0.0},
#  'vegetate': {'intrans': 5821.0,
#   'trans': 43.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 5864.0,
#   'percent_intrans': 0.9926671214188268,
#   'percent_trans': 0.007332878581173261,
#   'percent_ditrans': 0.0},
#  'vegetated': {'intrans': 2209.0,
#   'trans': 13.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2222.0,
#   'percent_intrans': 0.994149414941494,
#   'percent_trans': 0.00585058505850585,
#   'percent_ditrans': 0.0},
#  'vegetating': {'intrans': 3201.0,
#   'trans': 62.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 3263.0,
#   'percent_intrans': 0.9809990806006742,
#   'percent_trans': 0.019000919399325772,
#   'percent_ditrans': 0.0},
#  'vegetation': {'intrans': 5872.0,
#   'trans': 133.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 6005.0,
#   'percent_intrans': 0.9778517901748542,
#   'percent_trans': 0.02214820982514571,
#   'percent_ditrans': 0.0},
#  'veiled': {'intrans': 47367.0,
#   'trans': 3821.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 51188.0,
#   'percent_intrans': 0.9253535984996484,
#   'percent_trans': 0.07464640150035165,
#   'percent_ditrans': 0.0},
#  'veiling': {'intrans': 2807.0,
#   'trans': 3840.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 6647.0,
#   'percent_intrans': 0.4222957725289605,
#   'percent_trans': 0.5777042274710396,
#   'percent_ditrans': 0.0},
#  'veined': {'intrans': 9596.0,
#   'trans': 159.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 9755.0,
#   'percent_intrans': 0.9837006663249616,
#   'percent_trans': 0.01629933367503844,
#   'percent_ditrans': 0.0},
#  'vend': {'intrans': 921.0,
#   'trans': 1213.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2134.0,
#   'percent_intrans': 0.43158388003748827,
#   'percent_trans': 0.5684161199625117,
#   'percent_ditrans': 0.0},
#  'vending': {'intrans': 6519.0,
#   'trans': 1463.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 7982.0,
#   'percent_intrans': 0.8167126033575545,
#   'percent_trans': 0.1832873966424455,
#   'percent_ditrans': 0.0},
#  'veneered': {'intrans': 2211.0,
#   'trans': 0.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 2211.0,
#   'percent_intrans': 1.0,
#   'percent_trans': 0.0,
#   'percent_ditrans': 0.0},
#  'venerate': {'intrans': 5024.0,
#   'trans': 5175.0,
#   'xtrans': 0.0,
#   'ditrans': 38.0,
#   'total': 10237.0,
#   'percent_intrans': 0.49076877991599105,
#   'percent_trans': 0.5055191950766826,
#   'percent_ditrans': 0.0037120250073263646},
#  'venerated': {'intrans': 20168.0,
#   'trans': 1789.0,
#   'xtrans': 10.0,
#   'ditrans': 0.0,
#   'total': 21967.0,
#   'percent_intrans': 0.9181044293713296,
#   'percent_trans': 0.08144034233167934,
#   'percent_ditrans': 0.0},
#  'vent': {'intrans': 18563.0,
#   'trans': 12349.0,
#   'xtrans': 33.0,
#   'ditrans': 74.0,
#   'total': 31019.0,
#   'percent_intrans': 0.5984396660111545,
#   'percent_trans': 0.3981108352944969,
#   'percent_ditrans': 0.0023856346110448434},
#  'vented': {'intrans': 5972.0,
#   'trans': 3351.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 9323.0,
#   'percent_intrans': 0.6405663413064464,
#   'percent_trans': 0.3594336586935536,
#   'percent_ditrans': 0.0},
#  'ventilate': {'intrans': 2252.0,
#   'trans': 3253.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 5505.0,
#   'percent_intrans': 0.4090826521344232,
#   'percent_trans': 0.5909173478655767,
#   'percent_ditrans': 0.0},
#  'ventilated': {'intrans': 37879.0,
#   'trans': 171.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 38050.0,
#   'percent_intrans': 0.9955059132720104,
#   'percent_trans': 0.004494086727989489,
#   'percent_ditrans': 0.0},
#  'ventilating': {'intrans': 12280.0,
#   'trans': 5338.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 17618.0,
#   'percent_intrans': 0.6970144170734476,
#   'percent_trans': 0.3029855829265524,
#   'percent_ditrans': 0.0},
#  'venting': {'intrans': 2851.0,
#   'trans': 5590.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 8441.0,
#   'percent_intrans': 0.33775619002487856,
#   'percent_trans': 0.6622438099751214,
#   'percent_ditrans': 0.0},
#  'venture': {'intrans': 133260.0,
#   'trans': 17059.0,
#   'xtrans': 0.0,
#   'ditrans': 59.0,
#   'total': 150378.0,
#   'percent_intrans': 0.8861668595140246,
#   'percent_trans': 0.1134407958610967,
#   'percent_ditrans': 0.0003923446248786392},
#  'ventured': {'intrans': 101946.0,
#   'trans': 4279.0,
#   'xtrans': 0.0,
#   'ditrans': 14.0,
#   'total': 106239.0,
#   'percent_intrans': 0.9595911106090984,
#   'percent_trans': 0.04027711104208435,
#   'percent_ditrans': 0.00013177834881728933},
#  'venturing': {'intrans': 32200.0,
#   'trans': 3805.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 36005.0,
#   'percent_intrans': 0.8943202333009305,
#   'percent_trans': 0.10567976669906956,
#   'percent_ditrans': 0.0},
#  'ver': {'intrans': 4769.0,
#   'trans': 15.0,
#   'xtrans': 0.0,
#   'ditrans': 0.0,
#   'total': 4784.0,
#   'percent_intrans': 0.9968645484949832,
#   'percent_trans': 0.0031354515050167225,
#   'percent_ditrans': 0.0},
#  ...}

# %%
raw2 = raw2.set_index('Lemma')

# %%
raw2_dic = raw2.to_dict(orient='index')

# %%
raw2_dic
# Out:
# {'work': {'GrandIndex': 1,
#   'Index': 1,
#   'LogFreqHAL': 13.02,
#   'Concreteness': 3.48,
#   'AgeofAcqsn': 5.86,
#   'Database': 'CREA',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.78,
#   'unacc_pb': 0.044,
#   'tr_pb': 0.16,
#   'totalN_pb': 431.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'other - general process',
#   'SemanticType_JB_edit': 'other - general process',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'other',
#   'Typicality_LC': nan,
#   'SemClass_Consensus': 'other',
#   'CONSENSUS_JB': 'other',
#   'SemanticTypeLevin': 'verbs of creating and transformation',
#   'SemanticTypeEntry': '26.5knead',
#   'Percentage_dom_PoS': 0.57,
#   'Length': 4,
#   'Ortho_N': 9,
#   'Phono_N': 25,
#   'OLD': 1.5,
#   'PLD': 1.2,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 633.152,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 521.889,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 2421.1,
#   'N3_F': 1034.67},
#  'go': {'GrandIndex': 2,
#   'Index': 2,
#   'LogFreqHAL': 12.923,
#   'Concreteness': 3.15,
#   'AgeofAcqsn': 3.37,
#   'Database': 'CREA',
#   'Trans_Intrans': 'intransitive only',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative PP arg',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.16,
#   'unacc_pb': 0.43,
#   'tr_pb': 0.02,
#   'totalN_pb': 1029.0,
#   'most_frequent_pb': 'unacc',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unacc',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Achievement',
#   'SemanticType_JB': 'ch of location',
#   'SemanticType_JB_edit': 'ch of location',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'ch of location',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'ch of location',
#   'CONSENSUS_JB': 'ch of location',
#   'SemanticTypeLevin': 'verbs of existence, verbs of motion',
#   'SemanticTypeEntry': '47.7meander, 51.1advance',
#   'Percentage_dom_PoS': 0.98,
#   'Length': 2,
#   'Ortho_N': 17,
#   'Phono_N': 48,
#   'OLD': 1.35,
#   'PLD': 1.0,
#   'NPhon': 2,
#   'NSyll': 1,
#   'I_Mean_RT': 597.688,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 524.071,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 974.49,
#   'N3_F': nan},
#  'run': {'GrandIndex': 3,
#   'Index': 3,
#   'LogFreqHAL': 12.316,
#   'Concreteness': 4.31,
#   'AgeofAcqsn': 4.47,
#   'Database': 'CREA',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.18,
#   'unacc_pb': 0.34,
#   'tr_pb': 0.44,
#   'totalN_pb': 374.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'body mvt or posture',
#   'SemanticType_JB_edit': 'body movement or posture',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'manner of motion',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'manner of motion',
#   'CONSENSUS_JB': 'manner of motion',
#   'SemanticTypeLevin': 'verbs of creating and transformation, verbs of existence, verbs of existence, verbs of motion',
#   'SemanticTypeEntry': '26.3prepare, 47.5.1swarm, 47.7meander, 51.3.2run',
#   'Percentage_dom_PoS': 0.89,
#   'Length': 3,
#   'Ortho_N': 19,
#   'Phono_N': 40,
#   'OLD': 1.0,
#   'PLD': 1.0,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 596.647,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 559.955,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 386.53,
#   'N3_F': 229.7},
#  'play': {'GrandIndex': 4,
#   'Index': 4,
#   'LogFreqHAL': 11.915,
#   'Concreteness': 3.24,
#   'AgeofAcqsn': 4.1,
#   'Database': 'CREA',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative, transitive',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.097,
#   'unacc_pb': 0.15,
#   'tr_pb': 0.72,
#   'totalN_pb': 186.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': 0.33,
#   'tr_g': 0.57,
#   'totalN_g': 150.0,
#   'most_frequent_g': 'tr',
#   'Note': nan,
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': 'transitive',
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'social event',
#   'SemanticType_JB_edit': 'social event',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'social or interpersonal event',
#   'Typicality_LC': 3.0,
#   'SemClass_Consensus': 'social or interpersonal event',
#   'CONSENSUS_JB': 'social or interpersonal event',
#   'SemanticTypeLevin': 'verbs of creating and transformation, verbs of social interaction',
#   'SemanticTypeEntry': '26.7perform, 36.3meet',
#   'Percentage_dom_PoS': 0.81,
#   'Length': 4,
#   'Ortho_N': 6,
#   'Phono_N': 15,
#   'OLD': 1.45,
#   'PLD': 1.1,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 537.909,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 566.077,
#   'I_NMG_Mean_Accuracy': 0.963,
#   'N2_F': 781.22,
#   'N3_F': 329.47},
#  'live': {'GrandIndex': 5,
#   'Index': 5,
#   'LogFreqHAL': 11.763,
#   'Concreteness': 3.57,
#   'AgeofAcqsn': 6.1,
#   'Database': 'CREA',
#   'Trans_Intrans': 'intransitive only',
#   'SynClassLitrt': 'unergative/unaccusative',
#   'SynClassMemo': 'unergative PP arg',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.95,
#   'unacc_pb': 0.0078,
#   'tr_pb': 0.047,
#   'totalN_pb': 129.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'State',
#   'SemanticType_JB': 'existence',
#   'SemanticType_JB_edit': 'existence',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'existence',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'existence',
#   'CONSENSUS_JB': 'existence',
#   'SemanticTypeLevin': 'verbs of ingesting, lodge verbs, verbs of existence',
#   'SemanticTypeEntry': '39.6gorge, 46lodge, 47.1exist',
#   'Percentage_dom_PoS': 0.89,
#   'Length': 4,
#   'Ortho_N': 16,
#   'Phono_N': 21,
#   'OLD': 1.15,
#   'PLD': 1.25,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 629.886,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 553.769,
#   'I_NMG_Mean_Accuracy': 0.963,
#   'N2_F': 3645.64,
#   'N3_F': 606.44},
#  'leave': {'GrandIndex': 6,
#   'Index': 6,
#   'LogFreqHAL': 11.245,
#   'Concreteness': 2.53,
#   'AgeofAcqsn': 5.58,
#   'Database': 'CREA',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative PP arg, transitive',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.13,
#   'unacc_pb': 0.088,
#   'tr_pb': 0.4,
#   'totalN_pb': 354.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': 0.1,
#   'tr_g': 0.49,
#   'totalN_g': 200.0,
#   'most_frequent_g': 'tr',
#   'Note': 'polysemous',
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': 'transitive',
#   'AspClass_Consensus': 'Achievement',
#   'SemanticType_JB': 'ch of location',
#   'SemanticType_JB_edit': 'ch of location',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'ch of location',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'ch of location',
#   'CONSENSUS_JB': 'ch of location',
#   'SemanticTypeLevin': 'verbs of change of possession, verbs of change of possession, verbs of change of possession, hold and keep verbs, verbs of motion, verbs of motion',
#   'SemanticTypeEntry': '13.3FUT:have, 13.4.1entrust, 13.5.1get, 15.2keep, 51.1advance, 51.2abandon',
#   'Percentage_dom_PoS': 0.97,
#   'Length': 5,
#   'Ortho_N': 4,
#   'Phono_N': 33,
#   'OLD': 1.7,
#   'PLD': 1.0,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 565.818,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 617.846,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 1630.15,
#   'N3_F': 502.36},
#  'speak': {'GrandIndex': 7,
#   'Index': 7,
#   'LogFreqHAL': 10.891,
#   'Concreteness': 3.7,
#   'AgeofAcqsn': 3.56,
#   'Database': 'CREA',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative, transitive',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.87,
#   'unacc_pb': nan,
#   'tr_pb': 0.13,
#   'totalN_pb': 69.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'communication',
#   'SemanticType_JB_edit': 'communication',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'communication',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'communication',
#   'CONSENSUS_JB': 'communication',
#   'SemanticTypeLevin': 'verbs of communication',
#   'SemanticTypeEntry': '37.5talk',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 5,
#   'Ortho_N': 4,
#   'Phono_N': 12,
#   'OLD': 1.7,
#   'PLD': 1.3,
#   'NPhon': 4,
#   'NSyll': 1,
#   'I_Mean_RT': 598.719,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 645.13,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 973.45,
#   'N3_F': 284.91},
#  'listen': {'GrandIndex': 8,
#   'Index': 8,
#   'LogFreqHAL': 10.432,
#   'Concreteness': 3.47,
#   'AgeofAcqsn': 5.4,
#   'Database': 'CREA',
#   'Trans_Intrans': 'intransitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative PP arg',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.91,
#   'unacc_pb': nan,
#   'tr_pb': 0.088,
#   'totalN_pb': 34.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'perception',
#   'SemanticType_JB_edit': 'perception',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'perception',
#   'Typicality_LC': 4.0,
#   'SemClass_Consensus': 'perception',
#   'CONSENSUS_JB': 'perception',
#   'SemanticTypeLevin': 'verbs of perception, verbs of searching',
#   'SemanticTypeEntry': '30.3peer, 35.5rummage',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 6,
#   'Ortho_N': 2,
#   'Phono_N': 6,
#   'OLD': 1.85,
#   'PLD': 1.65,
#   'NPhon': 4,
#   'NSyll': 2,
#   'I_Mean_RT': 526.455,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 576.52,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 1596.62,
#   'N3_F': 306.11},
#  'walk': {'GrandIndex': 9,
#   'Index': 9,
#   'LogFreqHAL': 10.407,
#   'Concreteness': 4.07,
#   'AgeofAcqsn': 3.45,
#   'Database': 'CREA',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.88,
#   'unacc_pb': nan,
#   'tr_pb': 0.1,
#   'totalN_pb': 48.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'body mvt or posture',
#   'SemanticType_JB_edit': 'body movement or posture',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'body movement or posture',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'manner of motion',
#   'CONSENSUS_JB': 'manner of motion',
#   'SemanticTypeLevin': 'verbs of motion',
#   'SemanticTypeEntry': '51.3.2run',
#   'Percentage_dom_PoS': 0.79,
#   'Length': 4,
#   'Ortho_N': 9,
#   'Phono_N': 17,
#   'OLD': 1.7,
#   'PLD': 1.25,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 580.576,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 540.607,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 1288.42,
#   'N3_F': 315.7},
#  'cross': {'GrandIndex': 10,
#   'Index': 10,
#   'LogFreqHAL': 10.301,
#   'Concreteness': 4.44,
#   'AgeofAcqsn': 4.74,
#   'Database': 'CREA',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative, unaccusative, transitive',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.16,
#   'unacc_pb': 0.04,
#   'tr_pb': 0.8,
#   'totalN_pb': 25.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': 'transitive',
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'ch of location',
#   'SemanticType_JB_edit': 'ch of location',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'ch of location',
#   'Typicality_LC': 3.0,
#   'SemClass_Consensus': 'ch of location',
#   'CONSENSUS_JB': 'ch of location',
#   'SemanticTypeLevin': 'verbs of involving the body, verbs of existence, verbs of motion',
#   'SemanticTypeEntry': '40.3.2crane, 47.8hug, 51.1advance',
#   'Percentage_dom_PoS': 0.55,
#   'Length': 5,
#   'Ortho_N': 6,
#   'Phono_N': 11,
#   'OLD': 1.7,
#   'PLD': 1.75,
#   'NPhon': 4,
#   'NSyll': 1,
#   'I_Mean_RT': 558.906,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 557.964,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 1196.16,
#   'N3_F': 119.56},
#  'fly': {'GrandIndex': 11,
#   'Index': 11,
#   'LogFreqHAL': 10.289,
#   'Concreteness': 4.64,
#   'AgeofAcqsn': 3.05,
#   'Database': 'CREA',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative, unaccusative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.024,
#   'unacc_pb': 0.78,
#   'tr_pb': 0.2,
#   'totalN_pb': 82.0,
#   'most_frequent_pb': 'unacc',
#   'intr_g': 0.6,
#   'tr_g': 0.075,
#   'totalN_g': 200.0,
#   'most_frequent_g': 'intr',
#   'Note': nan,
#   'SynClassCorpus': 'unacc',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'manner of motion',
#   'SemanticType_JB_edit': 'manner of motion',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'manner of motion',
#   'Typicality_LC': 3.0,
#   'SemClass_Consensus': 'manner of motion',
#   'CONSENSUS_JB': 'manner of motion',
#   'SemanticTypeLevin': 'verbs of sending and carrying, verbs of existence, verbs of motion, verbs of motion',
#   'SemanticTypeEntry': '11.5drive, 47.6balance, 51.3.2run, 51.4.2pedal',
#   'Percentage_dom_PoS': 0.81,
#   'Length': 3,
#   'Ortho_N': 7,
#   'Phono_N': 15,
#   'OLD': 1.75,
#   'PLD': 1.25,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 541.697,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 598.25,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 58.84,
#   'N3_F': 52.95},
#  'sleep': {'GrandIndex': 12,
#   'Index': 12,
#   'LogFreqHAL': 10.151,
#   'Concreteness': 4.44,
#   'AgeofAcqsn': 2.79,
#   'Database': 'CREA',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 1.0,
#   'unacc_pb': nan,
#   'tr_pb': nan,
#   'totalN_pb': 16.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'body process',
#   'SemanticType_JB_edit': 'body process',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'body process',
#   'Typicality_LC': 4.0,
#   'SemClass_Consensus': 'body process',
#   'CONSENSUS_JB': 'body process',
#   'SemanticTypeLevin': 'verbs of involving the body, measure verbs',
#   'SemanticTypeEntry': '40.4snooze, 54.3fit',
#   'Percentage_dom_PoS': 0.65,
#   'Length': 5,
#   'Ortho_N': 6,
#   'Phono_N': 12,
#   'OLD': 1.5,
#   'PLD': 1.2,
#   'NPhon': 4,
#   'NSyll': 1,
#   'I_Mean_RT': 553.629,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 638.333,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 567.81,
#   'N3_F': 176.46},
#  'laugh': {'GrandIndex': 13,
#   'Index': 13,
#   'LogFreqHAL': 9.507,
#   'Concreteness': 4.21,
#   'AgeofAcqsn': 3.79,
#   'Database': 'CREA',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.85,
#   'unacc_pb': nan,
#   'tr_pb': nan,
#   'totalN_pb': 13.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'oral sound production',
#   'SemanticType_JB_edit': 'oral sound production',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'oral sound production',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'oral sound production',
#   'CONSENSUS_JB': 'oral sound production',
#   'SemanticTypeLevin': 'verbs of involving the body',
#   'SemanticTypeEntry': '40.2beam',
#   'Percentage_dom_PoS': 0.71,
#   'Length': 5,
#   'Ortho_N': 2,
#   'Phono_N': 26,
#   'OLD': 1.95,
#   'PLD': 1.05,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 555.871,
#   'I_Mean_Accuracy': 0.94,
#   'I_NMG_Mean_RT': 564.667,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 425.6,
#   'N3_F': 86.76},
#  'negotiate': {'GrandIndex': 14,
#   'Index': 14,
#   'LogFreqHAL': 8.35,
#   'Concreteness': 2,
#   'AgeofAcqsn': 10.85,
#   'Database': 'CREA',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative?',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.28,
#   'unacc_pb': 0.0099,
#   'tr_pb': 0.0099,
#   'totalN_pb': 101.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'communication',
#   'SemanticType_JB_edit': 'communication',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'social or interpersonal event/communication',
#   'Typicality_LC': 4.0,
#   'SemClass_Consensus': 'social or interpersonal event',
#   'CONSENSUS_JB': 'social or interpersonal event',
#   'SemanticTypeLevin': 'verbs of social interaction',
#   'SemanticTypeEntry': '36.1correspond',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 9,
#   'Ortho_N': 0,
#   'Phono_N': 0,
#   'OLD': 3.25,
#   'PLD': 3.85,
#   'NPhon': 8,
#   'NSyll': 4,
#   'I_Mean_RT': 745.879,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 679.538,
#   'I_NMG_Mean_Accuracy': 0.963,
#   'N2_F': 419.57,
#   'N3_F': 78.68},
#  'shout': {'GrandIndex': 15,
#   'Index': 15,
#   'LogFreqHAL': 8.097,
#   'Concreteness': 4.17,
#   'AgeofAcqsn': 4.72,
#   'Database': 'CREA',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.3,
#   'unacc_pb': nan,
#   'tr_pb': 0.5,
#   'totalN_pb': 20.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'oral sound production',
#   'SemanticType_JB_edit': 'oral sound production',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'oral sound production/communication',
#   'Typicality_LC': 4.0,
#   'SemClass_Consensus': 'oral sound production',
#   'CONSENSUS_JB': 'oral sound production',
#   'SemanticTypeLevin': 'verbs of communication',
#   'SemanticTypeEntry': '37.3snap/cackle',
#   'Percentage_dom_PoS': 0.68,
#   'Length': 5,
#   'Ortho_N': 8,
#   'Phono_N': 18,
#   'OLD': 1.55,
#   'PLD': 1.45,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 619.152,
#   'I_Mean_Accuracy': 0.94,
#   'I_NMG_Mean_RT': 637.107,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 2304.11,
#   'N3_F': 1039.28},
#  'act': {'GrandIndex': 16,
#   'Index': 16,
#   'LogFreqHAL': 11.187,
#   'Concreteness': 2.46,
#   'AgeofAcqsn': 6.42,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative?',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.88,
#   'unacc_pb': 0.019,
#   'tr_pb': 0.087,
#   'totalN_pb': 104.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'other - general process',
#   'SemanticType_JB_edit': 'other - general process',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'other',
#   'Typicality_LC': nan,
#   'SemClass_Consensus': 'other',
#   'CONSENSUS_JB': 'other',
#   'SemanticTypeLevin': 'verbs with predicative complements',
#   'SemanticTypeEntry': '29.6masquerade',
#   'Percentage_dom_PoS': 0.51,
#   'Length': 3,
#   'Ortho_N': 9,
#   'Phono_N': 11,
#   'OLD': 1.5,
#   'PLD': 1.0,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 635.182,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 626.692,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 190.02,
#   'N3_F': 187.94},
#  'jump': {'GrandIndex': 17,
#   'Index': 17,
#   'LogFreqHAL': 10.198,
#   'Concreteness': 4.52,
#   'AgeofAcqsn': 2.84,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.14,
#   'unacc_pb': 0.8,
#   'tr_pb': 0.025,
#   'totalN_pb': 161.0,
#   'most_frequent_pb': 'unacc',
#   'intr_g': 0.6,
#   'tr_g': 0.06,
#   'totalN_g': 200.0,
#   'most_frequent_g': 'intr',
#   'Note': nan,
#   'SynClassCorpus': 'unacc',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Semelfactive',
#   'SemanticType_JB': 'body mvt or posture',
#   'SemanticType_JB_edit': 'body movement or posture',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'body movement or posture',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'body movement or posture',
#   'CONSENSUS_JB': 'body movement or posture',
#   'SemanticTypeLevin': 'verbs of change of state, verbs of motion',
#   'SemanticTypeEntry': '45.6decrease, 51.3.2run',
#   'Percentage_dom_PoS': 0.83,
#   'Length': 4,
#   'Ortho_N': 7,
#   'Phono_N': 9,
#   'OLD': 1.6,
#   'PLD': 1.8,
#   'NPhon': 4,
#   'NSyll': 1,
#   'I_Mean_RT': 626.324,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 576.286,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 588.44,
#   'N3_F': 52.41},
#  'dance': {'GrandIndex': 18,
#   'Index': 18,
#   'LogFreqHAL': 10.171,
#   'Concreteness': 4.32,
#   'AgeofAcqsn': 4.63,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 1.0,
#   'unacc_pb': nan,
#   'tr_pb': nan,
#   'totalN_pb': 5.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': 0.88,
#   'tr_g': 0.062,
#   'totalN_g': 112.0,
#   'most_frequent_g': 'intr',
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'body mvt or posture',
#   'SemanticType_JB_edit': 'body movement or posture',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'body movement or posture',
#   'Typicality_LC': 4.0,
#   'SemClass_Consensus': 'body movement or posture',
#   'CONSENSUS_JB': 'body movement or posture',
#   'SemanticTypeLevin': 'verbs of creating and transformation, verbs of existence, verbs of motion',
#   'SemanticTypeEntry': '26.7perform, 47.3wobble, 51.5waltz',
#   'Percentage_dom_PoS': 0.56,
#   'Length': 5,
#   'Ortho_N': 3,
#   'Phono_N': 8,
#   'OLD': 1.65,
#   'PLD': 1.6,
#   'NPhon': 4,
#   'NSyll': 1,
#   'I_Mean_RT': 530.323,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 572.96,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 1071.06,
#   'N3_F': 263.04},
#  'lie': {'GrandIndex': 19,
#   'Index': 19,
#   'LogFreqHAL': 9.995,
#   'Concreteness': 3.11,
#   'AgeofAcqsn': 3.75,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'intransitive only',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative, unaccusative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.19,
#   'unacc_pb': 0.77,
#   'tr_pb': nan,
#   'totalN_pb': 52.0,
#   'most_frequent_pb': 'unacc',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': 'polysemous',
#   'SynClassCorpus': 'unacc',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'State, Process',
#   'SemanticType_JB': 'existence',
#   'SemanticType_JB_edit': 'existence',
#   'Typicality_JB': 4.0,
#   'SemanticType_LC': 'existence/communication/social/body movement or posture',
#   'Typicality_LC': 2.0,
#   'SemClass_Consensus': 'social or interpersonal event',
#   'CONSENSUS_JB': 'social or interpersonal event',
#   'SemanticTypeLevin': 'verbs of existence, verbs of assuming a position',
#   'SemanticTypeEntry': '47.6balance, 50crouch',
#   'Percentage_dom_PoS': 0.74,
#   'Length': 3,
#   'Ortho_N': 15,
#   'Phono_N': 51,
#   'OLD': 1.05,
#   'PLD': 1.0,
#   'NPhon': 2,
#   'NSyll': 1,
#   'I_Mean_RT': 566.829,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 550.357,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 209.44,
#   'N3_F': 84.3},
#  'cry': {'GrandIndex': 20,
#   'Index': 20,
#   'LogFreqHAL': 9.492,
#   'Concreteness': 4,
#   'AgeofAcqsn': 2.78,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.5,
#   'unacc_pb': nan,
#   'tr_pb': nan,
#   'totalN_pb': 4.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'oral sound production',
#   'SemanticType_JB_edit': 'oral sound production',
#   'Typicality_JB': 3.0,
#   'SemanticType_LC': 'oral sound production/body process',
#   'Typicality_LC': 4.0,
#   'SemClass_Consensus': 'oral sound production',
#   'CONSENSUS_JB': 'oral sound production',
#   'SemanticTypeLevin': 'psych verbs, verbs of communication, verbs of involving the body, verbs of involving the body, verbs of emission',
#   'SemanticTypeEntry': '31.3marvel, 37.3snap/cackle, 40.1.2breathe, 40.2beam, 43.2bang',
#   'Percentage_dom_PoS': 0.78,
#   'Length': 3,
#   'Ortho_N': 7,
#   'Phono_N': 8,
#   'OLD': 1.7,
#   'PLD': 1.15,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 564.97,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 576.269,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 233.75,
#   'N3_F': 52.53},
#  'sing': {'GrandIndex': 21,
#   'Index': 21,
#   'LogFreqHAL': 9.298,
#   'Concreteness': 4.34,
#   'AgeofAcqsn': 3.47,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative, transitive?',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.37,
#   'unacc_pb': 0.11,
#   'tr_pb': 0.47,
#   'totalN_pb': 19.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': 0.6,
#   'tr_g': 0.3,
#   'totalN_g': 115.0,
#   'most_frequent_g': 'intr',
#   'Note': nan,
#   'SynClassCorpus': 'conflict',
#   'SynClassFinal': 'unergative',
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'oral sound production',
#   'SemanticType_JB_edit': 'oral sound production',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'oral sound production',
#   'Typicality_LC': 4.0,
#   'SemClass_Consensus': 'oral sound production',
#   'CONSENSUS_JB': 'oral sound production',
#   'SemanticTypeLevin': 'verbs of creating and transformation, verbs of communication, verbs of sounds made by animals, verbs of emission',
#   'SemanticTypeEntry': '26.7perform, 37.3snap/cackle, 38bark, 43.2bang',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 4,
#   'Ortho_N': 16,
#   'Phono_N': 31,
#   'OLD': 1.0,
#   'PLD': 1.0,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 596.657,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 673.111,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 1539.67,
#   'N3_F': 141.24},
#  'skate': {'GrandIndex': 22,
#   'Index': 22,
#   'LogFreqHAL': 9.243,
#   'Concreteness': 4.56,
#   'AgeofAcqsn': 5.37,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'intransitive only',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': nan,
#   'unacc_pb': nan,
#   'tr_pb': nan,
#   'totalN_pb': nan,
#   'most_frequent_pb': nan,
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'none',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'manner of motion',
#   'SemanticType_JB_edit': 'manner of motion',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'manner of motion',
#   'Typicality_LC': 4.0,
#   'SemClass_Consensus': 'body movement or posture',
#   'CONSENSUS_JB': 'body movement or posture',
#   'SemanticTypeLevin': 'verbs of motion',
#   'SemanticTypeEntry': '51.4.1skate',
#   'Percentage_dom_PoS': 0.73,
#   'Length': 5,
#   'Ortho_N': 3,
#   'Phono_N': 14,
#   'OLD': 1.7,
#   'PLD': 1.35,
#   'NPhon': 4,
#   'NSyll': 1,
#   'I_Mean_RT': 581.03,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 710.75,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 659.16,
#   'N3_F': 122.12},
#  'dive': {'GrandIndex': 23,
#   'Index': 23,
#   'LogFreqHAL': 9.009,
#   'Concreteness': 4.03,
#   'AgeofAcqsn': 7.21,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'intransitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative? unaccusative?',
#   'SynClassSK': 'unergative',
#   'unerg_pb': nan,
#   'unacc_pb': 1.0,
#   'tr_pb': nan,
#   'totalN_pb': 7.0,
#   'most_frequent_pb': 'unacc',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': 'polysemous',
#   'SynClassCorpus': 'unacc',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Achievement',
#   'SemanticType_JB': 'body mvt or posture',
#   'SemanticType_JB_edit': 'body movement or posture',
#   'Typicality_JB': 3.0,
#   'SemanticType_LC': 'body movement or posture',
#   'Typicality_LC': 3.0,
#   'SemClass_Consensus': 'manner of motion',
#   'CONSENSUS_JB': 'manner of motion',
#   'SemanticTypeLevin': 'verbs of searching',
#   'SemanticTypeEntry': '35.2search',
#   'Percentage_dom_PoS': 0.55,
#   'Length': 4,
#   'Ortho_N': 15,
#   'Phono_N': 20,
#   'OLD': 1.1,
#   'PLD': 1.2,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 668.879,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 563.593,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 2598.48,
#   'N3_F': 494.5},
#  'scream': {'GrandIndex': 24,
#   'Index': 24,
#   'LogFreqHAL': 8.914,
#   'Concreteness': 4.32,
#   'AgeofAcqsn': 4.2,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.5,
#   'unacc_pb': nan,
#   'tr_pb': 0.4,
#   'totalN_pb': 10.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'oral sound production',
#   'SemanticType_JB_edit': 'oral sound production',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'oral sound production',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'oral sound production',
#   'CONSENSUS_JB': 'oral sound production',
#   'SemanticTypeLevin': 'verbs of communication, verbs of sounds made by animals, verbs of emission',
#   'SemanticTypeEntry': '37.3snap/cackle, 38bark, 43.2bang',
#   'Percentage_dom_PoS': 0.73,
#   'Length': 6,
#   'Ortho_N': 1,
#   'Phono_N': 7,
#   'OLD': 1.8,
#   'PLD': 1.65,
#   'NPhon': 5,
#   'NSyll': 1,
#   'I_Mean_RT': 607.485,
#   'I_Mean_Accuracy': 0.94,
#   'I_NMG_Mean_RT': 691.583,
#   'I_NMG_Mean_Accuracy': 0.96,
#   'N2_F': 593.13,
#   'N3_F': 110.34},
#  'proceed': {'GrandIndex': 25,
#   'Index': 25,
#   'LogFreqHAL': 8.78,
#   'Concreteness': 2.55,
#   'AgeofAcqsn': 8.33,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'intransitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative?',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.56,
#   'unacc_pb': 0.28,
#   'tr_pb': 0.15,
#   'totalN_pb': 39.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'aspectual',
#   'SemanticType_JB_edit': 'aspectual',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'aspectual',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'aspectual',
#   'CONSENSUS_JB': 'aspectual',
#   'SemanticTypeLevin': 'aspectual verbs',
#   'SemanticTypeEntry': '55.1begin',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 7,
#   'Ortho_N': 0,
#   'Phono_N': 2,
#   'OLD': 2.2,
#   'PLD': 2.45,
#   'NPhon': 6,
#   'NSyll': 2,
#   'I_Mean_RT': 663.086,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 617.808,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 2253.99,
#   'N3_F': 301.13},
#  'hesitate': {'GrandIndex': 26,
#   'Index': 26,
#   'LogFreqHAL': 8.666,
#   'Concreteness': 2.46,
#   'AgeofAcqsn': 8.3,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'intransitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.12,
#   'unacc_pb': nan,
#   'tr_pb': 0.88,
#   'totalN_pb': 8.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': 0.81,
#   'tr_g': 0.0067,
#   'totalN_g': 150.0,
#   'most_frequent_g': 'intr',
#   'Note': 'VP complement',
#   'SynClassCorpus': 'conflict',
#   'SynClassFinal': 'unergative',
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'cognitive event',
#   'SemanticType_JB_edit': 'cognitive event',
#   'Typicality_JB': 4.0,
#   'SemanticType_LC': 'cognitive event',
#   'Typicality_LC': 3.0,
#   'SemClass_Consensus': 'cognitive event',
#   'CONSENSUS_JB': 'cognitive event',
#   'SemanticTypeLevin': 'verbs of lingering and rushing',
#   'SemanticTypeEntry': '53.1linger',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 8,
#   'Ortho_N': 0,
#   'Phono_N': 0,
#   'OLD': 2.45,
#   'PLD': 2.75,
#   'NPhon': 7,
#   'NSyll': 3,
#   'I_Mean_RT': 699.0,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 594.48,
#   'I_NMG_Mean_Accuracy': 0.962,
#   'N2_F': 595.94,
#   'N3_F': 183.59},
#  'behave': {'GrandIndex': 27,
#   'Index': 27,
#   'LogFreqHAL': 8.656,
#   'Concreteness': 1.78,
#   'AgeofAcqsn': 4.28,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative?',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.47,
#   'unacc_pb': nan,
#   'tr_pb': 0.53,
#   'totalN_pb': 19.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'social event',
#   'SemanticType_JB_edit': 'social event',
#   'Typicality_JB': 4.0,
#   'SemanticType_LC': 'other',
#   'Typicality_LC': nan,
#   'SemClass_Consensus': 'other',
#   'CONSENSUS_JB': 'other',
#   'SemanticTypeLevin': 'verbs with predicative complements',
#   'SemanticTypeEntry': '29.6masquerade',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 6,
#   'Ortho_N': 1,
#   'Phono_N': 1,
#   'OLD': 2.15,
#   'PLD': 2.4,
#   'NPhon': 5,
#   'NSyll': 2,
#   'I_Mean_RT': 699.125,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 571.259,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 771.87,
#   'N3_F': 116.65},
#  'swim': {'GrandIndex': 28,
#   'Index': 28,
#   'LogFreqHAL': 8.54,
#   'Concreteness': 4.43,
#   'AgeofAcqsn': 4.17,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 1.0,
#   'unacc_pb': nan,
#   'tr_pb': nan,
#   'totalN_pb': 3.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'body mvt or posture',
#   'SemanticType_JB_edit': 'body movement or posture',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'body movement or posture',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'manner of motion',
#   'CONSENSUS_JB': 'manner of motion',
#   'SemanticTypeLevin': 'verbs of involving the body, verbs of existence, verbs of motion',
#   'SemanticTypeEntry': '40.8.2tingle, 47.5.1swarm, 51.3.2run',
#   'Percentage_dom_PoS': 0.73,
#   'Length': 4,
#   'Ortho_N': 7,
#   'Phono_N': 12,
#   'OLD': 1.7,
#   'PLD': 1.5,
#   'NPhon': 4,
#   'NSyll': 1,
#   'I_Mean_RT': 530.939,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 665.261,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 57.19,
#   'N3_F': 25.08},
#  'hop': {'GrandIndex': 29,
#   'Index': 29,
#   'LogFreqHAL': 8.408,
#   'Concreteness': 3.8,
#   'AgeofAcqsn': 4.84,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative, transitive?',
#   'SynClassSK': 'unergative',
#   'unerg_pb': nan,
#   'unacc_pb': nan,
#   'tr_pb': nan,
#   'totalN_pb': nan,
#   'most_frequent_pb': nan,
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'none',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Semelfactive',
#   'SemanticType_JB': 'body mvt or posture',
#   'SemanticType_JB_edit': 'body movement or posture',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'body movement or posture',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'manner of motion',
#   'CONSENSUS_JB': 'manner of motion',
#   'SemanticTypeLevin': 'verbs of existence, verbs of motion',
#   'SemanticTypeEntry': '47.5.1swarm, 51.3.2run',
#   'Percentage_dom_PoS': 0.83,
#   'Length': 3,
#   'Ortho_N': 21,
#   'Phono_N': 26,
#   'OLD': 1.15,
#   'PLD': 1.15,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 607.606,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 561.679,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 787.83,
#   'N3_F': 5.0},
#  'sail': {'GrandIndex': 30,
#   'Index': 30,
#   'LogFreqHAL': 8.175,
#   'Concreteness': 4.59,
#   'AgeofAcqsn': 6.47,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.67,
#   'unacc_pb': nan,
#   'tr_pb': 0.33,
#   'totalN_pb': 3.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': 0.72,
#   'tr_g': 0.091,
#   'totalN_g': 110.0,
#   'most_frequent_g': 'intr',
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'manner of motion',
#   'SemanticType_JB_edit': 'manner of motion',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'manner of motion',
#   'Typicality_LC': 4.0,
#   'SemClass_Consensus': 'manner of motion',
#   'CONSENSUS_JB': 'manner of motion',
#   'SemanticTypeLevin': 'verbs of motion',
#   'SemanticTypeEntry': '51.4.2pedal',
#   'Percentage_dom_PoS': 0.83,
#   'Length': 4,
#   'Ortho_N': 15,
#   'Phono_N': 47,
#   'OLD': 1.15,
#   'PLD': 1.0,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 598.647,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 594.08,
#   'I_NMG_Mean_Accuracy': 0.962,
#   'N2_F': 2939.86,
#   'N3_F': 1518.11},
#  'yell': {'GrandIndex': 31,
#   'Index': 31,
#   'LogFreqHAL': 8.108,
#   'Concreteness': 3.86,
#   'AgeofAcqsn': 3.83,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.17,
#   'unacc_pb': nan,
#   'tr_pb': 0.5,
#   'totalN_pb': 6.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': 0.94,
#   'tr_g': 0.048,
#   'totalN_g': 105.0,
#   'most_frequent_g': 'intr',
#   'Note': nan,
#   'SynClassCorpus': 'conflict',
#   'SynClassFinal': 'unergative',
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'oral sound production',
#   'SemanticType_JB_edit': 'oral sound production',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'oral sound production',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'oral sound production',
#   'CONSENSUS_JB': 'oral sound production',
#   'SemanticTypeLevin': 'verbs of communication, verbs of sounds made by animals',
#   'SemanticTypeEntry': '37.3snap/cackle, 38bark',
#   'Percentage_dom_PoS': 0.88,
#   'Length': 4,
#   'Ortho_N': 10,
#   'Phono_N': 31,
#   'OLD': 1.55,
#   'PLD': 1.0,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 672.621,
#   'I_Mean_Accuracy': 0.91,
#   'I_NMG_Mean_RT': 592.0,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 2994.24,
#   'N3_F': 921.69},
#  'howl': {'GrandIndex': 32,
#   'Index': 32,
#   'LogFreqHAL': 8.079,
#   'Concreteness': 3.83,
#   'AgeofAcqsn': 5.55,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 1.0,
#   'unacc_pb': nan,
#   'tr_pb': nan,
#   'totalN_pb': 1.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'oral sound production',
#   'SemanticType_JB_edit': 'oral sound production',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'oral sound production',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'oral sound production',
#   'CONSENSUS_JB': 'oral sound production',
#   'SemanticTypeLevin': 'verbs of communication, verbs of sounds made by animals, verbs of involving the body, verbs of emission, weather verbs',
#   'SemanticTypeEntry': '37.3snap/cackle, 38bark, 40.2beam, 43.2bang, 57rain',
#   'Percentage_dom_PoS': 0.65,
#   'Length': 4,
#   'Ortho_N': 6,
#   'Phono_N': 29,
#   'OLD': 1.6,
#   'PLD': 1.5,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 626.848,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 630.593,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 919.52,
#   'N3_F': 19.54},
#  'pee': {'GrandIndex': 33,
#   'Index': 33,
#   'LogFreqHAL': 8.058,
#   'Concreteness': 4.72,
#   'AgeofAcqsn': 3.89,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'intransitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': nan,
#   'unacc_pb': nan,
#   'tr_pb': nan,
#   'totalN_pb': nan,
#   'most_frequent_pb': nan,
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'none',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'body process',
#   'SemanticType_JB_edit': 'body process',
#   'Typicality_JB': 4.0,
#   'SemanticType_LC': 'body process',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'body process',
#   'CONSENSUS_JB': 'body process',
#   'SemanticTypeLevin': 'not found',
#   'SemanticTypeEntry': nan,
#   'Percentage_dom_PoS': 0.75,
#   'Length': 3,
#   'Ortho_N': 22,
#   'Phono_N': 53,
#   'OLD': 1.0,
#   'PLD': 1.0,
#   'NPhon': 2,
#   'NSyll': 1,
#   'I_Mean_RT': 700.156,
#   'I_Mean_Accuracy': 0.94,
#   'I_NMG_Mean_RT': 601.615,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 767.16,
#   'N3_F': 2.56},
#  'crawl': {'GrandIndex': 34,
#   'Index': 34,
#   'LogFreqHAL': 8.049,
#   'Concreteness': 4.27,
#   'AgeofAcqsn': 3.89,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'intransitive only',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 1.0,
#   'unacc_pb': nan,
#   'tr_pb': nan,
#   'totalN_pb': 5.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'body mvt or posture',
#   'SemanticType_JB_edit': 'body movement or posture',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'body movement or posture',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'manner of motion',
#   'CONSENSUS_JB': 'manner of motion',
#   'SemanticTypeLevin': 'verbs of existence, verbs of existence, verbs of motion',
#   'SemanticTypeEntry': '47.5.1swarm, 47.7meander, 51.3.2run',
#   'Percentage_dom_PoS': 0.87,
#   'Length': 5,
#   'Ortho_N': 3,
#   'Phono_N': 8,
#   'OLD': 1.75,
#   'PLD': 1.6,
#   'NPhon': 4,
#   'NSyll': 1,
#   'I_Mean_RT': 612.206,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 631.25,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 473.15,
#   'N3_F': 75.6},
#  'breathe': {'GrandIndex': 35,
#   'Index': 35,
#   'LogFreqHAL': 8.045,
#   'Concreteness': 4.07,
#   'AgeofAcqsn': 4.11,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': 'unergative',
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.62,
#   'unacc_pb': nan,
#   'tr_pb': 0.38,
#   'totalN_pb': 8.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'body mvt or posture',
#   'SemanticType_JB_edit': 'body movement or posture',
#   'Typicality_JB': 3.0,
#   'SemanticType_LC': 'body process',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'body process',
#   'CONSENSUS_JB': 'body process',
#   'SemanticTypeLevin': 'verbs of involving the body, verbs of existence',
#   'SemanticTypeEntry': '40.1.2breathe, 47.2billow',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 7,
#   'Ortho_N': 3,
#   'Phono_N': 7,
#   'OLD': 1.9,
#   'PLD': 1.65,
#   'NPhon': 4,
#   'NSyll': 1,
#   'I_Mean_RT': 661.606,
#   'I_Mean_Accuracy': 1.0,
#   'I_NMG_Mean_RT': 581.296,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 680.62,
#   'N3_F': 197.33},
#  'sneak': {'GrandIndex': 36,
#   'Index': 36,
#   'LogFreqHAL': 7.878,
#   'Concreteness': 2.82,
#   'AgeofAcqsn': 5.83,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative, transitive?',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.75,
#   'unacc_pb': nan,
#   'tr_pb': nan,
#   'totalN_pb': 4.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'body mvt or posture, ch obj loc',
#   'SemanticType_JB_edit': 'body movement or posture, ch obj loc',
#   'Typicality_JB': 2.0,
#   'SemanticType_LC': 'manner of motion',
#   'Typicality_LC': 3.0,
#   'SemClass_Consensus': 'manner of motion',
#   'CONSENSUS_JB': 'manner of motion',
#   'SemanticTypeLevin': 'verbs of removing, verbs of sending and carrying, verbs of motion',
#   'SemanticTypeEntry': '10.5steal, 11.1send, 51.3.2run',
#   'Percentage_dom_PoS': 0.93,
#   'Length': 5,
#   'Ortho_N': 3,
#   'Phono_N': 10,
#   'OLD': 1.8,
#   'PLD': 1.4,
#   'NPhon': 4,
#   'NSyll': 1,
#   'I_Mean_RT': 571.067,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 736.607,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 636.6,
#   'N3_F': 89.38},
#  'wander': {'GrandIndex': 37,
#   'Index': 37,
#   'LogFreqHAL': 7.832,
#   'Concreteness': 2.28,
#   'AgeofAcqsn': 6.89,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.8,
#   'unacc_pb': nan,
#   'tr_pb': 0.2,
#   'totalN_pb': 5.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'body mvt or posture',
#   'SemanticType_JB_edit': 'body movement or posture',
#   'Typicality_JB': 3.0,
#   'SemanticType_LC': 'body movement or posture',
#   'Typicality_LC': 4.0,
#   'SemClass_Consensus': 'manner of motion',
#   'CONSENSUS_JB': 'manner of motion',
#   'SemanticTypeLevin': 'verbs of existence, verbs of motion',
#   'SemanticTypeEntry': '47.7meander, 51.3.2run',
#   'Percentage_dom_PoS': 0.99,
#   'Length': 6,
#   'Ortho_N': 11,
#   'Phono_N': 7,
#   'OLD': 1.55,
#   'PLD': 1.55,
#   'NPhon': 5,
#   'NSyll': 2,
#   'I_Mean_RT': 707.586,
#   'I_Mean_Accuracy': 0.88,
#   'I_NMG_Mean_RT': 613.731,
#   'I_NMG_Mean_Accuracy': 0.963,
#   'N2_F': 2277.36,
#   'N3_F': 309.32},
#  'moan': {'GrandIndex': 38,
#   'Index': 38,
#   'LogFreqHAL': 7.669,
#   'Concreteness': 3.72,
#   'AgeofAcqsn': 7.72,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative?',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.67,
#   'unacc_pb': nan,
#   'tr_pb': 0.33,
#   'totalN_pb': 3.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'oral sound production',
#   'SemanticType_JB_edit': 'oral sound production',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'oral sound production',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'oral sound production',
#   'CONSENSUS_JB': 'oral sound production',
#   'SemanticTypeLevin': 'verbs of communication, verbs of involving the body, verbs of emission',
#   'SemanticTypeEntry': '37.3snap/cackle, 40.2beam, 43.2bang',
#   'Percentage_dom_PoS': 0.55,
#   'Length': 4,
#   'Ortho_N': 11,
#   'Phono_N': 44,
#   'OLD': 1.65,
#   'PLD': 1.0,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 690.5,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 620.5,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 2223.42,
#   'N3_F': 15.11},
#  'nod': {'GrandIndex': 39,
#   'Index': 39,
#   'LogFreqHAL': 7.665,
#   'Concreteness': 4.62,
#   'AgeofAcqsn': 5.62,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'both',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'unergative',
#   'SynClassSK': 'unergative',
#   'unerg_pb': 0.5,
#   'unacc_pb': nan,
#   'tr_pb': 0.5,
#   'totalN_pb': 2.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'unerg',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Semelfactive',
#   'SemanticType_JB': 'body mvt or posture',
#   'SemanticType_JB_edit': 'body movement or posture',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'body movement or posture',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'body movement or posture',
#   'CONSENSUS_JB': 'body movement or posture',
#   'SemanticTypeLevin': 'verbs of involving the body',
#   'SemanticTypeEntry': '40.3.1wink',
#   'Percentage_dom_PoS': 0.61,
#   'Length': 3,
#   'Ortho_N': 18,
#   'Phono_N': 35,
#   'OLD': 1.35,
#   'PLD': 1.0,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 663.129,
#   'I_Mean_Accuracy': 0.89,
#   'I_NMG_Mean_RT': 595.966,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 3641.82,
#   'N3_F': 11.72},
#  'blink': {'GrandIndex': 40,
#   'Index': 40,
#   'LogFreqHAL': 7.629,
# ...
#   'SynClassSK': 'transitive',
#   'unerg_pb': 0.2,
#   'unacc_pb': nan,
#   'tr_pb': 0.8,
#   'totalN_pb': 5.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'social event',
#   'SemanticType_JB_edit': 'social event',
#   'Typicality_JB': 4.0,
#   'SemanticType_LC': 'social or interpersonal event',
#   'Typicality_LC': 2.0,
#   'SemClass_Consensus': 'social or interpersonal event',
#   'CONSENSUS_JB': 'social or interpersonal event',
#   'SemanticTypeLevin': 'avoid verbs',
#   'SemanticTypeEntry': '52avoid',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 5,
#   'Ortho_N': 0,
#   'Phono_N': 0,
#   'OLD': 1.9,
#   'PLD': 1.9,
#   'NPhon': 4,
#   'NSyll': 2,
#   'I_Mean_RT': 683.613,
#   'I_Mean_Accuracy': 0.89,
#   'I_NMG_Mean_RT': 621.692,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 392.03,
#   'N3_F': 76.11},
#  'loathe': {'GrandIndex': 433,
#   'Index': 167,
#   'LogFreqHAL': 6.663,
#   'Concreteness': 2.04,
#   'AgeofAcqsn': 11.12,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'transitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'transitive',
#   'SynClassSK': 'transitive',
#   'unerg_pb': nan,
#   'unacc_pb': 0.5,
#   'tr_pb': 0.5,
#   'totalN_pb': 2.0,
#   'most_frequent_pb': 'unacc',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': 'psych',
#   'SynClassCorpus': 'unacc',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'State',
#   'SemanticType_JB': 'emotion',
#   'SemanticType_JB_edit': 'emotion',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'emotion',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'emotion',
#   'CONSENSUS_JB': 'emotion',
#   'SemanticTypeLevin': 'psych verbs',
#   'SemanticTypeEntry': '31.2admire',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 6,
#   'Ortho_N': 0,
#   'Phono_N': 16,
#   'OLD': 1.95,
#   'PLD': 1.25,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 677.069,
#   'I_Mean_Accuracy': 0.91,
#   'I_NMG_Mean_RT': 607.538,
#   'I_NMG_Mean_Accuracy': 0.929,
#   'N2_F': 496.18,
#   'N3_F': 17.94},
#  'relish': {'GrandIndex': 434,
#   'Index': 168,
#   'LogFreqHAL': 6.645,
#   'Concreteness': 3.3,
#   'AgeofAcqsn': 7.83,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'transitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'transitive',
#   'SynClassSK': 'transitive',
#   'unerg_pb': nan,
#   'unacc_pb': nan,
#   'tr_pb': 1.0,
#   'totalN_pb': 3.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'State',
#   'SemanticType_JB': 'emotion',
#   'SemanticType_JB_edit': 'emotion',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'emotion',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'emotion',
#   'CONSENSUS_JB': 'emotion',
#   'SemanticTypeLevin': 'psych verbs',
#   'SemanticTypeEntry': '31.2admire',
#   'Percentage_dom_PoS': 0.6,
#   'Length': 6,
#   'Ortho_N': 0,
#   'Phono_N': 4,
#   'OLD': 2.0,
#   'PLD': 1.85,
#   'NPhon': 5,
#   'NSyll': 2,
#   'I_Mean_RT': 695.656,
#   'I_Mean_Accuracy': 0.94,
#   'I_NMG_Mean_RT': 613.769,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 894.63,
#   'N3_F': 118.66},
#  'enrich': {'GrandIndex': 435,
#   'Index': 169,
#   'LogFreqHAL': 6.619,
#   'Concreteness': 2,
#   'AgeofAcqsn': 10.89,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'transitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'transitive',
#   'SynClassSK': 'transitive',
#   'unerg_pb': nan,
#   'unacc_pb': nan,
#   'tr_pb': 1.0,
#   'totalN_pb': 2.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'ch of state',
#   'SemanticType_JB_edit': 'ch of state',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'ch of state (result)',
#   'Typicality_LC': 2.0,
#   'SemClass_Consensus': 'ch of state',
#   'CONSENSUS_JB': 'ch of state',
#   'SemanticTypeLevin': 'verbs of putting',
#   'SemanticTypeEntry': '09.8fill',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 6,
#   'Ortho_N': 1,
#   'Phono_N': 0,
#   'OLD': 2.75,
#   'PLD': 2.55,
#   'NPhon': 5,
#   'NSyll': 2,
#   'I_Mean_RT': 767.643,
#   'I_Mean_Accuracy': 0.85,
#   'I_NMG_Mean_RT': 715.231,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 841.68,
#   'N3_F': 37.38},
#  'eradicate': {'GrandIndex': 436,
#   'Index': 170,
#   'LogFreqHAL': 6.612,
#   'Concreteness': 3,
#   'AgeofAcqsn': 14.75,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'transitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'transitive',
#   'SynClassSK': 'transitive',
#   'unerg_pb': nan,
#   'unacc_pb': nan,
#   'tr_pb': 1.0,
#   'totalN_pb': 2.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'ch of quantity',
#   'SemanticType_JB_edit': 'ch of quantity',
#   'Typicality_JB': 4.0,
#   'SemanticType_LC': 'creation?/other',
#   'Typicality_LC': nan,
#   'SemClass_Consensus': 'creation or destruction',
#   'CONSENSUS_JB': 'creation or destruction',
#   'SemanticTypeLevin': 'verbs of removing',
#   'SemanticTypeEntry': '10.1remove',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 9,
#   'Ortho_N': 0,
#   'Phono_N': 0,
#   'OLD': 2.85,
#   'PLD': 3.35,
#   'NPhon': 8,
#   'NSyll': 4,
#   'I_Mean_RT': 827.148,
#   'I_Mean_Accuracy': 0.82,
#   'I_NMG_Mean_RT': 758.692,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 323.75,
#   'N3_F': 107.98},
#  'embarrass': {'GrandIndex': 437,
#   'Index': 171,
#   'LogFreqHAL': 6.604,
#   'Concreteness': 2.14,
#   'AgeofAcqsn': 6.11,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'transitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'transitive',
#   'SynClassSK': 'transitive',
#   'unerg_pb': 0.25,
#   'unacc_pb': 0.12,
#   'tr_pb': 0.5,
#   'totalN_pb': 8.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': 'psych',
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'emotion',
#   'SemanticType_JB_edit': 'emotion',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'social or interpersonal event',
#   'Typicality_LC': 4.0,
#   'SemClass_Consensus': 'social or interpersonal event',
#   'CONSENSUS_JB': 'social or interpersonal event',
#   'SemanticTypeLevin': 'psych verbs',
#   'SemanticTypeEntry': '31.1amuse',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 9,
#   'Ortho_N': 0,
#   'Phono_N': 0,
#   'OLD': 3.85,
#   'PLD': 2.7,
#   'NPhon': 7,
#   'NSyll': 3,
#   'I_Mean_RT': 816.938,
#   'I_Mean_Accuracy': 0.94,
#   'I_NMG_Mean_RT': 714.571,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 169.98,
#   'N3_F': 10.22},
#  'pare': {'GrandIndex': 438,
#   'Index': 172,
#   'LogFreqHAL': 6.592,
#   'Concreteness': '#',
#   'AgeofAcqsn': 11.33,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'transitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'transitive',
#   'SynClassSK': 'transitive',
#   'unerg_pb': nan,
#   'unacc_pb': 0.33,
#   'tr_pb': 0.67,
#   'totalN_pb': 9.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'obj dir action or transfer, ch of appearance',
#   'SemanticType_JB_edit': 'obj dir action or transfer, ch of appearance',
#   'Typicality_JB': 4.0,
#   'SemanticType_LC': 'obj dir action',
#   'Typicality_LC': 3.0,
#   'SemClass_Consensus': 'obj-directed action',
#   'CONSENSUS_JB': 'obj-directed action',
#   'SemanticTypeLevin': 'not found',
#   'SemanticTypeEntry': nan,
#   'Percentage_dom_PoS': 1.0,
#   'Length': 4,
#   'Ortho_N': 26,
#   'Phono_N': 39,
#   'OLD': 1.0,
#   'PLD': 1.0,
#   'NPhon': 3,
#   'NSyll': 1,
#   'I_Mean_RT': 748.556,
#   'I_Mean_Accuracy': 0.56,
#   'I_NMG_Mean_RT': 622.522,
#   'I_NMG_Mean_Accuracy': 0.852,
#   'N2_F': 3844.9,
#   'N3_F': 434.21},
#  'forfeit': {'GrandIndex': 439,
#   'Index': 173,
#   'LogFreqHAL': 6.59,
#   'Concreteness': 2.63,
#   'AgeofAcqsn': 10.4,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'transitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'transitive',
#   'SynClassSK': 'transitive',
#   'unerg_pb': nan,
#   'unacc_pb': nan,
#   'tr_pb': 1.0,
#   'totalN_pb': 3.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Achievement',
#   'SemanticType_JB': 'obj dir action or transfer',
#   'SemanticType_JB_edit': 'obj dir action or transfer',
#   'Typicality_JB': 4.0,
#   'SemanticType_LC': 'social or interpersonal event',
#   'Typicality_LC': 3.0,
#   'SemClass_Consensus': 'obj-directed action or transfer',
#   'CONSENSUS_JB': 'obj-directed transfer',
#   'SemanticTypeLevin': 'verbs of change of possession',
#   'SemanticTypeEntry': '13.2contribute',
#   'Percentage_dom_PoS': 0.7,
#   'Length': 7,
#   'Ortho_N': 0,
#   'Phono_N': 2,
#   'OLD': 2.8,
#   'PLD': 2.1,
#   'NPhon': 6,
#   'NSyll': 2,
#   'I_Mean_RT': 705.452,
#   'I_Mean_Accuracy': 0.94,
#   'I_NMG_Mean_RT': 666.852,
#   'I_NMG_Mean_Accuracy': 0.964,
#   'N2_F': 463.99,
#   'N3_F': 111.67},
#  'frighten': {'GrandIndex': 440,
#   'Index': 174,
#   'LogFreqHAL': 6.576,
#   'Concreteness': 3.07,
#   'AgeofAcqsn': 8.83,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'transitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'transitive',
#   'SynClassSK': 'transitive',
#   'unerg_pb': nan,
#   'unacc_pb': 0.4,
#   'tr_pb': 0.6,
#   'totalN_pb': 5.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': 0.0,
#   'tr_g': 0.15,
#   'totalN_g': 200.0,
#   'most_frequent_g': 'tr',
#   'Note': 'psych',
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'emotion',
#   'SemanticType_JB_edit': 'emotion',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'emotion (result)',
#   'Typicality_LC': 4.0,
#   'SemClass_Consensus': 'emotion',
#   'CONSENSUS_JB': 'emotion',
#   'SemanticTypeLevin': 'psych verbs',
#   'SemanticTypeEntry': '31.1amuse',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 8,
#   'Ortho_N': 2,
#   'Phono_N': 2,
#   'OLD': 2.4,
#   'PLD': 1.95,
#   'NPhon': 5,
#   'NSyll': 2,
#   'I_Mean_RT': 688.853,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 679.407,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 601.73,
#   'N3_F': 132.89},
#  'crave': {'GrandIndex': 441,
#   'Index': 175,
#   'LogFreqHAL': 6.542,
#   'Concreteness': 2.52,
#   'AgeofAcqsn': 9.17,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'transitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'transitive',
#   'SynClassSK': 'transitive',
#   'unerg_pb': nan,
#   'unacc_pb': nan,
#   'tr_pb': 1.0,
#   'totalN_pb': 1.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': 'psych',
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'State',
#   'SemanticType_JB': 'emotion',
#   'SemanticType_JB_edit': 'emotion',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'emotion',
#   'Typicality_LC': 5.0,
#   'SemClass_Consensus': 'emotion',
#   'CONSENSUS_JB': 'emotion',
#   'SemanticTypeLevin': 'verbs of desire, verbs of desire',
#   'SemanticTypeEntry': '32.1want, 32.2long',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 5,
#   'Ortho_N': 8,
#   'Phono_N': 10,
#   'OLD': 1.55,
#   'PLD': 1.5,
#   'NPhon': 4,
#   'NSyll': 1,
#   'I_Mean_RT': 710.452,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 637.769,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 824.27,
#   'N3_F': 169.95},
#  'overwhelm': {'GrandIndex': 442,
#   'Index': 176,
#   'LogFreqHAL': 6.513,
#   'Concreteness': 1.42,
#   'AgeofAcqsn': 9.21,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'transitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'transitive',
#   'SynClassSK': 'transitive',
#   'unerg_pb': nan,
#   'unacc_pb': 0.12,
#   'tr_pb': 0.88,
#   'totalN_pb': 8.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'emotion',
#   'SemanticType_JB_edit': 'emotion',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'emotion (result)',
#   'Typicality_LC': 2.0,
#   'SemClass_Consensus': 'emotion',
#   'CONSENSUS_JB': 'emotion',
#   'SemanticTypeLevin': 'psych verbs',
#   'SemanticTypeEntry': '31.1amuse',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 9,
#   'Ortho_N': 0,
#   'Phono_N': 0,
#   'OLD': 3.65,
#   'PLD': 3.65,
#   'NPhon': 8,
#   'NSyll': 3,
#   'I_Mean_RT': 766.406,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 608.407,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 186.61,
#   'N3_F': 51.76},
#  'amuse': {'GrandIndex': 443,
#   'Index': 177,
#   'LogFreqHAL': 6.468,
#   'Concreteness': 2.57,
#   'AgeofAcqsn': 9.0,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'transitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'transitive',
#   'SynClassSK': 'transitive',
#   'unerg_pb': 0.5,
#   'unacc_pb': nan,
#   'tr_pb': nan,
#   'totalN_pb': 2.0,
#   'most_frequent_pb': 'unerg',
#   'intr_g': 0.0,
#   'tr_g': 0.36,
#   'totalN_g': 88.0,
#   'most_frequent_g': 'tr',
#   'Note': 'psych',
#   'SynClassCorpus': 'conflict',
#   'SynClassFinal': 'transitive',
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'emotion',
#   'SemanticType_JB_edit': 'emotion',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'emotion (result)',
#   'Typicality_LC': 4.0,
#   'SemClass_Consensus': 'emotion',
#   'CONSENSUS_JB': 'emotion',
#   'SemanticTypeLevin': 'psych verbs',
#   'SemanticTypeEntry': '31.1amuse',
#   'Percentage_dom_PoS': 0.96,
#   'Length': 5,
#   'Ortho_N': 1,
#   'Phono_N': 3,
#   'OLD': 1.85,
#   'PLD': 1.8,
#   'NPhon': 5,
#   'NSyll': 2,
#   'I_Mean_RT': 749.364,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 653.333,
#   'I_NMG_Mean_Accuracy': 0.96,
#   'N2_F': 1358.49,
#   'N3_F': 253.93},
#  'irritate': {'GrandIndex': 444,
#   'Index': 178,
#   'LogFreqHAL': 6.465,
#   'Concreteness': 2.43,
#   'AgeofAcqsn': 9.47,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'transitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'transitive',
#   'SynClassSK': 'transitive',
#   'unerg_pb': nan,
#   'unacc_pb': nan,
#   'tr_pb': 1.0,
#   'totalN_pb': 2.0,
#   'most_frequent_pb': 'tr',
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': 'psych',
#   'SynClassCorpus': 'tr',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'emotion',
#   'SemanticType_JB_edit': 'emotion',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'emotion (result)',
#   'Typicality_LC': 4.0,
#   'SemClass_Consensus': 'emotion',
#   'CONSENSUS_JB': 'emotion',
#   'SemanticTypeLevin': 'psych verbs',
#   'SemanticTypeEntry': '31.1amuse',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 8,
#   'Ortho_N': 1,
#   'Phono_N': 2,
#   'OLD': 2.55,
#   'PLD': 2.35,
#   'NPhon': 6,
#   'NSyll': 3,
#   'I_Mean_RT': 752.387,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 738.391,
#   'I_NMG_Mean_Accuracy': 0.821,
#   'N2_F': 416.17,
#   'N3_F': 112.23},
#  'purify': {'GrandIndex': 445,
#   'Index': 179,
#   'LogFreqHAL': 6.395,
#   'Concreteness': 2.35,
#   'AgeofAcqsn': 11.0,
#   'Database': 'VerbNet',
#   'Trans_Intrans': 'transitive only',
#   'SynClassLitrt': nan,
#   'SynClassMemo': 'transitive',
#   'SynClassSK': 'transitive',
#   'unerg_pb': nan,
#   'unacc_pb': nan,
#   'tr_pb': nan,
#   'totalN_pb': nan,
#   'most_frequent_pb': nan,
#   'intr_g': nan,
#   'tr_g': nan,
#   'totalN_g': nan,
#   'most_frequent_g': nan,
#   'Note': nan,
#   'SynClassCorpus': 'none',
#   'SynClassFinal': nan,
#   'AspClass_Consensus': 'Process',
#   'SemanticType_JB': 'ch of state',
#   'SemanticType_JB_edit': 'ch of state',
#   'Typicality_JB': 5.0,
#   'SemanticType_LC': 'ch of state (result)',
#   'Typicality_LC': 2.0,
#   'SemClass_Consensus': 'ch of state',
#   'CONSENSUS_JB': 'ch of state',
#   'SemanticTypeLevin': 'verbs of removing, verbs of change of state',
#   'SemanticTypeEntry': '10.6cheat, 45.4state',
#   'Percentage_dom_PoS': 1.0,
#   'Length': 6,
#   'Ortho_N': 1,
#   'Phono_N': 0,
#   'OLD': 2.35,
#   'PLD': 2.9,
#   'NPhon': 7,
#   'NSyll': 3,
#   'I_Mean_RT': 651.912,
#   'I_Mean_Accuracy': 0.97,
#   'I_NMG_Mean_RT': 729.643,
#   'I_NMG_Mean_Accuracy': 1.0,
#   'N2_F': 721.22,
#   'N3_F': 144.67}}

# %%
exceptlist = [] ### find verbs that do not appear in Google n-gram
for key, value in raw2_dic.items(): ### update raw2_dic with Google-ngram percentages
    try: 
        raw2_dic[key]['intr_google'] = round(ngram_dict[key]['percent_intrans'],4)
        raw2_dic[key]['trans_google'] = round(ngram_dict[key]['percent_trans'],4)
    except: 
        raw2_dic[key]['intr_google'] = 'notfound'
        raw2_dic[key]['trans_google'] = 'notfound'
        exceptlist.append(key)

# %%
#raw2_dic['break']
# Out:
# {'GrandIndex': 92,
#  'Index': 3,
#  'LogFreqHAL': 10.774,
#  'Concreteness': 3.71,
#  'AgeofAcqsn': 5.3,
#  'Database': 'CREA',
#  'Trans_Intrans': 'both',
#  'SynClassLitrt': 'unaccusative',
#  'SynClassMemo': 'unaccusative',
#  'SynClassSK': 'unaccusative',
#  'unerg_pb': 0.1,
#  'unacc_pb': 0.41,
#  'tr_pb': 0.47,
#  'totalN_pb': 135.0,
#  'most_frequent_pb': 'tr',
#  'intr_g': 0.18,
#  'tr_g': 0.28,
#  'totalN_g': 145.0,
#  'most_frequent_g': 'tr',
#  'Note': 'break in',
#  'SynClassCorpus': 'tr',
#  'SynClassFinal': 'transitive',
#  'AspClass_Consensus': 'Achievement',
#  'SemanticType_JB': 'ch of cohesiveness, obj dir action or transfer',
#  'SemanticType_JB_edit': 'ch of cohesiveness, obj dir action or transfer',
#  'Typicality_JB': 4.0,
#  'SemanticType_LC': 'obj dir action/ch of cohesiveness',
#  'Typicality_LC': 4.0,
#  'SemClass_Consensus': 'obj-directed action',
#  'CONSENSUS_JB': 'obj-directed action',
#  'SemanticTypeLevin': 'verbs of removing, verbs of separating and disassembling, verbs of involving the body, verbs of change of state, appearance, disappearance, and occurrence',
#  'SemanticTypeEntry': '10.6cheat, 23.2split, 40.8.3hurt, 45.1break, 48.1.1appear',
#  'Percentage_dom_PoS': 0.67,
#  'Length': 5,
#  'Ortho_N': 6,
#  'Phono_N': 21,
#  'OLD': 1.65,
#  'PLD': 1.2,
#  'NPhon': 4,
#  'NSyll': 1,
#  'I_Mean_RT': 604.147,
#  'I_Mean_Accuracy': 1.0,
#  'I_NMG_Mean_RT': 591.964,
#  'I_NMG_Mean_Accuracy': 1.0,
#  'N2_F': 1286.47,
#  'N3_F': 526.75,
#  'intr_google': 0.4465,
#  'trans_google': 0.5531}

# %%
raw_upd3 = pd.DataFrame.from_dict(raw2_dic, orient='index') ### df with Google n-gram columns

# %%
raw_upd3 = rearrange_col(raw_upd3, 'intr_google', 'SynClassFinal', right=True)
raw_upd3 = rearrange_col(raw_upd3, 'trans_google', 'intr_google', right=True)

# %%
raw_upd3.head()
# Out:
#       GrandIndex  Index  LogFreqHAL Concreteness  AgeofAcqsn Database  \
# work           1      1      13.020         3.48        5.86     CREA
# go             2      2      12.923         3.15        3.37     CREA
# run            3      3      12.316         4.31        4.47     CREA
# play           4      4      11.915         3.24        4.10     CREA
# live           5      5      11.763         3.57        6.10     CREA
#
#           Trans_Intrans            SynClassLitrt            SynClassMemo  \
# work               both               unergative              unergative
# go    intransitive only               unergative       unergative PP arg
# run                both               unergative              unergative
# play               both               unergative  unergative, transitive
# live  intransitive only  unergative/unaccusative       unergative PP arg
#
#       SynClassSK  unerg_pb  unacc_pb  tr_pb  totalN_pb most_frequent_pb  \
# work  unergative     0.780    0.0440  0.160      431.0            unerg
# go    unergative     0.160    0.4300  0.020     1029.0            unacc
# run   unergative     0.180    0.3400  0.440      374.0               tr
# play  unergative     0.097    0.1500  0.720      186.0               tr
# live  unergative     0.950    0.0078  0.047      129.0            unerg
#
#       intr_g  tr_g  totalN_g most_frequent_g Note SynClassCorpus  \
# work     NaN   NaN       NaN             NaN  NaN          unerg
# go       NaN   NaN       NaN             NaN  NaN          unacc
# run      NaN   NaN       NaN             NaN  NaN             tr
# play    0.33  0.57     150.0              tr  NaN             tr
# live     NaN   NaN       NaN             NaN  NaN          unerg
#
#      SynClassFinal intr_google trans_google AspClass_Consensus  \
# work           NaN      0.8878       0.1117            Process
# go             NaN      0.9567       0.0432        Achievement
# run            NaN      0.7627       0.2365            Process
# play    transitive      0.5561         0.44            Process
# live           NaN      0.9418       0.0581              State
#
#               SemanticType_JB      SemanticType_JB_edit  Typicality_JB  \
# work  other - general process   other - general process            5.0
# go             ch of location            ch of location            5.0
# run       body mvt or posture  body movement or posture            5.0
# play             social event              social event            5.0
# live                existence                 existence            5.0
#
#                     SemanticType_LC  Typicality_LC  \
# work                          other            NaN
# go                   ch of location            5.0
# run                manner of motion            5.0
# play  social or interpersonal event            3.0
# live                      existence            5.0
#
#                  SemClass_Consensus                   CONSENSUS_JB  \
# work                          other                          other
# go                   ch of location                 ch of location
# run                manner of motion               manner of motion
# play  social or interpersonal event  social or interpersonal event
# live                      existence                      existence
#
#                                                                                   SemanticTypeLevin  \
# work                                                           verbs of creating and transformation
# go                                                              verbs of existence, verbs of motion
# run   verbs of creating and transformation, verbs of existence, verbs of existence, verbs of motion
# play                              verbs of creating and transformation, verbs of social interaction
# live                                            verbs of ingesting, lodge verbs, verbs of existence
#
#                                      SemanticTypeEntry  Percentage_dom_PoS  \
# work                                         26.5knead                0.57
# go                            47.7meander, 51.1advance                0.98
# run   26.3prepare, 47.5.1swarm, 47.7meander, 51.3.2run                0.89
# play                             26.7perform, 36.3meet                0.81
# live                     39.6gorge, 46lodge, 47.1exist                0.89
#
#       Length  Ortho_N  Phono_N   OLD   PLD  NPhon  NSyll  I_Mean_RT  \
# work       4        9       25  1.50  1.20      3      1    633.152
# go         2       17       48  1.35  1.00      2      1    597.688
# run        3       19       40  1.00  1.00      3      1    596.647
# play       4        6       15  1.45  1.10      3      1    537.909
# live       4       16       21  1.15  1.25      3      1    629.886
#
#       I_Mean_Accuracy  I_NMG_Mean_RT  I_NMG_Mean_Accuracy     N2_F     N3_F
# work             1.00        521.889                1.000  2421.10  1034.67
# go               0.97        524.071                1.000   974.49      NaN
# run              1.00        559.955                1.000   386.53   229.70
# play             1.00        566.077                0.963   781.22   329.47
# live             1.00        553.769                0.963  3645.64   606.44

# %%
### find out how well SynClassSK and Google Ngram match
unergSK = raw_upd3.loc[raw_upd3['SynClassSK']=='unergative']
unaccSK = raw_upd3.loc[raw_upd3['SynClassSK']=='unaccusative'] 
transSK = raw_upd3.loc[raw_upd3['SynClassSK']=='transitive']

# %%
unergBest = unergSK.loc[raw_upd3['intr_google']>raw_upd3['trans_google']]
unergFail = unergSK.loc[raw_upd3['intr_google']<raw_upd3['trans_google']]
print ('# of all unergative verbs is ', unergSK.shape[0])
print ('# of unergative verbs that are supported by Google N-gram is ', unergBest.shape[0])
print ('the unergative verbs that are not supported are: ', unergFail.index.tolist())
# Out:
# # of all unergative verbs is  89
# # of unergative verbs that are supported by Google N-gram is  77
# the unergative verbs that are not supported are:  ['leave', 'cross', 'shrug', 'inhale']

# %%
unaccBest = unaccSK.loc[raw_upd3['intr_google']>raw_upd3['trans_google']]
unaccFail = unaccSK.loc[raw_upd3['intr_google']<raw_upd3['trans_google']]
print ('# of all unaccusative verbs is ', unaccSK.shape[0])
print ('# of unaccusative verbs that are supported by Google N-gram is ', unaccBest.shape[0])
print ('the unaccusative verbs that are not supported are: ', unaccFail.index.tolist())
# Out:
# # of all unaccusative verbs is  177
# # of unaccusative verbs that are supported by Google N-gram is  119
# the unaccusative verbs that are not supported are:  ['open', 'break', 'change', 'resume', 'increase', 'improve', 'click', 'smell', 'stretch', 'gather', 'shake', 'integrate', 'multiply', 'smash', 'strengthen', 'shatter', 'accelerate', 'dissolve', 'spoil', 'lighten', 'tighten', 'sway', 'drown', 'loosen', 'diminish', 'weaken', 'straighten', 'lessen', 'revive', 'shorten', 'awaken', 'broaden', 'soften', 'enlarge', 'diffuse', 'consolidate', 'inflate', 'sharpen', 'fasten', 'intensify', 'lengthen', 'dampen', 'darken', 'deepen', 'vaporize', 'submerge']

# %%
transBest = transSK.loc[raw_upd3['intr_google']<raw_upd3['trans_google']]
transFail = transSK.loc[raw_upd3['intr_google']>raw_upd3['trans_google']]
print ('# of all transitive verbs is ', transSK.shape[0])
print ('# of transitive verbs that are supported by Google N-gram is ', transBest.shape[0])
print ('the transitive verbs that are not supported are: ', transFail.index.tolist())
# Out:
# # of all transitive verbs is  179
# # of transitive verbs that are supported by Google N-gram is  148
# the transitive verbs that are not supported are:  ['want', 'help', 'read', 'write', 'eat', 'survive', 'steal', 'mean', 'allow', 'expect', 'suggest', 'doubt', 'prefer', 'assume', 'realize', 'imagine', 'suppose', 'delete', 'spare', 'imply', 'extract', 'ruin', 'predict', 'observe', 'regret', 'assert', 'perceive', 'admire', 'forbid', 'ascertain', 'crave']

# %%
### update SynClassFinal based on Google Ngram
raw_upd3.SynClassFinal = '' ### clear the SynClassFinal column
raw_upd3.loc[(raw_upd3['SynClassSK']=='unergative') & (raw_upd3['intr_google']>raw_upd3['trans_google']), 'SynClassFinal']='unergative'
raw_upd3.loc[(raw_upd3['SynClassSK']=='unergative') & (raw_upd3['intr_google']<raw_upd3['trans_google']), 'SynClassFinal']='unergativefailed'
raw_upd3.loc[(raw_upd3['SynClassSK']=='unaccusative') & (raw_upd3['intr_google']>raw_upd3['trans_google']), 'SynClassFinal']='unaccusative'
raw_upd3.loc[(raw_upd3['SynClassSK']=='unaccusative') & (raw_upd3['intr_google']<raw_upd3['trans_google']), 'SynClassFinal']='unaccusativefailed'
raw_upd3.loc[(raw_upd3['SynClassSK']=='transitive') & (raw_upd3['intr_google']<raw_upd3['trans_google']), 'SynClassFinal']='transitive'

# %%
raw_upd3.head()
# Out:
#       GrandIndex  Index  LogFreqHAL Concreteness  AgeofAcqsn Database  \
# work           1      1      13.020         3.48        5.86     CREA
# go             2      2      12.923         3.15        3.37     CREA
# run            3      3      12.316         4.31        4.47     CREA
# play           4      4      11.915         3.24        4.10     CREA
# live           5      5      11.763         3.57        6.10     CREA
#
#           Trans_Intrans            SynClassLitrt            SynClassMemo  \
# work               both               unergative              unergative
# go    intransitive only               unergative       unergative PP arg
# run                both               unergative              unergative
# play               both               unergative  unergative, transitive
# live  intransitive only  unergative/unaccusative       unergative PP arg
#
#       SynClassSK  unerg_pb  unacc_pb  tr_pb  totalN_pb most_frequent_pb  \
# work  unergative     0.780    0.0440  0.160      431.0            unerg
# go    unergative     0.160    0.4300  0.020     1029.0            unacc
# run   unergative     0.180    0.3400  0.440      374.0               tr
# play  unergative     0.097    0.1500  0.720      186.0               tr
# live  unergative     0.950    0.0078  0.047      129.0            unerg
#
#       intr_g  tr_g  totalN_g most_frequent_g Note SynClassCorpus  \
# work     NaN   NaN       NaN             NaN  NaN          unerg
# go       NaN   NaN       NaN             NaN  NaN          unacc
# run      NaN   NaN       NaN             NaN  NaN             tr
# play    0.33  0.57     150.0              tr  NaN             tr
# live     NaN   NaN       NaN             NaN  NaN          unerg
#
#      SynClassFinal intr_google trans_google AspClass_Consensus  \
# work    unergative      0.8878       0.1117            Process
# go      unergative      0.9567       0.0432        Achievement
# run     unergative      0.7627       0.2365            Process
# play    unergative      0.5561         0.44            Process
# live    unergative      0.9418       0.0581              State
#
#               SemanticType_JB      SemanticType_JB_edit  Typicality_JB  \
# work  other - general process   other - general process            5.0
# go             ch of location            ch of location            5.0
# run       body mvt or posture  body movement or posture            5.0
# play             social event              social event            5.0
# live                existence                 existence            5.0
#
#                     SemanticType_LC  Typicality_LC  \
# work                          other            NaN
# go                   ch of location            5.0
# run                manner of motion            5.0
# play  social or interpersonal event            3.0
# live                      existence            5.0
#
#                  SemClass_Consensus                   CONSENSUS_JB  \
# work                          other                          other
# go                   ch of location                 ch of location
# run                manner of motion               manner of motion
# play  social or interpersonal event  social or interpersonal event
# live                      existence                      existence
#
#                                                                                   SemanticTypeLevin  \
# work                                                           verbs of creating and transformation
# go                                                              verbs of existence, verbs of motion
# run   verbs of creating and transformation, verbs of existence, verbs of existence, verbs of motion
# play                              verbs of creating and transformation, verbs of social interaction
# live                                            verbs of ingesting, lodge verbs, verbs of existence
#
#                                      SemanticTypeEntry  Percentage_dom_PoS  \
# work                                         26.5knead                0.57
# go                            47.7meander, 51.1advance                0.98
# run   26.3prepare, 47.5.1swarm, 47.7meander, 51.3.2run                0.89
# play                             26.7perform, 36.3meet                0.81
# live                     39.6gorge, 46lodge, 47.1exist                0.89
#
#       Length  Ortho_N  Phono_N   OLD   PLD  NPhon  NSyll  I_Mean_RT  \
# work       4        9       25  1.50  1.20      3      1    633.152
# go         2       17       48  1.35  1.00      2      1    597.688
# run        3       19       40  1.00  1.00      3      1    596.647
# play       4        6       15  1.45  1.10      3      1    537.909
# live       4       16       21  1.15  1.25      3      1    629.886
#
#       I_Mean_Accuracy  I_NMG_Mean_RT  I_NMG_Mean_Accuracy     N2_F     N3_F
# work             1.00        521.889                1.000  2421.10  1034.67
# go               0.97        524.071                1.000   974.49      NaN
# run              1.00        559.955                1.000   386.53   229.70
# play             1.00        566.077                0.963   781.22   329.47
# live             1.00        553.769                0.963  3645.64   606.44

# %%
colnames = list(raw_upd3.columns.values)
cols_to_test = ['LogFreqHAL', 'AgeofAcqsn', 'Percentage_dom_PoS', 'Length', 'Ortho_N', 'Phono_N',\
                'OLD', 'PLD', 'NPhon', 'NSyll', 'I_Mean_RT', 'I_Mean_Accuracy', 'I_NMG_Mean_RT', \
                'I_NMG_Mean_Accuracy', 'N2_F', 'N3_F']

# %%
for c in cols_to_test: 
    if raw_upd3.loc[pd.isna(raw_upd3[c])].shape[0] !=0: ### find any columns that contain NaN
        print (c)
# Out:
# N3_F

# %%
raw_upd3.loc[pd.isna(raw_upd3['N3_F'])] ## this returns the row where N3F is NaN
# Out:
#     GrandIndex  Index  LogFreqHAL Concreteness  AgeofAcqsn Database  \
# go           2      2      12.923         3.15        3.37     CREA
#
#         Trans_Intrans SynClassLitrt       SynClassMemo  SynClassSK  unerg_pb  \
# go  intransitive only    unergative  unergative PP arg  unergative      0.16
#
#     unacc_pb  tr_pb  totalN_pb most_frequent_pb  intr_g  tr_g  totalN_g  \
# go      0.43   0.02     1029.0            unacc     NaN   NaN       NaN
#
#    most_frequent_g Note SynClassCorpus SynClassFinal intr_google trans_google  \
# go             NaN  NaN          unacc    unergative      0.9567       0.0432
#
#    AspClass_Consensus SemanticType_JB SemanticType_JB_edit  Typicality_JB  \
# go        Achievement  ch of location       ch of location            5.0
#
#    SemanticType_LC  Typicality_LC SemClass_Consensus    CONSENSUS_JB  \
# go  ch of location            5.0     ch of location  ch of location
#
#                       SemanticTypeLevin         SemanticTypeEntry  \
# go  verbs of existence, verbs of motion  47.7meander, 51.1advance
#
#     Percentage_dom_PoS  Length  Ortho_N  Phono_N   OLD  PLD  NPhon  NSyll  \
# go                0.98       2       17       48  1.35  1.0      2      1
#
#     I_Mean_RT  I_Mean_Accuracy  I_NMG_Mean_RT  I_NMG_Mean_Accuracy    N2_F  \
# go    597.688             0.97        524.071                  1.0  974.49
#
#     N3_F
# go   NaN

# %%
item_to_remove = raw_upd3.loc[pd.isna(raw_upd3['N3_F'])].index[0]
print (item_to_remove, ',', raw_upd3.loc[item_to_remove]['SynClassFinal'])
# Out:
# go , unergative

# %%
#### Create a dict that includes individual Series for each syntactic category (for each low-level property)
l = []
for c in cols_to_test:
    exec("%s={}" %c)
    
dict_list = [LogFreqHAL, AgeofAcqsn, Percentage_dom_PoS, Length, Ortho_N, Phono_N, OLD, PLD, NPhon, NSyll, \
             I_Mean_RT, I_Mean_Accuracy, I_NMG_Mean_RT, I_NMG_Mean_Accuracy, N2_F, N3_F]

dict_dict = dict(zip(cols_to_test, dict_list)) 

for k, v in dict_dict.items():
    print (k)
    for s in ['unergative', 'unaccusative', 'transitive']:
        v[s] = raw_upd3.loc[raw_upd3['SynClassFinal']==s][k].to_list()
#         print (v['unergative'])
#     print ('====')
#     print (v['unacc'])
#     print ('====')
#     print (v['tr'])
    print('unerg vs unacc:', stats.ttest_ind(v['unergative'], v['unaccusative']))
    print('unacc vs trans:', stats.ttest_ind(v['unaccusative'], v['transitive']))
    print('unerg vs trans:', stats.ttest_ind(v['unergative'], v['transitive']))
    print ('============================================================================================')
#     v['unerg-unacc'] = stats.ttest_ind(v['unerg'], v['unacc'])
#     v['unerg-tr'] = stats.ttest_ind(v['unerg'], v['tr'])
#     v['unacc-tr'] = stats.ttest_ind(v['unacc'], v['tr'])
# Out:
# LogFreqHAL
# unerg vs unacc: Ttest_indResult(statistic=0.5770748873649814, pvalue=0.5645579166677265)
# unacc vs trans: Ttest_indResult(statistic=-7.432345587990304, pvalue=1.4744963685504152e-12)
# unerg vs trans: Ttest_indResult(statistic=-5.81284880703498, pvalue=2.1084233444637657e-08)
# ============================================================================================
# AgeofAcqsn
# unerg vs unacc: Ttest_indResult(statistic=-3.439416911419329, pvalue=0.0007135823758899433)
# unacc vs trans: Ttest_indResult(statistic=-1.318171668265498, pvalue=0.18858443264721164)
# unerg vs trans: Ttest_indResult(statistic=-4.856304495764849, pvalue=2.2505428756713965e-06)
# ============================================================================================
# Percentage_dom_PoS
# unerg vs unacc: Ttest_indResult(statistic=-3.393950173412773, pvalue=0.0008352483792223676)
# unacc vs trans: Ttest_indResult(statistic=-2.7463982705386627, pvalue=0.00643822250191518)
# unerg vs trans: Ttest_indResult(statistic=-6.299871828995127, pvalue=1.5695669865466674e-09)
# ============================================================================================
# Length
# unerg vs unacc: Ttest_indResult(statistic=-2.1748387290012894, pvalue=0.030851997808501348)
# unacc vs trans: Ttest_indResult(statistic=-2.718898437763591, pvalue=0.006982497725328905)
# unerg vs trans: Ttest_indResult(statistic=-4.647576396182574, pvalue=5.7458541833131886e-06)
# ============================================================================================
# Ortho_N
# unerg vs unacc: Ttest_indResult(statistic=1.5403581387871899, pvalue=0.12510258817248407)
# unacc vs trans: Ttest_indResult(statistic=2.5691709465662362, pvalue=0.010741981271520533)
# unerg vs trans: Ttest_indResult(statistic=3.8343896611159867, pvalue=0.00016380773538184607)
# ============================================================================================
# Phono_N
# unerg vs unacc: Ttest_indResult(statistic=1.2838268503349364, pvalue=0.20073377299593698)
# unacc vs trans: Ttest_indResult(statistic=2.2288031416488128, pvalue=0.026665884895876707)
# unerg vs trans: Ttest_indResult(statistic=3.3752412476321494, pvalue=0.0008698076681247073)
# ============================================================================================
# OLD
# unerg vs unacc: Ttest_indResult(statistic=-1.6201552945966717, pvalue=0.10682326163684959)
# unacc vs trans: Ttest_indResult(statistic=-3.5564481634153404, pvalue=0.000445128468196395)
# unerg vs trans: Ttest_indResult(statistic=-4.925001534416881, pvalue=1.642199287950469e-06)
# ============================================================================================
# PLD
# unerg vs unacc: Ttest_indResult(statistic=-1.5952196458280072, pvalue=0.11229089267517112)
# unacc vs trans: Ttest_indResult(statistic=-3.4176567423813062, pvalue=0.0007309647649515906)
# unerg vs trans: Ttest_indResult(statistic=-4.6666433820299735, pvalue=5.281080378848498e-06)
# ============================================================================================
# NPhon
# unerg vs unacc: Ttest_indResult(statistic=-2.242061229995359, pvalue=0.026089632819692565)
# unacc vs trans: Ttest_indResult(statistic=-3.274755533271584, pvalue=0.0011982993213463218)
# unerg vs trans: Ttest_indResult(statistic=-5.183651860240157, pvalue=4.870519964952774e-07)
# ============================================================================================
# NSyll
# unerg vs unacc: Ttest_indResult(statistic=-2.3025330527539354, pvalue=0.022366120587490605)
# unacc vs trans: Ttest_indResult(statistic=-3.7195804141939357, pvalue=0.00024358656804895996)
# unerg vs trans: Ttest_indResult(statistic=-5.647709790157695, pvalue=4.925158983762744e-08)
# ============================================================================================
# I_Mean_RT
# unerg vs unacc: Ttest_indResult(statistic=-1.1460334191327195, pvalue=0.25319297157551496)
# unacc vs trans: Ttest_indResult(statistic=1.4304229000120363, pvalue=0.15377371625071737)
# unerg vs trans: Ttest_indResult(statistic=-0.04595914572225043, pvalue=0.963383942557967)
# ============================================================================================
# I_Mean_Accuracy
# unerg vs unacc: Ttest_indResult(statistic=0.42835635455587506, pvalue=0.6688668953494914)
# unacc vs trans: Ttest_indResult(statistic=-3.0303850201847267, pvalue=0.002683990657629576)
# unerg vs trans: Ttest_indResult(statistic=-2.303208299980863, pvalue=0.02218856934134626)
# ============================================================================================
# I_NMG_Mean_RT
# unerg vs unacc: Ttest_indResult(statistic=-0.17178339535913467, pvalue=0.8637868783269103)
# unacc vs trans: Ttest_indResult(statistic=-0.870028953822013, pvalue=0.38507196828110457)
# unerg vs trans: Ttest_indResult(statistic=-0.8736571304465545, pvalue=0.38324484060601305)
# ============================================================================================
# I_NMG_Mean_Accuracy
# unerg vs unacc: Ttest_indResult(statistic=0.601472381730641, pvalue=0.5482275944571864)
# unacc vs trans: Ttest_indResult(statistic=-0.3624112798034615, pvalue=0.717333567108262)
# unerg vs trans: Ttest_indResult(statistic=0.30360746646525566, pvalue=0.761710037889727)
# ============================================================================================
# N2_F
# unerg vs unacc: Ttest_indResult(statistic=-0.7230003678546341, pvalue=0.47055040977521323)
# unacc vs trans: Ttest_indResult(statistic=1.939957297430621, pvalue=0.05344578469764628)
# unerg vs trans: Ttest_indResult(statistic=1.242063801745511, pvalue=0.2155176833241171)
# ============================================================================================
# N3_F
# unerg vs unacc: Ttest_indResult(statistic=nan, pvalue=nan)
# unacc vs trans: Ttest_indResult(statistic=1.567919677619218, pvalue=0.11809315810826111)
# unerg vs trans: Ttest_indResult(statistic=nan, pvalue=nan)
# ============================================================================================

# %%
raw_upd3.head()
# Out:
#       GrandIndex  Index  LogFreqHAL Concreteness  AgeofAcqsn Database  \
# work           1      1      13.020         3.48        5.86     CREA
# go             2      2      12.923         3.15        3.37     CREA
# run            3      3      12.316         4.31        4.47     CREA
# play           4      4      11.915         3.24        4.10     CREA
# live           5      5      11.763         3.57        6.10     CREA
#
#           Trans_Intrans            SynClassLitrt            SynClassMemo  \
# work               both               unergative              unergative
# go    intransitive only               unergative       unergative PP arg
# run                both               unergative              unergative
# play               both               unergative  unergative, transitive
# live  intransitive only  unergative/unaccusative       unergative PP arg
#
#       SynClassSK  unerg_pb  unacc_pb  tr_pb  totalN_pb most_frequent_pb  \
# work  unergative     0.780    0.0440  0.160      431.0            unerg
# go    unergative     0.160    0.4300  0.020     1029.0            unacc
# run   unergative     0.180    0.3400  0.440      374.0               tr
# play  unergative     0.097    0.1500  0.720      186.0               tr
# live  unergative     0.950    0.0078  0.047      129.0            unerg
#
#       intr_g  tr_g  totalN_g most_frequent_g Note SynClassCorpus  \
# work     NaN   NaN       NaN             NaN  NaN          unerg
# go       NaN   NaN       NaN             NaN  NaN          unacc
# run      NaN   NaN       NaN             NaN  NaN             tr
# play    0.33  0.57     150.0              tr  NaN             tr
# live     NaN   NaN       NaN             NaN  NaN          unerg
#
#      SynClassFinal intr_google trans_google AspClass_Consensus  \
# work    unergative      0.8878       0.1117            Process
# go      unergative      0.9567       0.0432        Achievement
# run     unergative      0.7627       0.2365            Process
# play    unergative      0.5561         0.44            Process
# live    unergative      0.9418       0.0581              State
#
#               SemanticType_JB      SemanticType_JB_edit  Typicality_JB  \
# work  other - general process   other - general process            5.0
# go             ch of location            ch of location            5.0
# run       body mvt or posture  body movement or posture            5.0
# play             social event              social event            5.0
# live                existence                 existence            5.0
#
#                     SemanticType_LC  Typicality_LC  \
# work                          other            NaN
# go                   ch of location            5.0
# run                manner of motion            5.0
# play  social or interpersonal event            3.0
# live                      existence            5.0
#
#                  SemClass_Consensus                   CONSENSUS_JB  \
# work                          other                          other
# go                   ch of location                 ch of location
# run                manner of motion               manner of motion
# play  social or interpersonal event  social or interpersonal event
# live                      existence                      existence
#
#                                                                                   SemanticTypeLevin  \
# work                                                           verbs of creating and transformation
# go                                                              verbs of existence, verbs of motion
# run   verbs of creating and transformation, verbs of existence, verbs of existence, verbs of motion
# play                              verbs of creating and transformation, verbs of social interaction
# live                                            verbs of ingesting, lodge verbs, verbs of existence
#
#                                      SemanticTypeEntry  Percentage_dom_PoS  \
# work                                         26.5knead                0.57
# go                            47.7meander, 51.1advance                0.98
# run   26.3prepare, 47.5.1swarm, 47.7meander, 51.3.2run                0.89
# play                             26.7perform, 36.3meet                0.81
# live                     39.6gorge, 46lodge, 47.1exist                0.89
#
#       Length  Ortho_N  Phono_N   OLD   PLD  NPhon  NSyll  I_Mean_RT  \
# work       4        9       25  1.50  1.20      3      1    633.152
# go         2       17       48  1.35  1.00      2      1    597.688
# run        3       19       40  1.00  1.00      3      1    596.647
# play       4        6       15  1.45  1.10      3      1    537.909
# live       4       16       21  1.15  1.25      3      1    629.886
#
#       I_Mean_Accuracy  I_NMG_Mean_RT  I_NMG_Mean_Accuracy     N2_F     N3_F
# work             1.00        521.889                1.000  2421.10  1034.67
# go               0.97        524.071                1.000   974.49      NaN
# run              1.00        559.955                1.000   386.53   229.70
# play             1.00        566.077                0.963   781.22   329.47
# live             1.00        553.769                0.963  3645.64   606.44

# %%
raw_upd3.to_excel('/Users/songheekim/Google Drive/Primary/Projects/VerbVector/verblist_v2.13.xlsx')

# %%
### find the best verbs
# unergative = []
# unaccusative = []
# transitive = []
# failed_unergative=[]
# not_included=[]
# need_to_be_classified=[]

# for k, v in raw2_dic.items():
#     if v['SynClassSK'] == 'unergative' and v['SynClassSK'].startswith(v['SynClassFinal']):
#         unergative.append(k)
#     elif v['SynClassSK'] == 'unergative' and v['SynClassFinal']=='none':
#         unergative.append(k)
#     elif v['SynClassSK'] == 'unaccusative' and v['SynClassSK'].startswith(v['SynClassFinal']):
#         unaccusative.append(k)
#     elif v['SynClassSK'] == 'transitive' and v['SynClassSK'].startswith(v['SynClassFinal']):
#         transitive.append(k)
#     elif v['SynClassSK'] == 'unergative' and v['SynClassSK'].startswith(v['SynClassFinal'])==False:
#         failed_unergative.append(k)
#     else: 
#         not_included.append(k)
#         if v['Database']=='CREA':
#             need_to_be_classified.append(k)
#             print (k, 'is a verb in CREA and needs classficiation')

# %%
# print('the # of unergatives: ', len(unergative))
# print('the # of unaccusative: ', len(unaccusative))
# print('the # of transitives: ', len(transitive))
# print('the # of failed unergatives: ', len(failed_unergative))
# print(len(need_to_be_classified), 'of them appear in CREA')

# %%
# raw_upd3 = pd.DataFrame.from_dict(raw2_dic, orient='index')

# %%
#raw_upd3.head()

# %%
### label name update
# raw_upd3.loc[raw_upd3['SynClassFinal']=='unerg', 'SynClassFinal']='unergative'
# raw_upd3.loc[raw_upd3['SynClassFinal']=='unacc', 'SynClassFinal']='unaccusative'
# raw_upd3.loc[raw_upd3['SynClassFinal']=='tr', 'SynClassFinal']='transitive'

# %%
# unergative_list = raw_upd3[raw_upd3['SynClassFinal']=='unergative'].index
# unaccusative_list = raw_upd3[raw_upd3['SynClassFinal']=='unaccusative'].index
# transitive_list = raw_upd3[raw_upd3['SynClassFinal']=='transitive'].index

# %%
# print (unergative_list, "Unergative N=", len(unergative_list))
# print (unaccusative_list, "Unaccusative N=", len(unaccusative_list))
# print (transitive_list, "Transitive N=", len(transitive_list))

# %%
#### find verbs that have NaN in low-level qualities
# for c in cols_to_test: 
#     if raw_upd3.loc[pd.isna(raw_upd3[c])].shape[0] !=0: ### find any columns that contain NaN
#         verb_to_remove = raw_upd3.loc[pd.isna(raw_upd3[c])].index[0]
#         print ("verb", "\'", verb_to_remove, "\'", "has NaN in", c)
        
#### drop that verb from a list (if one of unergative, unaccsuative, transitive)
# categories = [unergative, unaccusative, transitive]
# for i in range(len(categories)):
#     if verb_to_remove in categories[i]:
#         print (i, verb_to_remove)
#     else:
#         print (verb_to_remove, 'is not found')

### make sure that low-level quality columns only have a numeral
# for col in cols_to_test:
#     col_to_list = raw_upd3[col].tolist()
#     types = list(set([type(i) for i in col_to_list]))
#     print (col, types)

#### Everything other than Concreteness looks fine

#pd.to_numeric(raw_upd3["Concreteness"])

# %%
# for k, v in raw2_dic.items():
#     if pd.isna(v['SynClassFinal']):
#         #print(k)
#         v['SynClassFinal'] = v['SynClassCorpus']

# %%
# verb_w_2syncat = raw_upd[raw_upd['most_frequent_pb'].notnull() & raw_upd['most_frequent_g'].notnull()]

# verb_w_1syncat = raw_upd[raw_upd['most_frequent_pb'].notnull() | raw_upd['most_frequent_g'].notnull()]

# verb_wo_syncat = raw_upd[raw_upd['most_frequent_pb'].isnull() & raw_upd['most_frequent_g'].isnull()]

# verb_w_2syncat.shape #number of verbs that appear both in PB and G

# verb_wo_syncat.shape #number of verbs that do not appear in either

# verb_w_1syncat.shape #number of verbs that appear in PB or G

# verb_w_1syncat.shape[0] + verb_w_2syncat.shape[0] + verb_wo_syncat.shape[0]

# raw_upd.shape
